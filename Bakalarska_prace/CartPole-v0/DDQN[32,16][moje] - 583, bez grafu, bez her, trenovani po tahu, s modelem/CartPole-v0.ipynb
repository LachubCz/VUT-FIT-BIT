# %% [markdown]
# # Inicializace

# %%
from collections import deque               # Ukladani stavu
from __future__ import division             # Deleni realnych cisel (kvuli verzi Pythonu 2.6)
import sys                                  # Pro navazani knihovny Open AI Gym
import numpy as np                          # Knihovna pro operace s maticemi
sys.path.append('/home/xbucha02/libraries') # Adresa knihovny Open AI Gym
import gym                                  # Knihovna Open AI Gym
#from gym import wrappers                    # Pomucka na nahravani
env = gym.make('CartPole-v0')            # Konkretni hra z Open AI Gym
#env = wrappers.Monitor(env, '/home/lachubcz/tmp/cartpole-experiment-1', force=True) #Nahravani zaznamu
#gpuMemoryUsage=1                            # Vyuziti pameti GPU
#import tensorflow as tf                     # Knihovna TensorFlow pro sdileni GPU
#from keras.backend.tensorflow_backend import set_session
#config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = gpuMemoryUsage
#set_session(tf.Session(config=config))
import random

# Parametry
observetime = 500                          # Pocet framu kazde hry
episodes = 1000                             # Pocet epizod
startEpsilon = 1.0                         # Pravdepodobnost konani nahodneho tahu na zacatku
endEpsilon = 0.005                           # Pravdepodobnost konani nahodneho tahu na konci
currentEpsilon = startEpsilon              # Soucasna pravdepodobnost konani nahodneho tahu
epsilonDiminution = (startEpsilon - endEpsilon)/(episodes * 5)                 # Hodnota snizovani epsilonu
gamma = 0.99                               # Discount faktor
minibatchSize = 32                         # Velikost minibatche
actionCount = env.action_space.n           # Pocet vstupu do prostredi
stateSize = env.observation_space.shape[0] # Pocet vystupu z prostredi
learningRate = 0.001                       # Learning rate
memorySize = 2000                         # Velikost Replay memory

# %% [markdown]
# # Model NN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import regularizers
from keras import optimizers
from keras import losses
from keras import metrics
from keras import backend as K

def _huber_loss(target, prediction):
    # sqrt(1+error^2)-1
    error = prediction - target
    return K.mean(K.sqrt(1+K.square(error))-1, axis=-1)

def getDQN(actionCount,stateSize):
    net = Sequential()
    net.add(Dense(32, activation="relu", input_dim=stateSize))
    net.add(Dense(16, activation="relu"))
    net.add(Dense(actionCount, activation="linear"))
    
    net.summary()
    
    net.compile(loss=losses.mean_squared_error, optimizer=optimizers.Adam(lr=learningRate), metrics=['accuracy'])
    
    return net

def loadDQN(net, name):
    net.load_weights(name)

def saveDQN(net, name):
    net.save_weights(name)

# %% [markdown]
# # Algoritmus DQN

# %%
net = getDQN(actionCount, stateSize)
netTarget = getDQN(actionCount, stateSize)
observation = env.reset()                    # Reset prostredi
memory = deque(maxlen=memorySize)

global scores
scores = []
global episodes
episodesList = []

for eps in range (episodes):
    
    #D = deque() #vyprazdneni D
    state = env.reset()
    state = np.reshape(state, [1, stateSize])
    #env.render()

    #q = 0
    for t in range(observetime):
        #if q == 0:
            
        #else:
        #    if q == 4:
        #        q = 0
        #    else:
        #        q = q + 1
        if currentEpsilon > endEpsilon:
            currentEpsilon = currentEpsilon - epsilonDiminution
            
        if np.random.rand() <= currentEpsilon:
            action = np.random.randint(0, actionCount, size=1)[0]
        else:
            Q = net.predict(state)

            action = np.argmax(Q)

        observation_new, reward, done, info = env.step(int(action))
        
        #reward = reward if not done else -10
        
        #if done and t != 199:
        #    reward = 10000
        
        next_state = np.reshape(observation_new, [1, stateSize])

        memory.append((state, action, reward, next_state, done))

        if len(memory) >= minibatchSize:
            minibatch = random.sample(memory, minibatchSize) #z D vybere pocet mb_size samplu

            for i in range(0, minibatchSize):

                stateMb = minibatch[i][0]
                actionMb = minibatch[i][1]
                rewardMb = minibatch[i][2]
                state_newMb = minibatch[i][3]
                doneMb = minibatch[i][4]

                target_f = net.predict(stateMb)

                if doneMb:
                    target_f[0][actionMb] = rewardMb
                else:
                    aNet = net.predict(state_newMb)[0]
                    tNet = netTarget.predict(state_newMb)[0]
                    target_f[0][actionMb] = rewardMb + gamma * tNet[np.argmax(aNet)]

                net.fit(stateMb, target_f, epochs=1, verbose=0)
        
        state = next_state         # Update state
        
        if eps % 25 == 0:
            saveDQN(net, "./DQN-CartPole-v0.h5")
        
        if done:
            print("Episode: {}/{}, epsilon: {:.2}, score: {}".format(eps, episodes, currentEpsilon, t))
            scores.append(t)
            episodesList.append(eps)
            netTarget.set_weights(net.get_weights())
            break
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 722
# Trainable params: 722
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 32)                160
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 722
# Trainable params: 722
# Non-trainable params: 0
# _________________________________________________________________
# Episode: 0/1000, epsilon: 1.0, score: 13
# Episode: 1/1000, epsilon: 0.99, score: 12
# Episode: 2/1000, epsilon: 0.99, score: 31
# Episode: 3/1000, epsilon: 0.99, score: 15
# Episode: 4/1000, epsilon: 0.98, score: 19
# Episode: 5/1000, epsilon: 0.98, score: 10
# Episode: 6/1000, epsilon: 0.97, score: 19
# Episode: 7/1000, epsilon: 0.97, score: 18
# Episode: 8/1000, epsilon: 0.97, score: 19
# Episode: 9/1000, epsilon: 0.96, score: 17
# Episode: 10/1000, epsilon: 0.96, score: 11
# Episode: 11/1000, epsilon: 0.96, score: 8
# Episode: 12/1000, epsilon: 0.95, score: 32
# Episode: 13/1000, epsilon: 0.95, score: 35
# Episode: 14/1000, epsilon: 0.94, score: 39
# Episode: 15/1000, epsilon: 0.93, score: 18
# Episode: 16/1000, epsilon: 0.93, score: 15
# Episode: 17/1000, epsilon: 0.93, score: 22
# Episode: 18/1000, epsilon: 0.92, score: 15
# Episode: 19/1000, epsilon: 0.92, score: 17
# Episode: 20/1000, epsilon: 0.92, score: 18
# Episode: 21/1000, epsilon: 0.91, score: 9
# Episode: 22/1000, epsilon: 0.91, score: 20
# Episode: 23/1000, epsilon: 0.91, score: 12
# Episode: 24/1000, epsilon: 0.9, score: 22
# Episode: 25/1000, epsilon: 0.9, score: 30
# Episode: 26/1000, epsilon: 0.89, score: 21
# Episode: 27/1000, epsilon: 0.89, score: 14
# Episode: 28/1000, epsilon: 0.89, score: 12
# Episode: 29/1000, epsilon: 0.88, score: 31
# Episode: 30/1000, epsilon: 0.88, score: 12
# Episode: 31/1000, epsilon: 0.87, score: 13
# Episode: 32/1000, epsilon: 0.87, score: 10
# Episode: 33/1000, epsilon: 0.87, score: 20
# Episode: 34/1000, epsilon: 0.85, score: 76
# Episode: 35/1000, epsilon: 0.85, score: 15
# Episode: 36/1000, epsilon: 0.85, score: 19
# Episode: 37/1000, epsilon: 0.84, score: 17
# Episode: 38/1000, epsilon: 0.84, score: 16
# Episode: 39/1000, epsilon: 0.83, score: 31
# Episode: 40/1000, epsilon: 0.82, score: 78
# Episode: 41/1000, epsilon: 0.81, score: 30
# Episode: 42/1000, epsilon: 0.81, score: 14
# Episode: 43/1000, epsilon: 0.79, score: 65
# Episode: 44/1000, epsilon: 0.79, score: 18
# Episode: 45/1000, epsilon: 0.79, score: 14
# Episode: 46/1000, epsilon: 0.78, score: 46
# Episode: 47/1000, epsilon: 0.77, score: 41
# Episode: 48/1000, epsilon: 0.75, score: 84
# Episode: 49/1000, epsilon: 0.75, score: 34
# Episode: 50/1000, epsilon: 0.74, score: 38
# Episode: 51/1000, epsilon: 0.72, score: 70
# Episode: 52/1000, epsilon: 0.72, score: 35
# Episode: 53/1000, epsilon: 0.71, score: 31
# Episode: 54/1000, epsilon: 0.7, score: 34
# Episode: 55/1000, epsilon: 0.69, score: 47
# Episode: 56/1000, epsilon: 0.69, score: 11
# Episode: 57/1000, epsilon: 0.68, score: 32
# Episode: 58/1000, epsilon: 0.68, score: 18
# Episode: 59/1000, epsilon: 0.67, score: 73
# Episode: 60/1000, epsilon: 0.66, score: 41
# Episode: 61/1000, epsilon: 0.64, score: 81
# Episode: 62/1000, epsilon: 0.63, score: 71
# Episode: 63/1000, epsilon: 0.61, score: 100
# Episode: 64/1000, epsilon: 0.6, score: 32
# Episode: 65/1000, epsilon: 0.59, score: 72
# Episode: 66/1000, epsilon: 0.57, score: 71
# Episode: 67/1000, epsilon: 0.57, score: 21
# Episode: 68/1000, epsilon: 0.56, score: 13
# Episode: 69/1000, epsilon: 0.55, score: 64
# Episode: 70/1000, epsilon: 0.52, score: 164
# Episode: 71/1000, epsilon: 0.48, score: 177
# Episode: 72/1000, epsilon: 0.45, score: 178
# Episode: 73/1000, epsilon: 0.42, score: 131
# Episode: 74/1000, epsilon: 0.41, score: 47
# Episode: 75/1000, epsilon: 0.38, score: 169
# Episode: 76/1000, epsilon: 0.35, score: 126
# Episode: 77/1000, epsilon: 0.33, score: 123
# Episode: 78/1000, epsilon: 0.33, score: 9
# Episode: 79/1000, epsilon: 0.31, score: 106
# Episode: 80/1000, epsilon: 0.3, score: 33
# Episode: 81/1000, epsilon: 0.29, score: 26
# Episode: 82/1000, epsilon: 0.27, score: 118
# Episode: 83/1000, epsilon: 0.26, score: 21
# Episode: 84/1000, epsilon: 0.24, score: 135
# Episode: 85/1000, epsilon: 0.21, score: 123
# Episode: 86/1000, epsilon: 0.19, score: 111
# Episode: 87/1000, epsilon: 0.19, score: 27
# Episode: 88/1000, epsilon: 0.16, score: 123
# Episode: 89/1000, epsilon: 0.14, score: 111
# Episode: 90/1000, epsilon: 0.12, score: 99
# Episode: 91/1000, epsilon: 0.094, score: 124
# Episode: 92/1000, epsilon: 0.073, score: 101
# Episode: 93/1000, epsilon: 0.051, score: 112
# Episode: 94/1000, epsilon: 0.027, score: 116
# Episode: 95/1000, epsilon: 0.0048, score: 139
# Episode: 96/1000, epsilon: 0.0048, score: 103
# Episode: 97/1000, epsilon: 0.0048, score: 116
# Episode: 98/1000, epsilon: 0.0048, score: 120
# Episode: 99/1000, epsilon: 0.0048, score: 156
# Episode: 100/1000, epsilon: 0.0048, score: 128
# Episode: 101/1000, epsilon: 0.0048, score: 66
# Episode: 102/1000, epsilon: 0.0048, score: 147
# Episode: 103/1000, epsilon: 0.0048, score: 105
# Episode: 104/1000, epsilon: 0.0048, score: 130
# Episode: 105/1000, epsilon: 0.0048, score: 106
# Episode: 106/1000, epsilon: 0.0048, score: 109
# Episode: 107/1000, epsilon: 0.0048, score: 118
# Episode: 108/1000, epsilon: 0.0048, score: 102
# Episode: 109/1000, epsilon: 0.0048, score: 99
# Episode: 110/1000, epsilon: 0.0048, score: 111
# Episode: 111/1000, epsilon: 0.0048, score: 120
# Episode: 112/1000, epsilon: 0.0048, score: 114
# Episode: 113/1000, epsilon: 0.0048, score: 111
# Episode: 114/1000, epsilon: 0.0048, score: 97
# Episode: 115/1000, epsilon: 0.0048, score: 104
# Episode: 116/1000, epsilon: 0.0048, score: 104
# Episode: 117/1000, epsilon: 0.0048, score: 110
# Episode: 118/1000, epsilon: 0.0048, score: 103
# Episode: 119/1000, epsilon: 0.0048, score: 109
# Episode: 120/1000, epsilon: 0.0048, score: 103
# Episode: 121/1000, epsilon: 0.0048, score: 112
# Episode: 122/1000, epsilon: 0.0048, score: 123
# Episode: 123/1000, epsilon: 0.0048, score: 118
# Episode: 124/1000, epsilon: 0.0048, score: 120
# Episode: 125/1000, epsilon: 0.0048, score: 110
# Episode: 126/1000, epsilon: 0.0048, score: 110
# Episode: 127/1000, epsilon: 0.0048, score: 111
# Episode: 128/1000, epsilon: 0.0048, score: 107
# Episode: 129/1000, epsilon: 0.0048, score: 118
# Episode: 130/1000, epsilon: 0.0048, score: 114
# Episode: 131/1000, epsilon: 0.0048, score: 109
# Episode: 132/1000, epsilon: 0.0048, score: 152
# Episode: 133/1000, epsilon: 0.0048, score: 113
# Episode: 134/1000, epsilon: 0.0048, score: 118
# Episode: 135/1000, epsilon: 0.0048, score: 83
# Episode: 136/1000, epsilon: 0.0048, score: 101
# Episode: 137/1000, epsilon: 0.0048, score: 78
# Episode: 138/1000, epsilon: 0.0048, score: 13
# Episode: 139/1000, epsilon: 0.0048, score: 14
# Episode: 140/1000, epsilon: 0.0048, score: 11
# Episode: 141/1000, epsilon: 0.0048, score: 29
# Episode: 142/1000, epsilon: 0.0048, score: 14
# Episode: 143/1000, epsilon: 0.0048, score: 149
# Episode: 144/1000, epsilon: 0.0048, score: 122
# Episode: 145/1000, epsilon: 0.0048, score: 126
# Episode: 146/1000, epsilon: 0.0048, score: 123
# Episode: 147/1000, epsilon: 0.0048, score: 117
# Episode: 148/1000, epsilon: 0.0048, score: 124
# Episode: 149/1000, epsilon: 0.0048, score: 99
# Episode: 150/1000, epsilon: 0.0048, score: 117
# Episode: 151/1000, epsilon: 0.0048, score: 101
# Episode: 152/1000, epsilon: 0.0048, score: 108
# Episode: 153/1000, epsilon: 0.0048, score: 93
# Episode: 154/1000, epsilon: 0.0048, score: 99
# Episode: 155/1000, epsilon: 0.0048, score: 98
# Episode: 156/1000, epsilon: 0.0048, score: 96
# Episode: 157/1000, epsilon: 0.0048, score: 92
# Episode: 158/1000, epsilon: 0.0048, score: 92
# Episode: 159/1000, epsilon: 0.0048, score: 103
# Episode: 160/1000, epsilon: 0.0048, score: 104
# Episode: 161/1000, epsilon: 0.0048, score: 124
# Episode: 162/1000, epsilon: 0.0048, score: 145
# Episode: 163/1000, epsilon: 0.0048, score: 145
# Episode: 164/1000, epsilon: 0.0048, score: 142
# Episode: 165/1000, epsilon: 0.0048, score: 139
# Episode: 166/1000, epsilon: 0.0048, score: 124
# Episode: 167/1000, epsilon: 0.0048, score: 134
# Episode: 168/1000, epsilon: 0.0048, score: 154
# Episode: 169/1000, epsilon: 0.0048, score: 109
# Episode: 170/1000, epsilon: 0.0048, score: 123
# Episode: 171/1000, epsilon: 0.0048, score: 143
# Episode: 172/1000, epsilon: 0.0048, score: 153
# Episode: 173/1000, epsilon: 0.0048, score: 170
# Episode: 174/1000, epsilon: 0.0048, score: 199
# Episode: 175/1000, epsilon: 0.0048, score: 199
# Episode: 176/1000, epsilon: 0.0048, score: 199
# Episode: 177/1000, epsilon: 0.0048, score: 147
# Episode: 178/1000, epsilon: 0.0048, score: 170
# Episode: 179/1000, epsilon: 0.0048, score: 114
# Episode: 180/1000, epsilon: 0.0048, score: 199
# Episode: 181/1000, epsilon: 0.0048, score: 188
# Episode: 182/1000, epsilon: 0.0048, score: 188
# Episode: 183/1000, epsilon: 0.0048, score: 165
# Episode: 184/1000, epsilon: 0.0048, score: 138
# Episode: 185/1000, epsilon: 0.0048, score: 179
# Episode: 186/1000, epsilon: 0.0048, score: 199
# Episode: 187/1000, epsilon: 0.0048, score: 123
# Episode: 188/1000, epsilon: 0.0048, score: 114
# Episode: 189/1000, epsilon: 0.0048, score: 72
# Episode: 190/1000, epsilon: 0.0048, score: 99
# Episode: 191/1000, epsilon: 0.0048, score: 87
# Episode: 192/1000, epsilon: 0.0048, score: 86
# Episode: 193/1000, epsilon: 0.0048, score: 94
# Episode: 194/1000, epsilon: 0.0048, score: 88
# Episode: 195/1000, epsilon: 0.0048, score: 104
# Episode: 196/1000, epsilon: 0.0048, score: 97
# Episode: 197/1000, epsilon: 0.0048, score: 117
# Episode: 198/1000, epsilon: 0.0048, score: 109
# Episode: 199/1000, epsilon: 0.0048, score: 199
# Episode: 200/1000, epsilon: 0.0048, score: 199
# Episode: 201/1000, epsilon: 0.0048, score: 199
# Episode: 202/1000, epsilon: 0.0048, score: 29
# Episode: 203/1000, epsilon: 0.0048, score: 130
# Episode: 204/1000, epsilon: 0.0048, score: 174
# Episode: 205/1000, epsilon: 0.0048, score: 199
# Episode: 206/1000, epsilon: 0.0048, score: 138
# Episode: 207/1000, epsilon: 0.0048, score: 199
# Episode: 208/1000, epsilon: 0.0048, score: 120
# Episode: 209/1000, epsilon: 0.0048, score: 199
# Episode: 210/1000, epsilon: 0.0048, score: 182
# Episode: 211/1000, epsilon: 0.0048, score: 199
# Episode: 212/1000, epsilon: 0.0048, score: 93
# Episode: 213/1000, epsilon: 0.0048, score: 90
# Episode: 214/1000, epsilon: 0.0048, score: 97
# Episode: 215/1000, epsilon: 0.0048, score: 160
# Episode: 216/1000, epsilon: 0.0048, score: 199
# Episode: 217/1000, epsilon: 0.0048, score: 199
# Episode: 218/1000, epsilon: 0.0048, score: 199
# Episode: 219/1000, epsilon: 0.0048, score: 169
# Episode: 220/1000, epsilon: 0.0048, score: 118
# Episode: 221/1000, epsilon: 0.0048, score: 137
# Episode: 222/1000, epsilon: 0.0048, score: 168
# Episode: 223/1000, epsilon: 0.0048, score: 143
# Episode: 224/1000, epsilon: 0.0048, score: 139
# Episode: 225/1000, epsilon: 0.0048, score: 168
# Episode: 226/1000, epsilon: 0.0048, score: 194
# Episode: 227/1000, epsilon: 0.0048, score: 199
# Episode: 228/1000, epsilon: 0.0048, score: 199
# Episode: 229/1000, epsilon: 0.0048, score: 199
# Episode: 230/1000, epsilon: 0.0048, score: 199
# Episode: 231/1000, epsilon: 0.0048, score: 199
# Episode: 232/1000, epsilon: 0.0048, score: 199
# Episode: 233/1000, epsilon: 0.0048, score: 199
# Episode: 234/1000, epsilon: 0.0048, score: 199
# Episode: 235/1000, epsilon: 0.0048, score: 199
# Episode: 236/1000, epsilon: 0.0048, score: 199
# Episode: 237/1000, epsilon: 0.0048, score: 163
# Episode: 238/1000, epsilon: 0.0048, score: 170
# Episode: 239/1000, epsilon: 0.0048, score: 133
# Episode: 240/1000, epsilon: 0.0048, score: 199
# Episode: 241/1000, epsilon: 0.0048, score: 199
# Episode: 242/1000, epsilon: 0.0048, score: 199
# Episode: 243/1000, epsilon: 0.0048, score: 199
# Episode: 244/1000, epsilon: 0.0048, score: 199
# Episode: 245/1000, epsilon: 0.0048, score: 199
# Episode: 246/1000, epsilon: 0.0048, score: 199
# Episode: 247/1000, epsilon: 0.0048, score: 199
# Episode: 248/1000, epsilon: 0.0048, score: 199
# Episode: 249/1000, epsilon: 0.0048, score: 199
# Episode: 250/1000, epsilon: 0.0048, score: 199
# Episode: 251/1000, epsilon: 0.0048, score: 199
# Episode: 252/1000, epsilon: 0.0048, score: 199
# Episode: 253/1000, epsilon: 0.0048, score: 139
# Episode: 254/1000, epsilon: 0.0048, score: 147
# Episode: 255/1000, epsilon: 0.0048, score: 82
# Episode: 256/1000, epsilon: 0.0048, score: 118
# Episode: 257/1000, epsilon: 0.0048, score: 189
# Episode: 258/1000, epsilon: 0.0048, score: 199
# Episode: 259/1000, epsilon: 0.0048, score: 199
# Episode: 260/1000, epsilon: 0.0048, score: 199
# Episode: 261/1000, epsilon: 0.0048, score: 199
# Episode: 262/1000, epsilon: 0.0048, score: 199
# Episode: 263/1000, epsilon: 0.0048, score: 199
# Episode: 264/1000, epsilon: 0.0048, score: 153
# Episode: 265/1000, epsilon: 0.0048, score: 199
# Episode: 266/1000, epsilon: 0.0048, score: 199
# Episode: 267/1000, epsilon: 0.0048, score: 199
# Episode: 268/1000, epsilon: 0.0048, score: 199
# Episode: 269/1000, epsilon: 0.0048, score: 199
# Episode: 270/1000, epsilon: 0.0048, score: 189
# Episode: 271/1000, epsilon: 0.0048, score: 54
# Episode: 272/1000, epsilon: 0.0048, score: 29
# Episode: 273/1000, epsilon: 0.0048, score: 44
# Episode: 274/1000, epsilon: 0.0048, score: 199
# Episode: 275/1000, epsilon: 0.0048, score: 23
# Episode: 276/1000, epsilon: 0.0048, score: 27
# Episode: 277/1000, epsilon: 0.0048, score: 199
# Episode: 278/1000, epsilon: 0.0048, score: 199
# Episode: 279/1000, epsilon: 0.0048, score: 199
# Episode: 280/1000, epsilon: 0.0048, score: 199
# Episode: 281/1000, epsilon: 0.0048, score: 199
# Episode: 282/1000, epsilon: 0.0048, score: 199
# Episode: 283/1000, epsilon: 0.0048, score: 199
# Episode: 284/1000, epsilon: 0.0048, score: 199
# Episode: 285/1000, epsilon: 0.0048, score: 199
# Episode: 286/1000, epsilon: 0.0048, score: 199
# Episode: 287/1000, epsilon: 0.0048, score: 199
# Episode: 288/1000, epsilon: 0.0048, score: 199
# Episode: 289/1000, epsilon: 0.0048, score: 199
# Episode: 290/1000, epsilon: 0.0048, score: 199
# Episode: 291/1000, epsilon: 0.0048, score: 199
# Episode: 292/1000, epsilon: 0.0048, score: 199
# Episode: 293/1000, epsilon: 0.0048, score: 199
# Episode: 294/1000, epsilon: 0.0048, score: 199
# Episode: 295/1000, epsilon: 0.0048, score: 199
# Episode: 296/1000, epsilon: 0.0048, score: 199
# Episode: 297/1000, epsilon: 0.0048, score: 199
# Episode: 298/1000, epsilon: 0.0048, score: 114
# Episode: 299/1000, epsilon: 0.0048, score: 199
# Episode: 300/1000, epsilon: 0.0048, score: 199
# Episode: 301/1000, epsilon: 0.0048, score: 96
# Episode: 302/1000, epsilon: 0.0048, score: 199
# Episode: 303/1000, epsilon: 0.0048, score: 43
# Episode: 304/1000, epsilon: 0.0048, score: 146
# Episode: 305/1000, epsilon: 0.0048, score: 199
# Episode: 306/1000, epsilon: 0.0048, score: 199
# Episode: 307/1000, epsilon: 0.0048, score: 199
# Episode: 308/1000, epsilon: 0.0048, score: 118
# Episode: 309/1000, epsilon: 0.0048, score: 199
# Episode: 310/1000, epsilon: 0.0048, score: 199
# Episode: 311/1000, epsilon: 0.0048, score: 199
# Episode: 312/1000, epsilon: 0.0048, score: 148
# Episode: 313/1000, epsilon: 0.0048, score: 199
# Episode: 314/1000, epsilon: 0.0048, score: 199
# Episode: 315/1000, epsilon: 0.0048, score: 199
# Episode: 316/1000, epsilon: 0.0048, score: 199
# Episode: 317/1000, epsilon: 0.0048, score: 199
# Episode: 318/1000, epsilon: 0.0048, score: 199
# Episode: 319/1000, epsilon: 0.0048, score: 199
# Episode: 320/1000, epsilon: 0.0048, score: 199
# Episode: 321/1000, epsilon: 0.0048, score: 199
# Episode: 322/1000, epsilon: 0.0048, score: 172
# Episode: 323/1000, epsilon: 0.0048, score: 156
# Episode: 324/1000, epsilon: 0.0048, score: 120
# Episode: 325/1000, epsilon: 0.0048, score: 107
# Episode: 326/1000, epsilon: 0.0048, score: 89
# Episode: 327/1000, epsilon: 0.0048, score: 78
# Episode: 328/1000, epsilon: 0.0048, score: 86
# Episode: 329/1000, epsilon: 0.0048, score: 94
# Episode: 330/1000, epsilon: 0.0048, score: 92
# Episode: 331/1000, epsilon: 0.0048, score: 100
# Episode: 332/1000, epsilon: 0.0048, score: 126
# Episode: 333/1000, epsilon: 0.0048, score: 112
# Episode: 334/1000, epsilon: 0.0048, score: 27
# Episode: 335/1000, epsilon: 0.0048, score: 19
# Episode: 336/1000, epsilon: 0.0048, score: 45
# Episode: 337/1000, epsilon: 0.0048, score: 199
# Episode: 338/1000, epsilon: 0.0048, score: 135
# Episode: 339/1000, epsilon: 0.0048, score: 126
# Episode: 340/1000, epsilon: 0.0048, score: 135
# Episode: 341/1000, epsilon: 0.0048, score: 152
# Episode: 342/1000, epsilon: 0.0048, score: 131
# Episode: 343/1000, epsilon: 0.0048, score: 199
# Episode: 344/1000, epsilon: 0.0048, score: 199
# Episode: 345/1000, epsilon: 0.0048, score: 199
# Episode: 346/1000, epsilon: 0.0048, score: 199
# Episode: 347/1000, epsilon: 0.0048, score: 199
# Episode: 348/1000, epsilon: 0.0048, score: 199
# Episode: 349/1000, epsilon: 0.0048, score: 151
# Episode: 350/1000, epsilon: 0.0048, score: 199
# Episode: 351/1000, epsilon: 0.0048, score: 114
# Episode: 352/1000, epsilon: 0.0048, score: 199
# Episode: 353/1000, epsilon: 0.0048, score: 77
# Episode: 354/1000, epsilon: 0.0048, score: 175
# Episode: 355/1000, epsilon: 0.0048, score: 156
# Episode: 356/1000, epsilon: 0.0048, score: 113
# Episode: 357/1000, epsilon: 0.0048, score: 178
# Episode: 358/1000, epsilon: 0.0048, score: 177
# Episode: 359/1000, epsilon: 0.0048, score: 105
# Episode: 360/1000, epsilon: 0.0048, score: 107
# Episode: 361/1000, epsilon: 0.0048, score: 194
# Episode: 362/1000, epsilon: 0.0048, score: 199
# Episode: 363/1000, epsilon: 0.0048, score: 140
# Episode: 364/1000, epsilon: 0.0048, score: 184
# Episode: 365/1000, epsilon: 0.0048, score: 121
# Episode: 366/1000, epsilon: 0.0048, score: 197
# Episode: 367/1000, epsilon: 0.0048, score: 199
# Episode: 368/1000, epsilon: 0.0048, score: 148
# Episode: 369/1000, epsilon: 0.0048, score: 199
# Episode: 370/1000, epsilon: 0.0048, score: 199
# Episode: 371/1000, epsilon: 0.0048, score: 199
# Episode: 372/1000, epsilon: 0.0048, score: 60
# Episode: 373/1000, epsilon: 0.0048, score: 31
# Episode: 374/1000, epsilon: 0.0048, score: 10
# Episode: 375/1000, epsilon: 0.0048, score: 8
# Episode: 376/1000, epsilon: 0.0048, score: 9
# Episode: 377/1000, epsilon: 0.0048, score: 14
# Episode: 378/1000, epsilon: 0.0048, score: 10
# Episode: 379/1000, epsilon: 0.0048, score: 39
# Episode: 380/1000, epsilon: 0.0048, score: 199
# Episode: 381/1000, epsilon: 0.0048, score: 199
# Episode: 382/1000, epsilon: 0.0048, score: 169
# Episode: 383/1000, epsilon: 0.0048, score: 150
# Episode: 384/1000, epsilon: 0.0048, score: 165
# Episode: 385/1000, epsilon: 0.0048, score: 161
# Episode: 386/1000, epsilon: 0.0048, score: 143
# Episode: 387/1000, epsilon: 0.0048, score: 70
# Episode: 388/1000, epsilon: 0.0048, score: 91
# Episode: 389/1000, epsilon: 0.0048, score: 106
# Episode: 390/1000, epsilon: 0.0048, score: 120
# Episode: 391/1000, epsilon: 0.0048, score: 151
# Episode: 392/1000, epsilon: 0.0048, score: 199
# Episode: 393/1000, epsilon: 0.0048, score: 199
# Episode: 394/1000, epsilon: 0.0048, score: 199
# Episode: 395/1000, epsilon: 0.0048, score: 124
# Episode: 396/1000, epsilon: 0.0048, score: 116
# Episode: 397/1000, epsilon: 0.0048, score: 113
# Episode: 398/1000, epsilon: 0.0048, score: 115
# Episode: 399/1000, epsilon: 0.0048, score: 108
# Episode: 400/1000, epsilon: 0.0048, score: 117
# Episode: 401/1000, epsilon: 0.0048, score: 120
# Episode: 402/1000, epsilon: 0.0048, score: 119
# Episode: 403/1000, epsilon: 0.0048, score: 113
# Episode: 404/1000, epsilon: 0.0048, score: 114
# Episode: 405/1000, epsilon: 0.0048, score: 121
# Episode: 406/1000, epsilon: 0.0048, score: 143
# Episode: 407/1000, epsilon: 0.0048, score: 131
# Episode: 408/1000, epsilon: 0.0048, score: 121
# Episode: 409/1000, epsilon: 0.0048, score: 16
# Episode: 410/1000, epsilon: 0.0048, score: 15
# Episode: 411/1000, epsilon: 0.0048, score: 158
# Episode: 412/1000, epsilon: 0.0048, score: 146
# Episode: 413/1000, epsilon: 0.0048, score: 93
# Episode: 414/1000, epsilon: 0.0048, score: 83
# Episode: 415/1000, epsilon: 0.0048, score: 199
# Episode: 416/1000, epsilon: 0.0048, score: 136
# Episode: 417/1000, epsilon: 0.0048, score: 199
# Episode: 418/1000, epsilon: 0.0048, score: 167
# Episode: 419/1000, epsilon: 0.0048, score: 199
# Episode: 420/1000, epsilon: 0.0048, score: 199
# Episode: 421/1000, epsilon: 0.0048, score: 199
# Episode: 422/1000, epsilon: 0.0048, score: 199
# Episode: 423/1000, epsilon: 0.0048, score: 178
# Episode: 424/1000, epsilon: 0.0048, score: 199
# Episode: 425/1000, epsilon: 0.0048, score: 182
# Episode: 426/1000, epsilon: 0.0048, score: 12
# Episode: 427/1000, epsilon: 0.0048, score: 25
# Episode: 428/1000, epsilon: 0.0048, score: 199
# Episode: 429/1000, epsilon: 0.0048, score: 199
# Episode: 430/1000, epsilon: 0.0048, score: 199
# Episode: 431/1000, epsilon: 0.0048, score: 199
# Episode: 432/1000, epsilon: 0.0048, score: 199
# Episode: 433/1000, epsilon: 0.0048, score: 199
# Episode: 434/1000, epsilon: 0.0048, score: 199
# Episode: 435/1000, epsilon: 0.0048, score: 199
# Episode: 436/1000, epsilon: 0.0048, score: 166
# Episode: 437/1000, epsilon: 0.0048, score: 199
# Episode: 438/1000, epsilon: 0.0048, score: 199
# Episode: 439/1000, epsilon: 0.0048, score: 199
# Episode: 440/1000, epsilon: 0.0048, score: 199
# Episode: 441/1000, epsilon: 0.0048, score: 199
# Episode: 442/1000, epsilon: 0.0048, score: 199
# Episode: 443/1000, epsilon: 0.0048, score: 199
# Episode: 444/1000, epsilon: 0.0048, score: 167
# Episode: 445/1000, epsilon: 0.0048, score: 160
# Episode: 446/1000, epsilon: 0.0048, score: 159
# Episode: 447/1000, epsilon: 0.0048, score: 169
# Episode: 448/1000, epsilon: 0.0048, score: 178
# Episode: 449/1000, epsilon: 0.0048, score: 177
# Episode: 450/1000, epsilon: 0.0048, score: 164
# Episode: 451/1000, epsilon: 0.0048, score: 143
# Episode: 452/1000, epsilon: 0.0048, score: 161
# Episode: 453/1000, epsilon: 0.0048, score: 170
# Episode: 454/1000, epsilon: 0.0048, score: 173
# Episode: 455/1000, epsilon: 0.0048, score: 191
# Episode: 456/1000, epsilon: 0.0048, score: 61
# Episode: 457/1000, epsilon: 0.0048, score: 199
# Episode: 458/1000, epsilon: 0.0048, score: 188
# Episode: 459/1000, epsilon: 0.0048, score: 178
# Episode: 460/1000, epsilon: 0.0048, score: 174
# Episode: 461/1000, epsilon: 0.0048, score: 152
# Episode: 462/1000, epsilon: 0.0048, score: 168
# Episode: 463/1000, epsilon: 0.0048, score: 149
# Episode: 464/1000, epsilon: 0.0048, score: 135
# Episode: 465/1000, epsilon: 0.0048, score: 127
# Episode: 466/1000, epsilon: 0.0048, score: 112
# Episode: 467/1000, epsilon: 0.0048, score: 104
# Episode: 468/1000, epsilon: 0.0048, score: 181
# Episode: 469/1000, epsilon: 0.0048, score: 143
# Episode: 470/1000, epsilon: 0.0048, score: 160
# Episode: 471/1000, epsilon: 0.0048, score: 141
# Episode: 472/1000, epsilon: 0.0048, score: 148
# Episode: 473/1000, epsilon: 0.0048, score: 173
# Episode: 474/1000, epsilon: 0.0048, score: 127
# Episode: 475/1000, epsilon: 0.0048, score: 122
# Episode: 476/1000, epsilon: 0.0048, score: 140
# Episode: 477/1000, epsilon: 0.0048, score: 142
# Episode: 478/1000, epsilon: 0.0048, score: 125
# Episode: 479/1000, epsilon: 0.0048, score: 128
# Episode: 480/1000, epsilon: 0.0048, score: 137
# Episode: 481/1000, epsilon: 0.0048, score: 137
# Episode: 482/1000, epsilon: 0.0048, score: 133
# Episode: 483/1000, epsilon: 0.0048, score: 148
# Episode: 484/1000, epsilon: 0.0048, score: 151
# Episode: 485/1000, epsilon: 0.0048, score: 199
# Episode: 486/1000, epsilon: 0.0048, score: 199
# Episode: 487/1000, epsilon: 0.0048, score: 191
# Episode: 488/1000, epsilon: 0.0048, score: 164
# Episode: 489/1000, epsilon: 0.0048, score: 30
# Episode: 490/1000, epsilon: 0.0048, score: 12
# Episode: 491/1000, epsilon: 0.0048, score: 9
# Episode: 492/1000, epsilon: 0.0048, score: 196
# Episode: 493/1000, epsilon: 0.0048, score: 169
# Episode: 494/1000, epsilon: 0.0048, score: 173
# Episode: 495/1000, epsilon: 0.0048, score: 134
# Episode: 496/1000, epsilon: 0.0048, score: 199
# Episode: 497/1000, epsilon: 0.0048, score: 199
# Episode: 498/1000, epsilon: 0.0048, score: 145
# Episode: 499/1000, epsilon: 0.0048, score: 138
# Episode: 500/1000, epsilon: 0.0048, score: 161
# Episode: 501/1000, epsilon: 0.0048, score: 129
# Episode: 502/1000, epsilon: 0.0048, score: 138
# Episode: 503/1000, epsilon: 0.0048, score: 162
# Episode: 504/1000, epsilon: 0.0048, score: 134
# Episode: 505/1000, epsilon: 0.0048, score: 141
# Episode: 506/1000, epsilon: 0.0048, score: 189
# Episode: 507/1000, epsilon: 0.0048, score: 199
# Episode: 508/1000, epsilon: 0.0048, score: 199
# Episode: 509/1000, epsilon: 0.0048, score: 199
# Episode: 510/1000, epsilon: 0.0048, score: 159
# Episode: 511/1000, epsilon: 0.0048, score: 176
# Episode: 512/1000, epsilon: 0.0048, score: 145
# Episode: 513/1000, epsilon: 0.0048, score: 119
# Episode: 514/1000, epsilon: 0.0048, score: 150
# Episode: 515/1000, epsilon: 0.0048, score: 134
# Episode: 516/1000, epsilon: 0.0048, score: 140
# Episode: 517/1000, epsilon: 0.0048, score: 138
# Episode: 518/1000, epsilon: 0.0048, score: 142
# Episode: 519/1000, epsilon: 0.0048, score: 138
# Episode: 520/1000, epsilon: 0.0048, score: 139
# Episode: 521/1000, epsilon: 0.0048, score: 132
# Episode: 522/1000, epsilon: 0.0048, score: 144
# Episode: 523/1000, epsilon: 0.0048, score: 134
# Episode: 524/1000, epsilon: 0.0048, score: 129
# Episode: 525/1000, epsilon: 0.0048, score: 163
# Episode: 526/1000, epsilon: 0.0048, score: 199
# Episode: 527/1000, epsilon: 0.0048, score: 199
# Episode: 528/1000, epsilon: 0.0048, score: 193
# Episode: 529/1000, epsilon: 0.0048, score: 172
# Episode: 530/1000, epsilon: 0.0048, score: 199
# Episode: 531/1000, epsilon: 0.0048, score: 160
# Episode: 532/1000, epsilon: 0.0048, score: 166
# Episode: 533/1000, epsilon: 0.0048, score: 199
# Episode: 534/1000, epsilon: 0.0048, score: 199
# Episode: 535/1000, epsilon: 0.0048, score: 199
# Episode: 536/1000, epsilon: 0.0048, score: 199
# Episode: 537/1000, epsilon: 0.0048, score: 199
# Episode: 538/1000, epsilon: 0.0048, score: 199
# Episode: 539/1000, epsilon: 0.0048, score: 199
# Episode: 540/1000, epsilon: 0.0048, score: 199
# Episode: 541/1000, epsilon: 0.0048, score: 144
# Episode: 542/1000, epsilon: 0.0048, score: 171
# Episode: 543/1000, epsilon: 0.0048, score: 146
# Episode: 544/1000, epsilon: 0.0048, score: 163
# Episode: 545/1000, epsilon: 0.0048, score: 163
# Episode: 546/1000, epsilon: 0.0048, score: 199
# Episode: 547/1000, epsilon: 0.0048, score: 199
# Episode: 548/1000, epsilon: 0.0048, score: 199
# Episode: 549/1000, epsilon: 0.0048, score: 125
# Episode: 550/1000, epsilon: 0.0048, score: 72
# Episode: 551/1000, epsilon: 0.0048, score: 105
# Episode: 552/1000, epsilon: 0.0048, score: 199
# Episode: 553/1000, epsilon: 0.0048, score: 199
# Episode: 554/1000, epsilon: 0.0048, score: 199
# Episode: 555/1000, epsilon: 0.0048, score: 199
# Episode: 556/1000, epsilon: 0.0048, score: 199
# Episode: 557/1000, epsilon: 0.0048, score: 92
# Episode: 558/1000, epsilon: 0.0048, score: 199
# Episode: 559/1000, epsilon: 0.0048, score: 169
# Episode: 560/1000, epsilon: 0.0048, score: 199
# Episode: 561/1000, epsilon: 0.0048, score: 199
# Episode: 562/1000, epsilon: 0.0048, score: 199
# Episode: 563/1000, epsilon: 0.0048, score: 199
# Episode: 564/1000, epsilon: 0.0048, score: 199
# Episode: 565/1000, epsilon: 0.0048, score: 199
# Episode: 566/1000, epsilon: 0.0048, score: 199
# Episode: 567/1000, epsilon: 0.0048, score: 199
# Episode: 568/1000, epsilon: 0.0048, score: 199
# Episode: 569/1000, epsilon: 0.0048, score: 199
# Episode: 570/1000, epsilon: 0.0048, score: 199
# Episode: 571/1000, epsilon: 0.0048, score: 199
# Episode: 572/1000, epsilon: 0.0048, score: 199
# Episode: 573/1000, epsilon: 0.0048, score: 116
# Episode: 574/1000, epsilon: 0.0048, score: 199
# Episode: 575/1000, epsilon: 0.0048, score: 199
# Episode: 576/1000, epsilon: 0.0048, score: 199
# Episode: 577/1000, epsilon: 0.0048, score: 199
# Episode: 578/1000, epsilon: 0.0048, score: 199
# Episode: 579/1000, epsilon: 0.0048, score: 199
# Episode: 580/1000, epsilon: 0.0048, score: 199
# Episode: 581/1000, epsilon: 0.0048, score: 199
# Episode: 582/1000, epsilon: 0.0048, score: 199
# Episode: 583/1000, epsilon: 0.0048, score: 199
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f7965de3dc92> in <module>()
#      63                 else:
#      64                     aNet = net.predict(state_newMb)[0]
# ---> 65                     tNet = netTarget.predict(state_newMb)[0]
#      66                     target_f[0][actionMb] = rewardMb + gamma * tNet[np.argmax(aNet)]
#      67
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     911         if not self.built:
#     912             self.build()
# --> 913         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     914
#     915     def predict_on_batch(self, x):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1711         f = self.predict_function
#    1712         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1713                                   verbose=verbose, steps=steps)
#    1714
#    1715     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1267                 else:
#    1268                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1269                 batch_outs = f(ins_batch)
#    1270                 if not isinstance(batch_outs, list):
#    1271                     batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2268                 value = (indices, sparse_coo.data, sparse_coo.shape)
#    2269             feed_dict[tensor] = value
# -> 2270         session = get_session()
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in get_session()
#     164         session = _SESSION
#     165     if not _MANUAL_VAR_INIT:
# --> 166         with session.graph.as_default():
#     167             _initialize_variables()
#     168     return session
#
# KeyboardInterrupt:

# %% [markdown]
# # Výsledky

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import copy

score1 = copy.copy(scores)
score2 = copy.copy(scores)
score3 = copy.copy(scores)

for i in range (len(scores)):
    if i > 1 and i < (len(scores)-2):
        score1[i] = (scores[i - 2] + scores[i - 1] + scores[i] + scores[i + 1] + scores[i + 2])/5
        
for i in range (len(scores)):
    if i > 4 and i < (len(scores)-5):
        score2[i] += scores[i - 5] + scores[i - 4] + scores[i - 3] + scores[i - 2] + scores[i - 1]
        score2[i] += scores[i + 5] + scores[i + 4] + scores[i + 3] + scores[i + 2] + scores[i + 1]
        score2[i] = score2[i]/11

for i in range (len(scores)):
    if i > 49 and i < (len(scores) - 50):
        for e in range (1,50):
            score3[i] += scores[i - e] + scores[i + e] 
        score3[i] = score3[i]/101      

plt.plot(episodesList, scores, 'ro')
plt.ylabel("Score")
plt.xlabel("Episodes")
plt.title("Vysledky")
plt.show()

plt.plot(scores)
plt.ylabel("Score")
plt.xlabel("Episodes")
plt.title("Funkce interpolace vysledku")
plt.show()

plt.plot(score1)
plt.ylabel("Score")
plt.xlabel("Episodes")
plt.title("Funkce interpolace vysledku (filtr - prumer 5-ti prvku)")
plt.show()

plt.plot(score2)
plt.ylabel("Score")
plt.xlabel("Episodes")
plt.title("Funkce interpolace vysledku  (filtr - prumer 11-cti prvku)")
plt.show()

plt.plot(score3)
plt.ylabel("Score")
plt.xlabel("Episodes")
plt.title("Funkce interpolace vysledku  (filtr - prumer 101 prvku)")
plt.show()

saveDQN(net, "./DQN-CartPole-v0.h5")

# %% [markdown]
# # Hra

# %%
netForPlay = getDQN(actionCount, stateSize)
loadDQN(netForPlay, "./DQN-CartPole-v0.h5")
observation = env.reset()

for i in range (100):
    state = env.reset()
    state = np.reshape(state, [1, stateSize])
    
    total_reward = 0
    done = False
    
    while not done:
        #env.render()
        Q = netForPlay.predict(state)   
        action = np.argmax(Q)  
        observation_new, reward, done, info = env.step(int(action))

        next_state = np.reshape(observation_new, [1, stateSize])
        state = next_state

        total_reward += reward

    print('{}. Game - score: {}'.format(i, total_reward))
