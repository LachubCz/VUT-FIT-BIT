# %% [markdown]
# # Inicializace

# %%
from collections import deque                # Trida pro ukladani stavu
from __future__ import division              # Deleni realnych cisel (kvuli verzi Pythonu 2.6)

import numpy as np                           # Knihovna pro matematicke operace
import random                                # Knihovna pro nahodny vyber samplu z pameti
import sys                                   # Pro pripojeni knihovny Open AI Gym
sys.path.append('/home/xbucha02/libraries')  # Pripojeni knihovny Open AI Gym
import gym                                   # Knihovna Open AI Gym
#from gym import wrappers                    # Nahravani zaznamu
env = gym.make('CartPole-v0')             # Konkretni hra z Open AI Gym
actionCount = env.action_space.n             # Pocet vstupu do prostredi
stateSize = env.observation_space.shape[0]   # Pocet vystupu z prostredi
#env = wrappers.Monitor(env, '/home/lachubcz/tmp/cartpole-experiment-1', force=True) #Nahravani zaznamu

gpuMemoryUsage=1.2                            # Vyuziti pameti GPU
import tensorflow as tf                     # Knihovna TensorFlow
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = gpuMemoryUsage
set_session(tf.Session(config=config))

# Parametry
observetime = 500                          # Delka pozorovani
episodes = 1500                            # Pocet epizod
games = 100                                # Pocet her
trainingAfterSucces = 100                  # Pocet trenovani na uspesnem datasetu
scores = []                                # Pole pro ulozeni vysledku na analyzu
episodesList = []                          # Pole pro ulozeni cisel epizod na analyzu
bestScore = 0                              # Promenna pro ukladani nejlepsiho prubezneho vysledku

# %% [markdown]
# # Agent

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import regularizers
from keras import optimizers
from keras import losses
from keras import metrics

class Agent:
    def __init__(self, env):
        self.startEpsilon = 1                           # Pravdepodobnost konani nahodneho tahu na zacatku
        self.endEpsilon = 0.01                          # Pravdepodobnost konani nahodneho tahu na konci
        self.currentEpsilon = self.startEpsilon         # Soucasna pravdepodobnost konani nahodneho tahu
        self.epsilonDiminution = 0.995                  # Hodnota snizovani epsilonu
        self.gamma = 0.95                               # Discount faktor
        self.minibatchSize = 32                         # Velikost minibatche
        self.actionCount = env.action_space.n           # Pocet vstupu do prostredi
        self.stateSize = env.observation_space.shape[0] # Pocet vystupu z prostredi
        self.learningRate = 0.005                       # Learning rate
        self.fractionUpdate = 0.125
        self.memorySize = 2000                          # Velikost Replay memory
        self.primaryMemory = deque(maxlen=self.memorySize)
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
        self.net = self.getNN(env)
        self.netTarget = self.getNN(env)
        self.updateTargetNet()

    def getNN(self, env):
        net = Sequential()
        net.add(Dense(32, activation="relu", input_shape=(4,) + env.observation_space.shape ))
        net.add(Flatten())
        net.add(Dense(16, activation="relu"))
        
        net.add(Dense(self.actionCount, activation="linear"))

        net.summary()

        net.compile(loss=losses.mean_squared_error, optimizer=optimizers.Adam(lr=self.learningRate), metrics=['accuracy'])

        return net
    
    def updateTargetNet(self):
        self.netTarget.set_weights(self.net.get_weights())
    
    def updateTargetNetPartially(self):
        weights = self.net.get_weights()
        weightsTarget = self.netTarget.get_weights()
        
        for i in range(len(weightsTarget)):
            weightsTarget[i] = weights[i] * self.fractionUpdate + weightsTarget[i] * (1 - self.fractionUpdate)
            
        self.netTarget.set_weights(weightsTarget)
        
    def rememberPrimMem(self, state, action, reward, nextState, done):
        self.primaryMemory.append((state, action, reward, nextState, done))
    
    def rememberSecMem(self, state, action, reward, nextState, done):
        self.secondaryMemory.append((state, action, reward, nextState, done))
        
    def clearSecMem(self):
        self.secondaryMemory.clear()
        
    def epsilonActulization(self):
        if self.currentEpsilon > self.endEpsilon:
            if (self.currentEpsilon * self.epsilonDiminution) > self.endEpsilon:
                self.currentEpsilon = self.currentEpsilon * self.epsilonDiminution
            else:
                self.currentEpsilon = self.endEpsilon
    
    def getActionWE(self, state):
        if np.random.rand() <= self.currentEpsilon:
            return np.random.randint(0, self.actionCount, size=1)[0]
        else:
            Q = self.net.predict(state)
            return np.argmax(Q)

    def getAction(self, state):
        Q = self.net.predict(state)
        return np.argmax(Q)
    
    def resetSecMem(self):
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
    def resetEpsilon(self):
        self.currentEpsilon = self.startEpsilon
    
    def trainDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize)
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize)
            else:
                return
        else:
            return

        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]

            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]

                target_f[0][action] = reward + self.gamma * np.max(aNet)

            self.net.fit(state, target_f, epochs=1, verbose=0)
                
    def trainDDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        else:
            return
        
        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]
            
            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]
                tNet = self.netTarget.predict(nextState)[0]
                target_f[0][action] = reward + self.gamma * tNet[np.argmax(aNet)]
            
            self.net.fit(state, target_f, epochs=1, verbose=0)
    
    def loadNN(self, name):
        self.net.load_weights(name)

    def saveNN(self, name):
        self.net.save_weights(name)

# %% [markdown]
# # Algoritmus

# %%
import copy
agent = Agent(env) #vytvoreni agenta
    
#agent.loadNN("./DDQN-MountainCar-v0.h5") #nacteni NN
#agent.updateTargetNet() #nacteni NN do netTarget

for eps in range (episodes):
    state = env.reset() #resetovani prostredi
    state = np.reshape(state, [1, stateSize]) #formatovani

    state1 = copy.copy(state)
    state2 = copy.copy(state)
    state3 = copy.copy(state)
    
    state = np.concatenate((state, state1))
    state = np.concatenate((state, state2))
    state = np.concatenate((state, state3))

    state = np.expand_dims(state, axis=0)
    
    agent.epsilonActulization() #aktualizace epsilon
    
    #env.render()

    for t in range(observetime):

        action = agent.getActionWE(state) #ziskani akce

        newState, reward, done, info = env.step(action) #provedeni akce
        
        nextState = np.reshape(newState, [1, stateSize]) #formatovani
        
        temp = copy.copy(nextState)
        
        nextState = np.concatenate((nextState, state1))
        nextState = np.concatenate((nextState, state2))
        nextState = np.concatenate((nextState, state3))
        
        state3 = copy.copy(state2)
        state2 = copy.copy(state1)
        state1 = copy.copy(temp)
        
        nextState = np.expand_dims(nextState, axis=0)
        
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do primarni pameti
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do sekundarni pameti
        
        #agent.trainDDQN(1) #trenovani na primarni pameti
        
        state = nextState #zmena stavu
        
        if done: #konec epizody
            print("Episode: {}/{}, epsilon: {:.2}, score: {}".format(eps, episodes, agent.currentEpsilon, t))
            agent.trainDQN(1)
            scores.append(t) #ulozeni aktualniho skore
            episodesList.append(eps) #ulozeni aktualniho cisla epizody
            
            #agent.updateTargetNet() #aktualizace target site
            
            if t > bestScore: #bylo dosazeno njelepsiho skore
                bestScore = t #nove nejlepsi skore
            #    for i in range(trainingAfterSucces): #pocet trenovani
            #        agent.trainDDQN(2) #trenovani na sekundarni pameti
                agent.saveNN("./DDQN-CartPole-v0-{}.h5" .format(eps)) #ulozeni site
            #    #agent.resetEpsilon() #resetovani epsilonu
            
            #agent.resetSecMem() #vycisteni sekundarni pameti
            
            break
            
agent.saveNN("./DDQN-CartPole-v0.h5") #ulozeni site
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 4, 32)             160
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dense_45 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 2,258.0
# Trainable params: 2,258.0
# Non-trainable params: 0.0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 4, 32)             160
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dense_48 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 2,258.0
# Trainable params: 2,258.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Episode: 0/1500, epsilon: 0.99, score: 20
# Episode: 1/1500, epsilon: 0.99, score: 17
# Episode: 2/1500, epsilon: 0.99, score: 16
# Episode: 3/1500, epsilon: 0.98, score: 19
# Episode: 4/1500, epsilon: 0.98, score: 17
# Episode: 5/1500, epsilon: 0.97, score: 22
# Episode: 6/1500, epsilon: 0.97, score: 15
# Episode: 7/1500, epsilon: 0.96, score: 43
# Episode: 8/1500, epsilon: 0.96, score: 10
# Episode: 9/1500, epsilon: 0.95, score: 67
# Episode: 10/1500, epsilon: 0.95, score: 20
# Episode: 11/1500, epsilon: 0.94, score: 13
# Episode: 12/1500, epsilon: 0.94, score: 13
# Episode: 13/1500, epsilon: 0.93, score: 125
# Episode: 14/1500, epsilon: 0.93, score: 16
# Episode: 15/1500, epsilon: 0.92, score: 10
# Episode: 16/1500, epsilon: 0.92, score: 10
# Episode: 17/1500, epsilon: 0.91, score: 10
# Episode: 18/1500, epsilon: 0.91, score: 20
# Episode: 19/1500, epsilon: 0.9, score: 12
# Episode: 20/1500, epsilon: 0.9, score: 18
# Episode: 21/1500, epsilon: 0.9, score: 15
# Episode: 22/1500, epsilon: 0.89, score: 11
# Episode: 23/1500, epsilon: 0.89, score: 9
# Episode: 24/1500, epsilon: 0.88, score: 42
# Episode: 25/1500, epsilon: 0.88, score: 27
# Episode: 26/1500, epsilon: 0.87, score: 23
# Episode: 27/1500, epsilon: 0.87, score: 26
# Episode: 28/1500, epsilon: 0.86, score: 15
# Episode: 29/1500, epsilon: 0.86, score: 47
# Episode: 30/1500, epsilon: 0.86, score: 28
# Episode: 31/1500, epsilon: 0.85, score: 21
# Episode: 32/1500, epsilon: 0.85, score: 33
# Episode: 33/1500, epsilon: 0.84, score: 12
# Episode: 34/1500, epsilon: 0.84, score: 11
# Episode: 35/1500, epsilon: 0.83, score: 35
# Episode: 36/1500, epsilon: 0.83, score: 15
# Episode: 37/1500, epsilon: 0.83, score: 12
# Episode: 38/1500, epsilon: 0.82, score: 19
# Episode: 39/1500, epsilon: 0.82, score: 18
# Episode: 40/1500, epsilon: 0.81, score: 9
# Episode: 41/1500, epsilon: 0.81, score: 10
# Episode: 42/1500, epsilon: 0.81, score: 11
# Episode: 43/1500, epsilon: 0.8, score: 21
# Episode: 44/1500, epsilon: 0.8, score: 10
# Episode: 45/1500, epsilon: 0.79, score: 14
# Episode: 46/1500, epsilon: 0.79, score: 17
# Episode: 47/1500, epsilon: 0.79, score: 14
# Episode: 48/1500, epsilon: 0.78, score: 15
# Episode: 49/1500, epsilon: 0.78, score: 17
# Episode: 50/1500, epsilon: 0.77, score: 24
# Episode: 51/1500, epsilon: 0.77, score: 13
# Episode: 52/1500, epsilon: 0.77, score: 16
# Episode: 53/1500, epsilon: 0.76, score: 11
# Episode: 54/1500, epsilon: 0.76, score: 15
# Episode: 55/1500, epsilon: 0.76, score: 30
# Episode: 56/1500, epsilon: 0.75, score: 10
# Episode: 57/1500, epsilon: 0.75, score: 13
# Episode: 58/1500, epsilon: 0.74, score: 31
# Episode: 59/1500, epsilon: 0.74, score: 16
# Episode: 60/1500, epsilon: 0.74, score: 17
# Episode: 61/1500, epsilon: 0.73, score: 23
# Episode: 62/1500, epsilon: 0.73, score: 20
# Episode: 63/1500, epsilon: 0.73, score: 13
# Episode: 64/1500, epsilon: 0.72, score: 20
# Episode: 65/1500, epsilon: 0.72, score: 14
# Episode: 66/1500, epsilon: 0.71, score: 46
# Episode: 67/1500, epsilon: 0.71, score: 14
# Episode: 68/1500, epsilon: 0.71, score: 10
# Episode: 69/1500, epsilon: 0.7, score: 16
# Episode: 70/1500, epsilon: 0.7, score: 31
# Episode: 71/1500, epsilon: 0.7, score: 11
# Episode: 72/1500, epsilon: 0.69, score: 20
# Episode: 73/1500, epsilon: 0.69, score: 13
# Episode: 74/1500, epsilon: 0.69, score: 24
# Episode: 75/1500, epsilon: 0.68, score: 14
# Episode: 76/1500, epsilon: 0.68, score: 10
# Episode: 77/1500, epsilon: 0.68, score: 11
# Episode: 78/1500, epsilon: 0.67, score: 16
# Episode: 79/1500, epsilon: 0.67, score: 24
# Episode: 80/1500, epsilon: 0.67, score: 15
# Episode: 81/1500, epsilon: 0.66, score: 20
# Episode: 82/1500, epsilon: 0.66, score: 18
# Episode: 83/1500, epsilon: 0.66, score: 15
# Episode: 84/1500, epsilon: 0.65, score: 9
# Episode: 85/1500, epsilon: 0.65, score: 9
# Episode: 86/1500, epsilon: 0.65, score: 10
# Episode: 87/1500, epsilon: 0.64, score: 8
# Episode: 88/1500, epsilon: 0.64, score: 21
# Episode: 89/1500, epsilon: 0.64, score: 11
# Episode: 90/1500, epsilon: 0.63, score: 11
# Episode: 91/1500, epsilon: 0.63, score: 13
# Episode: 92/1500, epsilon: 0.63, score: 29
# Episode: 93/1500, epsilon: 0.62, score: 48
# Episode: 94/1500, epsilon: 0.62, score: 18
# Episode: 95/1500, epsilon: 0.62, score: 35
# Episode: 96/1500, epsilon: 0.61, score: 13
# Episode: 97/1500, epsilon: 0.61, score: 14
# Episode: 98/1500, epsilon: 0.61, score: 12
# Episode: 99/1500, epsilon: 0.61, score: 8
# Episode: 100/1500, epsilon: 0.6, score: 18
# Episode: 101/1500, epsilon: 0.6, score: 18
# Episode: 102/1500, epsilon: 0.6, score: 10
# Episode: 103/1500, epsilon: 0.59, score: 14
# Episode: 104/1500, epsilon: 0.59, score: 60
# Episode: 105/1500, epsilon: 0.59, score: 33
# Episode: 106/1500, epsilon: 0.58, score: 24
# Episode: 107/1500, epsilon: 0.58, score: 15
# Episode: 108/1500, epsilon: 0.58, score: 9
# Episode: 109/1500, epsilon: 0.58, score: 13
# Episode: 110/1500, epsilon: 0.57, score: 13
# Episode: 111/1500, epsilon: 0.57, score: 21
# Episode: 112/1500, epsilon: 0.57, score: 12
# Episode: 113/1500, epsilon: 0.56, score: 20
# Episode: 114/1500, epsilon: 0.56, score: 10
# Episode: 115/1500, epsilon: 0.56, score: 13
# Episode: 116/1500, epsilon: 0.56, score: 19
# Episode: 117/1500, epsilon: 0.55, score: 11
# Episode: 118/1500, epsilon: 0.55, score: 26
# Episode: 119/1500, epsilon: 0.55, score: 15
# Episode: 120/1500, epsilon: 0.55, score: 18
# Episode: 121/1500, epsilon: 0.54, score: 19
# Episode: 122/1500, epsilon: 0.54, score: 36
# Episode: 123/1500, epsilon: 0.54, score: 95
# Episode: 124/1500, epsilon: 0.53, score: 16
# Episode: 125/1500, epsilon: 0.53, score: 21
# Episode: 126/1500, epsilon: 0.53, score: 24
# Episode: 127/1500, epsilon: 0.53, score: 16
# Episode: 128/1500, epsilon: 0.52, score: 18
# Episode: 129/1500, epsilon: 0.52, score: 48
# Episode: 130/1500, epsilon: 0.52, score: 15
# Episode: 131/1500, epsilon: 0.52, score: 15
# Episode: 132/1500, epsilon: 0.51, score: 19
# Episode: 133/1500, epsilon: 0.51, score: 37
# Episode: 134/1500, epsilon: 0.51, score: 24
# Episode: 135/1500, epsilon: 0.51, score: 41
# Episode: 136/1500, epsilon: 0.5, score: 26
# Episode: 137/1500, epsilon: 0.5, score: 21
# Episode: 138/1500, epsilon: 0.5, score: 12
# Episode: 139/1500, epsilon: 0.5, score: 45
# Episode: 140/1500, epsilon: 0.49, score: 34
# Episode: 141/1500, epsilon: 0.49, score: 33
# Episode: 142/1500, epsilon: 0.49, score: 13
# Episode: 143/1500, epsilon: 0.49, score: 18
# Episode: 144/1500, epsilon: 0.48, score: 65
# Episode: 145/1500, epsilon: 0.48, score: 51
# Episode: 146/1500, epsilon: 0.48, score: 27
# Episode: 147/1500, epsilon: 0.48, score: 26
# Episode: 148/1500, epsilon: 0.47, score: 19
# Episode: 149/1500, epsilon: 0.47, score: 45
# Episode: 150/1500, epsilon: 0.47, score: 8
# Episode: 151/1500, epsilon: 0.47, score: 60
# Episode: 152/1500, epsilon: 0.46, score: 15
# Episode: 153/1500, epsilon: 0.46, score: 22
# Episode: 154/1500, epsilon: 0.46, score: 49
# Episode: 155/1500, epsilon: 0.46, score: 43
# Episode: 156/1500, epsilon: 0.46, score: 15
# Episode: 157/1500, epsilon: 0.45, score: 19
# Episode: 158/1500, epsilon: 0.45, score: 12
# Episode: 159/1500, epsilon: 0.45, score: 21
# Episode: 160/1500, epsilon: 0.45, score: 14
# Episode: 161/1500, epsilon: 0.44, score: 41
# Episode: 162/1500, epsilon: 0.44, score: 38
# Episode: 163/1500, epsilon: 0.44, score: 19
# Episode: 164/1500, epsilon: 0.44, score: 39
# Episode: 165/1500, epsilon: 0.44, score: 19
# Episode: 166/1500, epsilon: 0.43, score: 26
# Episode: 167/1500, epsilon: 0.43, score: 30
# Episode: 168/1500, epsilon: 0.43, score: 24
# Episode: 169/1500, epsilon: 0.43, score: 84
# Episode: 170/1500, epsilon: 0.42, score: 14
# Episode: 171/1500, epsilon: 0.42, score: 32
# Episode: 172/1500, epsilon: 0.42, score: 33
# Episode: 173/1500, epsilon: 0.42, score: 66
# Episode: 174/1500, epsilon: 0.42, score: 11
# Episode: 175/1500, epsilon: 0.41, score: 25
# Episode: 176/1500, epsilon: 0.41, score: 91
# Episode: 177/1500, epsilon: 0.41, score: 21
# Episode: 178/1500, epsilon: 0.41, score: 16
# Episode: 179/1500, epsilon: 0.41, score: 47
# Episode: 180/1500, epsilon: 0.4, score: 10
# Episode: 181/1500, epsilon: 0.4, score: 34
# Episode: 182/1500, epsilon: 0.4, score: 24
# Episode: 183/1500, epsilon: 0.4, score: 27
# Episode: 184/1500, epsilon: 0.4, score: 31
# Episode: 185/1500, epsilon: 0.39, score: 36
# Episode: 186/1500, epsilon: 0.39, score: 18
# Episode: 187/1500, epsilon: 0.39, score: 82
# Episode: 188/1500, epsilon: 0.39, score: 61
# Episode: 189/1500, epsilon: 0.39, score: 20
# Episode: 190/1500, epsilon: 0.38, score: 22
# Episode: 191/1500, epsilon: 0.38, score: 10
# Episode: 192/1500, epsilon: 0.38, score: 14
# Episode: 193/1500, epsilon: 0.38, score: 26
# Episode: 194/1500, epsilon: 0.38, score: 125
# Episode: 195/1500, epsilon: 0.37, score: 16
# Episode: 196/1500, epsilon: 0.37, score: 30
# Episode: 197/1500, epsilon: 0.37, score: 69
# Episode: 198/1500, epsilon: 0.37, score: 45
# Episode: 199/1500, epsilon: 0.37, score: 20
# Episode: 200/1500, epsilon: 0.37, score: 39
# Episode: 201/1500, epsilon: 0.36, score: 22
# Episode: 202/1500, epsilon: 0.36, score: 72
# Episode: 203/1500, epsilon: 0.36, score: 21
# Episode: 204/1500, epsilon: 0.36, score: 71
# Episode: 205/1500, epsilon: 0.36, score: 43
# Episode: 206/1500, epsilon: 0.35, score: 18
# Episode: 207/1500, epsilon: 0.35, score: 15
# Episode: 208/1500, epsilon: 0.35, score: 80
# Episode: 209/1500, epsilon: 0.35, score: 98
# Episode: 210/1500, epsilon: 0.35, score: 31
# Episode: 211/1500, epsilon: 0.35, score: 44
# Episode: 212/1500, epsilon: 0.34, score: 74
# Episode: 213/1500, epsilon: 0.34, score: 21
# Episode: 214/1500, epsilon: 0.34, score: 42
# Episode: 215/1500, epsilon: 0.34, score: 21
# Episode: 216/1500, epsilon: 0.34, score: 25
# Episode: 217/1500, epsilon: 0.34, score: 65
# Episode: 218/1500, epsilon: 0.33, score: 123
# Episode: 219/1500, epsilon: 0.33, score: 16
# Episode: 220/1500, epsilon: 0.33, score: 134
# Episode: 221/1500, epsilon: 0.33, score: 42
# Episode: 222/1500, epsilon: 0.33, score: 22
# Episode: 223/1500, epsilon: 0.33, score: 136
# Episode: 224/1500, epsilon: 0.32, score: 27
# Episode: 225/1500, epsilon: 0.32, score: 13
# Episode: 226/1500, epsilon: 0.32, score: 10
# Episode: 227/1500, epsilon: 0.32, score: 30
# Episode: 228/1500, epsilon: 0.32, score: 22
# Episode: 229/1500, epsilon: 0.32, score: 104
# Episode: 230/1500, epsilon: 0.31, score: 12
# Episode: 231/1500, epsilon: 0.31, score: 32
# Episode: 232/1500, epsilon: 0.31, score: 11
# Episode: 233/1500, epsilon: 0.31, score: 14
# Episode: 234/1500, epsilon: 0.31, score: 17
# Episode: 235/1500, epsilon: 0.31, score: 26
# Episode: 236/1500, epsilon: 0.3, score: 29
# Episode: 237/1500, epsilon: 0.3, score: 16
# Episode: 238/1500, epsilon: 0.3, score: 24
# Episode: 239/1500, epsilon: 0.3, score: 65
# Episode: 240/1500, epsilon: 0.3, score: 54
# Episode: 241/1500, epsilon: 0.3, score: 60
# Episode: 242/1500, epsilon: 0.3, score: 167
# Episode: 243/1500, epsilon: 0.29, score: 32
# Episode: 244/1500, epsilon: 0.29, score: 133
# Episode: 245/1500, epsilon: 0.29, score: 45
# Episode: 246/1500, epsilon: 0.29, score: 42
# Episode: 247/1500, epsilon: 0.29, score: 199
# Episode: 248/1500, epsilon: 0.29, score: 68
# Episode: 249/1500, epsilon: 0.29, score: 146
# Episode: 250/1500, epsilon: 0.28, score: 145
# Episode: 251/1500, epsilon: 0.28, score: 39
# Episode: 252/1500, epsilon: 0.28, score: 85
# Episode: 253/1500, epsilon: 0.28, score: 199
# Episode: 254/1500, epsilon: 0.28, score: 153
# Episode: 255/1500, epsilon: 0.28, score: 134
# Episode: 256/1500, epsilon: 0.28, score: 199
# Episode: 257/1500, epsilon: 0.27, score: 199
# Episode: 258/1500, epsilon: 0.27, score: 12
# Episode: 259/1500, epsilon: 0.27, score: 174
# Episode: 260/1500, epsilon: 0.27, score: 199
# Episode: 261/1500, epsilon: 0.27, score: 109
# Episode: 262/1500, epsilon: 0.27, score: 151
# Episode: 263/1500, epsilon: 0.27, score: 99
# Episode: 264/1500, epsilon: 0.26, score: 199
# Episode: 265/1500, epsilon: 0.26, score: 12
# Episode: 266/1500, epsilon: 0.26, score: 199
# Episode: 267/1500, epsilon: 0.26, score: 24
# Episode: 268/1500, epsilon: 0.26, score: 156
# Episode: 269/1500, epsilon: 0.26, score: 154
# Episode: 270/1500, epsilon: 0.26, score: 199
# Episode: 271/1500, epsilon: 0.26, score: 150
# Episode: 272/1500, epsilon: 0.25, score: 117
# Episode: 273/1500, epsilon: 0.25, score: 164
# Episode: 274/1500, epsilon: 0.25, score: 199
# Episode: 275/1500, epsilon: 0.25, score: 139
# Episode: 276/1500, epsilon: 0.25, score: 199
# Episode: 277/1500, epsilon: 0.25, score: 199
# Episode: 278/1500, epsilon: 0.25, score: 37
# Episode: 279/1500, epsilon: 0.25, score: 106
# Episode: 280/1500, epsilon: 0.24, score: 138
# Episode: 281/1500, epsilon: 0.24, score: 199
# Episode: 282/1500, epsilon: 0.24, score: 199
# Episode: 283/1500, epsilon: 0.24, score: 152
# Episode: 284/1500, epsilon: 0.24, score: 16
# Episode: 285/1500, epsilon: 0.24, score: 33
# Episode: 286/1500, epsilon: 0.24, score: 199
# Episode: 287/1500, epsilon: 0.24, score: 106
# Episode: 288/1500, epsilon: 0.23, score: 25
# Episode: 289/1500, epsilon: 0.23, score: 145
# Episode: 290/1500, epsilon: 0.23, score: 119
# Episode: 291/1500, epsilon: 0.23, score: 105
# Episode: 292/1500, epsilon: 0.23, score: 125
# Episode: 293/1500, epsilon: 0.23, score: 15
# Episode: 294/1500, epsilon: 0.23, score: 131
# Episode: 295/1500, epsilon: 0.23, score: 150
# Episode: 296/1500, epsilon: 0.23, score: 113
# Episode: 297/1500, epsilon: 0.22, score: 121
# Episode: 298/1500, epsilon: 0.22, score: 175
# Episode: 299/1500, epsilon: 0.22, score: 199
# Episode: 300/1500, epsilon: 0.22, score: 199
# Episode: 301/1500, epsilon: 0.22, score: 188
# Episode: 302/1500, epsilon: 0.22, score: 166
# Episode: 303/1500, epsilon: 0.22, score: 181
# Episode: 304/1500, epsilon: 0.22, score: 29
# Episode: 305/1500, epsilon: 0.22, score: 199
# Episode: 306/1500, epsilon: 0.21, score: 195
# Episode: 307/1500, epsilon: 0.21, score: 152
# Episode: 308/1500, epsilon: 0.21, score: 169
# Episode: 309/1500, epsilon: 0.21, score: 15
# Episode: 310/1500, epsilon: 0.21, score: 199
# Episode: 311/1500, epsilon: 0.21, score: 141
# Episode: 312/1500, epsilon: 0.21, score: 25
# Episode: 313/1500, epsilon: 0.21, score: 151
# Episode: 314/1500, epsilon: 0.21, score: 125
# Episode: 315/1500, epsilon: 0.21, score: 17
# Episode: 316/1500, epsilon: 0.2, score: 140
# Episode: 317/1500, epsilon: 0.2, score: 20
# Episode: 318/1500, epsilon: 0.2, score: 133
# Episode: 319/1500, epsilon: 0.2, score: 118
# Episode: 320/1500, epsilon: 0.2, score: 148
# Episode: 321/1500, epsilon: 0.2, score: 134
# Episode: 322/1500, epsilon: 0.2, score: 101
# Episode: 323/1500, epsilon: 0.2, score: 118
# Episode: 324/1500, epsilon: 0.2, score: 127
# Episode: 325/1500, epsilon: 0.2, score: 121
# Episode: 326/1500, epsilon: 0.19, score: 10
# Episode: 327/1500, epsilon: 0.19, score: 111
# Episode: 328/1500, epsilon: 0.19, score: 199
# Episode: 329/1500, epsilon: 0.19, score: 143
# Episode: 330/1500, epsilon: 0.19, score: 198
# Episode: 331/1500, epsilon: 0.19, score: 180
# Episode: 332/1500, epsilon: 0.19, score: 128
# Episode: 333/1500, epsilon: 0.19, score: 113
# Episode: 334/1500, epsilon: 0.19, score: 174
# Episode: 335/1500, epsilon: 0.19, score: 150
# Episode: 336/1500, epsilon: 0.18, score: 199
# Episode: 337/1500, epsilon: 0.18, score: 172
# Episode: 338/1500, epsilon: 0.18, score: 110
# Episode: 339/1500, epsilon: 0.18, score: 108
# Episode: 340/1500, epsilon: 0.18, score: 101
# Episode: 341/1500, epsilon: 0.18, score: 90
# Episode: 342/1500, epsilon: 0.18, score: 135
# Episode: 343/1500, epsilon: 0.18, score: 107
# Episode: 344/1500, epsilon: 0.18, score: 125
# Episode: 345/1500, epsilon: 0.18, score: 118
# Episode: 346/1500, epsilon: 0.18, score: 139
# Episode: 347/1500, epsilon: 0.17, score: 140
# Episode: 348/1500, epsilon: 0.17, score: 130
# Episode: 349/1500, epsilon: 0.17, score: 82
# Episode: 350/1500, epsilon: 0.17, score: 105
# Episode: 351/1500, epsilon: 0.17, score: 135
# Episode: 352/1500, epsilon: 0.17, score: 199
# Episode: 353/1500, epsilon: 0.17, score: 199
# Episode: 354/1500, epsilon: 0.17, score: 177
# Episode: 355/1500, epsilon: 0.17, score: 23
# Episode: 356/1500, epsilon: 0.17, score: 121
# Episode: 357/1500, epsilon: 0.17, score: 123
# Episode: 358/1500, epsilon: 0.17, score: 193
# Episode: 359/1500, epsilon: 0.16, score: 115
# Episode: 360/1500, epsilon: 0.16, score: 156
# Episode: 361/1500, epsilon: 0.16, score: 41
# Episode: 362/1500, epsilon: 0.16, score: 158
# Episode: 363/1500, epsilon: 0.16, score: 126
# Episode: 364/1500, epsilon: 0.16, score: 142
# Episode: 365/1500, epsilon: 0.16, score: 170
# Episode: 366/1500, epsilon: 0.16, score: 134
# Episode: 367/1500, epsilon: 0.16, score: 199
# Episode: 368/1500, epsilon: 0.16, score: 150
# Episode: 369/1500, epsilon: 0.16, score: 111
# Episode: 370/1500, epsilon: 0.16, score: 108
# Episode: 371/1500, epsilon: 0.15, score: 142
# Episode: 372/1500, epsilon: 0.15, score: 127
# Episode: 373/1500, epsilon: 0.15, score: 113
# Episode: 374/1500, epsilon: 0.15, score: 142
# Episode: 375/1500, epsilon: 0.15, score: 199
# Episode: 376/1500, epsilon: 0.15, score: 103
# Episode: 377/1500, epsilon: 0.15, score: 133
# Episode: 378/1500, epsilon: 0.15, score: 155
# Episode: 379/1500, epsilon: 0.15, score: 155
# Episode: 380/1500, epsilon: 0.15, score: 111
# Episode: 381/1500, epsilon: 0.15, score: 119
# Episode: 382/1500, epsilon: 0.15, score: 171
# Episode: 383/1500, epsilon: 0.15, score: 136
# Episode: 384/1500, epsilon: 0.15, score: 120
# Episode: 385/1500, epsilon: 0.14, score: 8
# Episode: 386/1500, epsilon: 0.14, score: 149
# Episode: 387/1500, epsilon: 0.14, score: 139
# Episode: 388/1500, epsilon: 0.14, score: 139
# Episode: 389/1500, epsilon: 0.14, score: 134
# Episode: 390/1500, epsilon: 0.14, score: 199
# Episode: 391/1500, epsilon: 0.14, score: 154
# Episode: 392/1500, epsilon: 0.14, score: 164
# Episode: 393/1500, epsilon: 0.14, score: 199
# Episode: 394/1500, epsilon: 0.14, score: 146
# Episode: 395/1500, epsilon: 0.14, score: 194
# Episode: 396/1500, epsilon: 0.14, score: 159
# Episode: 397/1500, epsilon: 0.14, score: 11
# Episode: 398/1500, epsilon: 0.14, score: 172
# Episode: 399/1500, epsilon: 0.13, score: 8
# Episode: 400/1500, epsilon: 0.13, score: 12
# Episode: 401/1500, epsilon: 0.13, score: 37
# Episode: 402/1500, epsilon: 0.13, score: 142
# Episode: 403/1500, epsilon: 0.13, score: 105
# Episode: 404/1500, epsilon: 0.13, score: 28
# Episode: 405/1500, epsilon: 0.13, score: 24
# Episode: 406/1500, epsilon: 0.13, score: 15
# Episode: 407/1500, epsilon: 0.13, score: 77
# Episode: 408/1500, epsilon: 0.13, score: 107
# Episode: 409/1500, epsilon: 0.13, score: 8
# Episode: 410/1500, epsilon: 0.13, score: 16
# Episode: 411/1500, epsilon: 0.13, score: 114
# Episode: 412/1500, epsilon: 0.13, score: 133
# Episode: 413/1500, epsilon: 0.13, score: 156
# Episode: 414/1500, epsilon: 0.12, score: 199
# Episode: 415/1500, epsilon: 0.12, score: 19
# Episode: 416/1500, epsilon: 0.12, score: 38
# Episode: 417/1500, epsilon: 0.12, score: 162
# Episode: 418/1500, epsilon: 0.12, score: 19
# Episode: 419/1500, epsilon: 0.12, score: 95
# Episode: 420/1500, epsilon: 0.12, score: 116
# Episode: 421/1500, epsilon: 0.12, score: 158
# Episode: 422/1500, epsilon: 0.12, score: 140
# Episode: 423/1500, epsilon: 0.12, score: 160
# Episode: 424/1500, epsilon: 0.12, score: 43
# Episode: 425/1500, epsilon: 0.12, score: 16
# Episode: 426/1500, epsilon: 0.12, score: 113
# Episode: 427/1500, epsilon: 0.12, score: 96
# Episode: 428/1500, epsilon: 0.12, score: 59
# Episode: 429/1500, epsilon: 0.12, score: 162
# Episode: 430/1500, epsilon: 0.12, score: 141
# Episode: 431/1500, epsilon: 0.11, score: 126
# Episode: 432/1500, epsilon: 0.11, score: 150
# Episode: 433/1500, epsilon: 0.11, score: 126
# Episode: 434/1500, epsilon: 0.11, score: 85
# Episode: 435/1500, epsilon: 0.11, score: 116
# Episode: 436/1500, epsilon: 0.11, score: 138
# Episode: 437/1500, epsilon: 0.11, score: 128
# Episode: 438/1500, epsilon: 0.11, score: 179
# Episode: 439/1500, epsilon: 0.11, score: 151
# Episode: 440/1500, epsilon: 0.11, score: 148
# Episode: 441/1500, epsilon: 0.11, score: 199
# Episode: 442/1500, epsilon: 0.11, score: 175
# Episode: 443/1500, epsilon: 0.11, score: 171
# Episode: 444/1500, epsilon: 0.11, score: 149
# Episode: 445/1500, epsilon: 0.11, score: 199
# Episode: 446/1500, epsilon: 0.11, score: 134
# Episode: 447/1500, epsilon: 0.11, score: 130
# Episode: 448/1500, epsilon: 0.11, score: 161
# Episode: 449/1500, epsilon: 0.1, score: 127
# Episode: 450/1500, epsilon: 0.1, score: 119
# Episode: 451/1500, epsilon: 0.1, score: 175
# Episode: 452/1500, epsilon: 0.1, score: 160
# Episode: 453/1500, epsilon: 0.1, score: 163
# Episode: 454/1500, epsilon: 0.1, score: 151
# Episode: 455/1500, epsilon: 0.1, score: 156
# Episode: 456/1500, epsilon: 0.1, score: 141
# Episode: 457/1500, epsilon: 0.1, score: 115
# Episode: 458/1500, epsilon: 0.1, score: 141
# Episode: 459/1500, epsilon: 0.1, score: 110
# Episode: 460/1500, epsilon: 0.099, score: 151
# Episode: 461/1500, epsilon: 0.099, score: 125
# Episode: 462/1500, epsilon: 0.098, score: 129
# Episode: 463/1500, epsilon: 0.098, score: 191
# Episode: 464/1500, epsilon: 0.097, score: 142
# Episode: 465/1500, epsilon: 0.097, score: 125
# Episode: 466/1500, epsilon: 0.096, score: 115
# Episode: 467/1500, epsilon: 0.096, score: 54
# Episode: 468/1500, epsilon: 0.095, score: 106
# Episode: 469/1500, epsilon: 0.095, score: 169
# Episode: 470/1500, epsilon: 0.094, score: 141
# Episode: 471/1500, epsilon: 0.094, score: 170
# Episode: 472/1500, epsilon: 0.093, score: 133
# Episode: 473/1500, epsilon: 0.093, score: 137
# Episode: 474/1500, epsilon: 0.092, score: 16
# Episode: 475/1500, epsilon: 0.092, score: 98
# Episode: 476/1500, epsilon: 0.092, score: 179
# Episode: 477/1500, epsilon: 0.091, score: 113
# Episode: 478/1500, epsilon: 0.091, score: 126
# Episode: 479/1500, epsilon: 0.09, score: 158
# Episode: 480/1500, epsilon: 0.09, score: 133
# Episode: 481/1500, epsilon: 0.089, score: 199
# Episode: 482/1500, epsilon: 0.089, score: 44
# Episode: 483/1500, epsilon: 0.088, score: 194
# Episode: 484/1500, epsilon: 0.088, score: 190
# Episode: 485/1500, epsilon: 0.088, score: 155
# Episode: 486/1500, epsilon: 0.087, score: 170
# Episode: 487/1500, epsilon: 0.087, score: 11
# Episode: 488/1500, epsilon: 0.086, score: 182
# Episode: 489/1500, epsilon: 0.086, score: 176
# Episode: 490/1500, epsilon: 0.085, score: 198
# Episode: 491/1500, epsilon: 0.085, score: 130
# Episode: 492/1500, epsilon: 0.084, score: 114
# Episode: 493/1500, epsilon: 0.084, score: 154
# Episode: 494/1500, epsilon: 0.084, score: 111
# Episode: 495/1500, epsilon: 0.083, score: 199
# Episode: 496/1500, epsilon: 0.083, score: 121
# Episode: 497/1500, epsilon: 0.082, score: 132
# Episode: 498/1500, epsilon: 0.082, score: 129
# Episode: 499/1500, epsilon: 0.082, score: 138
# Episode: 500/1500, epsilon: 0.081, score: 157
# Episode: 501/1500, epsilon: 0.081, score: 116
# Episode: 502/1500, epsilon: 0.08, score: 119
# Episode: 503/1500, epsilon: 0.08, score: 118
# Episode: 504/1500, epsilon: 0.08, score: 163
# Episode: 505/1500, epsilon: 0.079, score: 146
# Episode: 506/1500, epsilon: 0.079, score: 38
# Episode: 507/1500, epsilon: 0.078, score: 94
# Episode: 508/1500, epsilon: 0.078, score: 112
# Episode: 509/1500, epsilon: 0.078, score: 149
# Episode: 510/1500, epsilon: 0.077, score: 176
# Episode: 511/1500, epsilon: 0.077, score: 160
# Episode: 512/1500, epsilon: 0.076, score: 112
# Episode: 513/1500, epsilon: 0.076, score: 128
# Episode: 514/1500, epsilon: 0.076, score: 152
# Episode: 515/1500, epsilon: 0.075, score: 118
# Episode: 516/1500, epsilon: 0.075, score: 102
# Episode: 517/1500, epsilon: 0.075, score: 54
# Episode: 518/1500, epsilon: 0.074, score: 51
# Episode: 519/1500, epsilon: 0.074, score: 34
# Episode: 520/1500, epsilon: 0.073, score: 85
# Episode: 521/1500, epsilon: 0.073, score: 58
# Episode: 522/1500, epsilon: 0.073, score: 49
# Episode: 523/1500, epsilon: 0.072, score: 118
# Episode: 524/1500, epsilon: 0.072, score: 123
# Episode: 525/1500, epsilon: 0.072, score: 173
# Episode: 526/1500, epsilon: 0.071, score: 20
# Episode: 527/1500, epsilon: 0.071, score: 14
# Episode: 528/1500, epsilon: 0.071, score: 114
# Episode: 529/1500, epsilon: 0.07, score: 196
# Episode: 530/1500, epsilon: 0.07, score: 103
# Episode: 531/1500, epsilon: 0.069, score: 166
# Episode: 532/1500, epsilon: 0.069, score: 161
# Episode: 533/1500, epsilon: 0.069, score: 174
# Episode: 534/1500, epsilon: 0.068, score: 199
# Episode: 535/1500, epsilon: 0.068, score: 18
# Episode: 536/1500, epsilon: 0.068, score: 199
# Episode: 537/1500, epsilon: 0.067, score: 199
# Episode: 538/1500, epsilon: 0.067, score: 153
# Episode: 539/1500, epsilon: 0.067, score: 24
# Episode: 540/1500, epsilon: 0.066, score: 131
# Episode: 541/1500, epsilon: 0.066, score: 106
# Episode: 542/1500, epsilon: 0.066, score: 109
# Episode: 543/1500, epsilon: 0.065, score: 199
# Episode: 544/1500, epsilon: 0.065, score: 199
# Episode: 545/1500, epsilon: 0.065, score: 199
# Episode: 546/1500, epsilon: 0.064, score: 199
# Episode: 547/1500, epsilon: 0.064, score: 199
# Episode: 548/1500, epsilon: 0.064, score: 196
# Episode: 549/1500, epsilon: 0.063, score: 191
# Episode: 550/1500, epsilon: 0.063, score: 199
# Episode: 551/1500, epsilon: 0.063, score: 199
# Episode: 552/1500, epsilon: 0.063, score: 199
# Episode: 553/1500, epsilon: 0.062, score: 159
# Episode: 554/1500, epsilon: 0.062, score: 136
# Episode: 555/1500, epsilon: 0.062, score: 185
# Episode: 556/1500, epsilon: 0.061, score: 14
# Episode: 557/1500, epsilon: 0.061, score: 99
# Episode: 558/1500, epsilon: 0.061, score: 124
# Episode: 559/1500, epsilon: 0.06, score: 199
# Episode: 560/1500, epsilon: 0.06, score: 112
# Episode: 561/1500, epsilon: 0.06, score: 124
# Episode: 562/1500, epsilon: 0.059, score: 171
# Episode: 563/1500, epsilon: 0.059, score: 199
# Episode: 564/1500, epsilon: 0.059, score: 118
# Episode: 565/1500, epsilon: 0.059, score: 94
# Episode: 566/1500, epsilon: 0.058, score: 149
# Episode: 567/1500, epsilon: 0.058, score: 174
# Episode: 568/1500, epsilon: 0.058, score: 199
# Episode: 569/1500, epsilon: 0.057, score: 157
# Episode: 570/1500, epsilon: 0.057, score: 199
# Episode: 571/1500, epsilon: 0.057, score: 199
# Episode: 572/1500, epsilon: 0.057, score: 164
# Episode: 573/1500, epsilon: 0.056, score: 199
# Episode: 574/1500, epsilon: 0.056, score: 170
# Episode: 575/1500, epsilon: 0.056, score: 199
# Episode: 576/1500, epsilon: 0.055, score: 199
# Episode: 577/1500, epsilon: 0.055, score: 183
# Episode: 578/1500, epsilon: 0.055, score: 154
# Episode: 579/1500, epsilon: 0.055, score: 199
# Episode: 580/1500, epsilon: 0.054, score: 199
# Episode: 581/1500, epsilon: 0.054, score: 199
# Episode: 582/1500, epsilon: 0.054, score: 170
# Episode: 583/1500, epsilon: 0.054, score: 186
# Episode: 584/1500, epsilon: 0.053, score: 199
# Episode: 585/1500, epsilon: 0.053, score: 194
# Episode: 586/1500, epsilon: 0.053, score: 173
# Episode: 587/1500, epsilon: 0.052, score: 199
# Episode: 588/1500, epsilon: 0.052, score: 182
# Episode: 589/1500, epsilon: 0.052, score: 124
# Episode: 590/1500, epsilon: 0.052, score: 144
# Episode: 591/1500, epsilon: 0.051, score: 138
# Episode: 592/1500, epsilon: 0.051, score: 199
# Episode: 593/1500, epsilon: 0.051, score: 123
# Episode: 594/1500, epsilon: 0.051, score: 10
# Episode: 595/1500, epsilon: 0.05, score: 96
# Episode: 596/1500, epsilon: 0.05, score: 93
# Episode: 597/1500, epsilon: 0.05, score: 158
# Episode: 598/1500, epsilon: 0.05, score: 132
# Episode: 599/1500, epsilon: 0.049, score: 199
# Episode: 600/1500, epsilon: 0.049, score: 136
# Episode: 601/1500, epsilon: 0.049, score: 154
# Episode: 602/1500, epsilon: 0.049, score: 144
# Episode: 603/1500, epsilon: 0.048, score: 162
# Episode: 604/1500, epsilon: 0.048, score: 122
# Episode: 605/1500, epsilon: 0.048, score: 109
# Episode: 606/1500, epsilon: 0.048, score: 145
# Episode: 607/1500, epsilon: 0.047, score: 131
# Episode: 608/1500, epsilon: 0.047, score: 181
# Episode: 609/1500, epsilon: 0.047, score: 199
# Episode: 610/1500, epsilon: 0.047, score: 111
# Episode: 611/1500, epsilon: 0.047, score: 199
# Episode: 612/1500, epsilon: 0.046, score: 173
# Episode: 613/1500, epsilon: 0.046, score: 156
# Episode: 614/1500, epsilon: 0.046, score: 177
# Episode: 615/1500, epsilon: 0.046, score: 181
# Episode: 616/1500, epsilon: 0.045, score: 64
# Episode: 617/1500, epsilon: 0.045, score: 89
# Episode: 618/1500, epsilon: 0.045, score: 90
# Episode: 619/1500, epsilon: 0.045, score: 83
# Episode: 620/1500, epsilon: 0.044, score: 92
# Episode: 621/1500, epsilon: 0.044, score: 10
# Episode: 622/1500, epsilon: 0.044, score: 199
# Episode: 623/1500, epsilon: 0.044, score: 55
# Episode: 624/1500, epsilon: 0.044, score: 72
# Episode: 625/1500, epsilon: 0.043, score: 109
# Episode: 626/1500, epsilon: 0.043, score: 158
# Episode: 627/1500, epsilon: 0.043, score: 171
# Episode: 628/1500, epsilon: 0.043, score: 103
# Episode: 629/1500, epsilon: 0.043, score: 9
# Episode: 630/1500, epsilon: 0.042, score: 63
# Episode: 631/1500, epsilon: 0.042, score: 121
# Episode: 632/1500, epsilon: 0.042, score: 119
# Episode: 633/1500, epsilon: 0.042, score: 170
# Episode: 634/1500, epsilon: 0.041, score: 179
# Episode: 635/1500, epsilon: 0.041, score: 153
# Episode: 636/1500, epsilon: 0.041, score: 153
# Episode: 637/1500, epsilon: 0.041, score: 9
# Episode: 638/1500, epsilon: 0.041, score: 125
# Episode: 639/1500, epsilon: 0.04, score: 122
# Episode: 640/1500, epsilon: 0.04, score: 104
# Episode: 641/1500, epsilon: 0.04, score: 30
# Episode: 642/1500, epsilon: 0.04, score: 114
# Episode: 643/1500, epsilon: 0.04, score: 166
# Episode: 644/1500, epsilon: 0.039, score: 131
# Episode: 645/1500, epsilon: 0.039, score: 132
# Episode: 646/1500, epsilon: 0.039, score: 199
# Episode: 647/1500, epsilon: 0.039, score: 172
# Episode: 648/1500, epsilon: 0.039, score: 164
# Episode: 649/1500, epsilon: 0.038, score: 92
# Episode: 650/1500, epsilon: 0.038, score: 102
# Episode: 651/1500, epsilon: 0.038, score: 11
# Episode: 652/1500, epsilon: 0.038, score: 83
# Episode: 653/1500, epsilon: 0.038, score: 14
# Episode: 654/1500, epsilon: 0.038, score: 94
# Episode: 655/1500, epsilon: 0.037, score: 110
# Episode: 656/1500, epsilon: 0.037, score: 84
# Episode: 657/1500, epsilon: 0.037, score: 75
# Episode: 658/1500, epsilon: 0.037, score: 100
# Episode: 659/1500, epsilon: 0.037, score: 100
# Episode: 660/1500, epsilon: 0.036, score: 126
# Episode: 661/1500, epsilon: 0.036, score: 101
# Episode: 662/1500, epsilon: 0.036, score: 114
# Episode: 663/1500, epsilon: 0.036, score: 113
# Episode: 664/1500, epsilon: 0.036, score: 114
# Episode: 665/1500, epsilon: 0.035, score: 95
# Episode: 666/1500, epsilon: 0.035, score: 97
# Episode: 667/1500, epsilon: 0.035, score: 99
# Episode: 668/1500, epsilon: 0.035, score: 199
# Episode: 669/1500, epsilon: 0.035, score: 150
# Episode: 670/1500, epsilon: 0.035, score: 139
# Episode: 671/1500, epsilon: 0.034, score: 156
# Episode: 672/1500, epsilon: 0.034, score: 115
# Episode: 673/1500, epsilon: 0.034, score: 14
# Episode: 674/1500, epsilon: 0.034, score: 128
# Episode: 675/1500, epsilon: 0.034, score: 134
# Episode: 676/1500, epsilon: 0.034, score: 109
# Episode: 677/1500, epsilon: 0.033, score: 97
# Episode: 678/1500, epsilon: 0.033, score: 126
# Episode: 679/1500, epsilon: 0.033, score: 121
# Episode: 680/1500, epsilon: 0.033, score: 108
# Episode: 681/1500, epsilon: 0.033, score: 139
# Episode: 682/1500, epsilon: 0.033, score: 98
# Episode: 683/1500, epsilon: 0.032, score: 105
# Episode: 684/1500, epsilon: 0.032, score: 181
# Episode: 685/1500, epsilon: 0.032, score: 122
# Episode: 686/1500, epsilon: 0.032, score: 122
# Episode: 687/1500, epsilon: 0.032, score: 124
# Episode: 688/1500, epsilon: 0.032, score: 103
# Episode: 689/1500, epsilon: 0.031, score: 109
# Episode: 690/1500, epsilon: 0.031, score: 104
# Episode: 691/1500, epsilon: 0.031, score: 97
# Episode: 692/1500, epsilon: 0.031, score: 107
# Episode: 693/1500, epsilon: 0.031, score: 99
# Episode: 694/1500, epsilon: 0.031, score: 146
# Episode: 695/1500, epsilon: 0.031, score: 107
# Episode: 696/1500, epsilon: 0.03, score: 111
# Episode: 697/1500, epsilon: 0.03, score: 104
# Episode: 698/1500, epsilon: 0.03, score: 199
# Episode: 699/1500, epsilon: 0.03, score: 145
# Episode: 700/1500, epsilon: 0.03, score: 121
# Episode: 701/1500, epsilon: 0.03, score: 180
# Episode: 702/1500, epsilon: 0.029, score: 199
# Episode: 703/1500, epsilon: 0.029, score: 16
# Episode: 704/1500, epsilon: 0.029, score: 125
# Episode: 705/1500, epsilon: 0.029, score: 192
# Episode: 706/1500, epsilon: 0.029, score: 162
# Episode: 707/1500, epsilon: 0.029, score: 166
# Episode: 708/1500, epsilon: 0.029, score: 14
# Episode: 709/1500, epsilon: 0.028, score: 183
# Episode: 710/1500, epsilon: 0.028, score: 166
# Episode: 711/1500, epsilon: 0.028, score: 99
# Episode: 712/1500, epsilon: 0.028, score: 16
# Episode: 713/1500, epsilon: 0.028, score: 12
# Episode: 714/1500, epsilon: 0.028, score: 15
# Episode: 715/1500, epsilon: 0.028, score: 12
# Episode: 716/1500, epsilon: 0.027, score: 9
# Episode: 717/1500, epsilon: 0.027, score: 122
# Episode: 718/1500, epsilon: 0.027, score: 10
# Episode: 719/1500, epsilon: 0.027, score: 10
# Episode: 720/1500, epsilon: 0.027, score: 14
# Episode: 721/1500, epsilon: 0.027, score: 22
# Episode: 722/1500, epsilon: 0.027, score: 26
# Episode: 723/1500, epsilon: 0.027, score: 148
# Episode: 724/1500, epsilon: 0.026, score: 87
# Episode: 725/1500, epsilon: 0.026, score: 106
# Episode: 726/1500, epsilon: 0.026, score: 66
# Episode: 727/1500, epsilon: 0.026, score: 101
# Episode: 728/1500, epsilon: 0.026, score: 189
# Episode: 729/1500, epsilon: 0.026, score: 131
# Episode: 730/1500, epsilon: 0.026, score: 199
# Episode: 731/1500, epsilon: 0.025, score: 199
# Episode: 732/1500, epsilon: 0.025, score: 199
# Episode: 733/1500, epsilon: 0.025, score: 162
# Episode: 734/1500, epsilon: 0.025, score: 199
# Episode: 735/1500, epsilon: 0.025, score: 199
# Episode: 736/1500, epsilon: 0.025, score: 199
# Episode: 737/1500, epsilon: 0.025, score: 199
# Episode: 738/1500, epsilon: 0.025, score: 197
# Episode: 739/1500, epsilon: 0.024, score: 155
# Episode: 740/1500, epsilon: 0.024, score: 153
# Episode: 741/1500, epsilon: 0.024, score: 199
# Episode: 742/1500, epsilon: 0.024, score: 199
# Episode: 743/1500, epsilon: 0.024, score: 124
# Episode: 744/1500, epsilon: 0.024, score: 154
# Episode: 745/1500, epsilon: 0.024, score: 199
# Episode: 746/1500, epsilon: 0.024, score: 168
# Episode: 747/1500, epsilon: 0.024, score: 199
# Episode: 748/1500, epsilon: 0.023, score: 145
# Episode: 749/1500, epsilon: 0.023, score: 162
# Episode: 750/1500, epsilon: 0.023, score: 148
# Episode: 751/1500, epsilon: 0.023, score: 160
# Episode: 752/1500, epsilon: 0.023, score: 182
# Episode: 753/1500, epsilon: 0.023, score: 199
# Episode: 754/1500, epsilon: 0.023, score: 147
# Episode: 755/1500, epsilon: 0.023, score: 177
# Episode: 756/1500, epsilon: 0.022, score: 169
# Episode: 757/1500, epsilon: 0.022, score: 151
# Episode: 758/1500, epsilon: 0.022, score: 199
# Episode: 759/1500, epsilon: 0.022, score: 173
# Episode: 760/1500, epsilon: 0.022, score: 126
# Episode: 761/1500, epsilon: 0.022, score: 152
# Episode: 762/1500, epsilon: 0.022, score: 161
# Episode: 763/1500, epsilon: 0.022, score: 197
# Episode: 764/1500, epsilon: 0.022, score: 152
# Episode: 765/1500, epsilon: 0.022, score: 143
# Episode: 766/1500, epsilon: 0.021, score: 158
# Episode: 767/1500, epsilon: 0.021, score: 21
# Episode: 768/1500, epsilon: 0.021, score: 139
# Episode: 769/1500, epsilon: 0.021, score: 138
# Episode: 770/1500, epsilon: 0.021, score: 199
# Episode: 771/1500, epsilon: 0.021, score: 157
# Episode: 772/1500, epsilon: 0.021, score: 179
# Episode: 773/1500, epsilon: 0.021, score: 19
# Episode: 774/1500, epsilon: 0.021, score: 101
# Episode: 775/1500, epsilon: 0.02, score: 199
# Episode: 776/1500, epsilon: 0.02, score: 110
# Episode: 777/1500, epsilon: 0.02, score: 158
# Episode: 778/1500, epsilon: 0.02, score: 199
# Episode: 779/1500, epsilon: 0.02, score: 199
# Episode: 780/1500, epsilon: 0.02, score: 199
# Episode: 781/1500, epsilon: 0.02, score: 199
# Episode: 782/1500, epsilon: 0.02, score: 199
# Episode: 783/1500, epsilon: 0.02, score: 199
# Episode: 784/1500, epsilon: 0.02, score: 13
# Episode: 785/1500, epsilon: 0.019, score: 17
# Episode: 786/1500, epsilon: 0.019, score: 157
# Episode: 787/1500, epsilon: 0.019, score: 199
# Episode: 788/1500, epsilon: 0.019, score: 199
# Episode: 789/1500, epsilon: 0.019, score: 199
# Episode: 790/1500, epsilon: 0.019, score: 196
# Episode: 791/1500, epsilon: 0.019, score: 167
# Episode: 792/1500, epsilon: 0.019, score: 113
# Episode: 793/1500, epsilon: 0.019, score: 137
# Episode: 794/1500, epsilon: 0.019, score: 199
# Episode: 795/1500, epsilon: 0.019, score: 199
# Episode: 796/1500, epsilon: 0.018, score: 112
# Episode: 797/1500, epsilon: 0.018, score: 23
# Episode: 798/1500, epsilon: 0.018, score: 102
# Episode: 799/1500, epsilon: 0.018, score: 104
# Episode: 800/1500, epsilon: 0.018, score: 107
# Episode: 801/1500, epsilon: 0.018, score: 153
# Episode: 802/1500, epsilon: 0.018, score: 199
# Episode: 803/1500, epsilon: 0.018, score: 199
# Episode: 804/1500, epsilon: 0.018, score: 199
# Episode: 805/1500, epsilon: 0.018, score: 199
# Episode: 806/1500, epsilon: 0.018, score: 13
# Episode: 807/1500, epsilon: 0.017, score: 133
# Episode: 808/1500, epsilon: 0.017, score: 199
# Episode: 809/1500, epsilon: 0.017, score: 199
# Episode: 810/1500, epsilon: 0.017, score: 199
# Episode: 811/1500, epsilon: 0.017, score: 175
# Episode: 812/1500, epsilon: 0.017, score: 117
# Episode: 813/1500, epsilon: 0.017, score: 118
# Episode: 814/1500, epsilon: 0.017, score: 199
# Episode: 815/1500, epsilon: 0.017, score: 20
# Episode: 816/1500, epsilon: 0.017, score: 199
# Episode: 817/1500, epsilon: 0.017, score: 199
# Episode: 818/1500, epsilon: 0.016, score: 187
# Episode: 819/1500, epsilon: 0.016, score: 199
# Episode: 820/1500, epsilon: 0.016, score: 199
# Episode: 821/1500, epsilon: 0.016, score: 199
# Episode: 822/1500, epsilon: 0.016, score: 199
# Episode: 823/1500, epsilon: 0.016, score: 199
# Episode: 824/1500, epsilon: 0.016, score: 183
# Episode: 825/1500, epsilon: 0.016, score: 199
# Episode: 826/1500, epsilon: 0.016, score: 164
# Episode: 827/1500, epsilon: 0.016, score: 149
# Episode: 828/1500, epsilon: 0.016, score: 165
# Episode: 829/1500, epsilon: 0.016, score: 139
# Episode: 830/1500, epsilon: 0.016, score: 138
# Episode: 831/1500, epsilon: 0.015, score: 90
# Episode: 832/1500, epsilon: 0.015, score: 130
# Episode: 833/1500, epsilon: 0.015, score: 135
# Episode: 834/1500, epsilon: 0.015, score: 168
# Episode: 835/1500, epsilon: 0.015, score: 125
# Episode: 836/1500, epsilon: 0.015, score: 89
# Episode: 837/1500, epsilon: 0.015, score: 170
# Episode: 838/1500, epsilon: 0.015, score: 112
# Episode: 839/1500, epsilon: 0.015, score: 126
# Episode: 840/1500, epsilon: 0.015, score: 109
# Episode: 841/1500, epsilon: 0.015, score: 199
# Episode: 842/1500, epsilon: 0.015, score: 121
# Episode: 843/1500, epsilon: 0.015, score: 107
# Episode: 844/1500, epsilon: 0.014, score: 158
# Episode: 845/1500, epsilon: 0.014, score: 116
# Episode: 846/1500, epsilon: 0.014, score: 138
# Episode: 847/1500, epsilon: 0.014, score: 119
# Episode: 848/1500, epsilon: 0.014, score: 120
# Episode: 849/1500, epsilon: 0.014, score: 113
# Episode: 850/1500, epsilon: 0.014, score: 115
# Episode: 851/1500, epsilon: 0.014, score: 117
# Episode: 852/1500, epsilon: 0.014, score: 120
# Episode: 853/1500, epsilon: 0.014, score: 95
# Episode: 854/1500, epsilon: 0.014, score: 118
# Episode: 855/1500, epsilon: 0.014, score: 111
# Episode: 856/1500, epsilon: 0.014, score: 126
# Episode: 857/1500, epsilon: 0.014, score: 117
# Episode: 858/1500, epsilon: 0.013, score: 117
# Episode: 859/1500, epsilon: 0.013, score: 126
# Episode: 860/1500, epsilon: 0.013, score: 104
# Episode: 861/1500, epsilon: 0.013, score: 117
# Episode: 862/1500, epsilon: 0.013, score: 103
# Episode: 863/1500, epsilon: 0.013, score: 114
# Episode: 864/1500, epsilon: 0.013, score: 124
# Episode: 865/1500, epsilon: 0.013, score: 111
# Episode: 866/1500, epsilon: 0.013, score: 121
# Episode: 867/1500, epsilon: 0.013, score: 125
# Episode: 868/1500, epsilon: 0.013, score: 139
# Episode: 869/1500, epsilon: 0.013, score: 118
# Episode: 870/1500, epsilon: 0.013, score: 113
# Episode: 871/1500, epsilon: 0.013, score: 148
# Episode: 872/1500, epsilon: 0.013, score: 130
# Episode: 873/1500, epsilon: 0.013, score: 109
# Episode: 874/1500, epsilon: 0.012, score: 107
# Episode: 875/1500, epsilon: 0.012, score: 90
# Episode: 876/1500, epsilon: 0.012, score: 118
# Episode: 877/1500, epsilon: 0.012, score: 97
# Episode: 878/1500, epsilon: 0.012, score: 112
# Episode: 879/1500, epsilon: 0.012, score: 48
# Episode: 880/1500, epsilon: 0.012, score: 105
# Episode: 881/1500, epsilon: 0.012, score: 105
# Episode: 882/1500, epsilon: 0.012, score: 43
# Episode: 883/1500, epsilon: 0.012, score: 10
# Episode: 884/1500, epsilon: 0.012, score: 132
# Episode: 885/1500, epsilon: 0.012, score: 108
# Episode: 886/1500, epsilon: 0.012, score: 96
# Episode: 887/1500, epsilon: 0.012, score: 106
# Episode: 888/1500, epsilon: 0.012, score: 100
# Episode: 889/1500, epsilon: 0.012, score: 98
# Episode: 890/1500, epsilon: 0.011, score: 17
# Episode: 891/1500, epsilon: 0.011, score: 51
# Episode: 892/1500, epsilon: 0.011, score: 109
# Episode: 893/1500, epsilon: 0.011, score: 103
# Episode: 894/1500, epsilon: 0.011, score: 116
# Episode: 895/1500, epsilon: 0.011, score: 43
# Episode: 896/1500, epsilon: 0.011, score: 102
# Episode: 897/1500, epsilon: 0.011, score: 124
# Episode: 898/1500, epsilon: 0.011, score: 36
# Episode: 899/1500, epsilon: 0.011, score: 40
# Episode: 900/1500, epsilon: 0.011, score: 101
# Episode: 901/1500, epsilon: 0.011, score: 24
# Episode: 902/1500, epsilon: 0.011, score: 119
# Episode: 903/1500, epsilon: 0.011, score: 127
# Episode: 904/1500, epsilon: 0.011, score: 115
# Episode: 905/1500, epsilon: 0.011, score: 199
# Episode: 906/1500, epsilon: 0.011, score: 141
# Episode: 907/1500, epsilon: 0.011, score: 147
# Episode: 908/1500, epsilon: 0.01, score: 103
# Episode: 909/1500, epsilon: 0.01, score: 199
# Episode: 910/1500, epsilon: 0.01, score: 182
# Episode: 911/1500, epsilon: 0.01, score: 121
# Episode: 912/1500, epsilon: 0.01, score: 199
# Episode: 913/1500, epsilon: 0.01, score: 159
# Episode: 914/1500, epsilon: 0.01, score: 199
# Episode: 915/1500, epsilon: 0.01, score: 199
# Episode: 916/1500, epsilon: 0.01, score: 199
# Episode: 917/1500, epsilon: 0.01, score: 199
# Episode: 918/1500, epsilon: 0.01, score: 199
# Episode: 919/1500, epsilon: 0.01, score: 109
# Episode: 920/1500, epsilon: 0.01, score: 159
# Episode: 921/1500, epsilon: 0.01, score: 199
# Episode: 922/1500, epsilon: 0.01, score: 199
# Episode: 923/1500, epsilon: 0.01, score: 117
# Episode: 924/1500, epsilon: 0.01, score: 199
# Episode: 925/1500, epsilon: 0.01, score: 199
# Episode: 926/1500, epsilon: 0.01, score: 199
# Episode: 927/1500, epsilon: 0.01, score: 32
# Episode: 928/1500, epsilon: 0.01, score: 106
# Episode: 929/1500, epsilon: 0.01, score: 199
# Episode: 930/1500, epsilon: 0.01, score: 157
# Episode: 931/1500, epsilon: 0.01, score: 199
# Episode: 932/1500, epsilon: 0.01, score: 140
# Episode: 933/1500, epsilon: 0.01, score: 12
# Episode: 934/1500, epsilon: 0.01, score: 108
# Episode: 935/1500, epsilon: 0.01, score: 102
# Episode: 936/1500, epsilon: 0.01, score: 199
# Episode: 937/1500, epsilon: 0.01, score: 142
# Episode: 938/1500, epsilon: 0.01, score: 199
# Episode: 939/1500, epsilon: 0.01, score: 147
# Episode: 940/1500, epsilon: 0.01, score: 114
# Episode: 941/1500, epsilon: 0.01, score: 136
# Episode: 942/1500, epsilon: 0.01, score: 11
# Episode: 943/1500, epsilon: 0.01, score: 118
# Episode: 944/1500, epsilon: 0.01, score: 127
# Episode: 945/1500, epsilon: 0.01, score: 98
# Episode: 946/1500, epsilon: 0.01, score: 169
# Episode: 947/1500, epsilon: 0.01, score: 187
# Episode: 948/1500, epsilon: 0.01, score: 105
# Episode: 949/1500, epsilon: 0.01, score: 154
# Episode: 950/1500, epsilon: 0.01, score: 119
# Episode: 951/1500, epsilon: 0.01, score: 170
# Episode: 952/1500, epsilon: 0.01, score: 72
# Episode: 953/1500, epsilon: 0.01, score: 56
# Episode: 954/1500, epsilon: 0.01, score: 95
# Episode: 955/1500, epsilon: 0.01, score: 16
# Episode: 956/1500, epsilon: 0.01, score: 11
# Episode: 957/1500, epsilon: 0.01, score: 10
# Episode: 958/1500, epsilon: 0.01, score: 7
# Episode: 959/1500, epsilon: 0.01, score: 9
# Episode: 960/1500, epsilon: 0.01, score: 12
# Episode: 961/1500, epsilon: 0.01, score: 9
# Episode: 962/1500, epsilon: 0.01, score: 117
# Episode: 963/1500, epsilon: 0.01, score: 18
# Episode: 964/1500, epsilon: 0.01, score: 10
# Episode: 965/1500, epsilon: 0.01, score: 16
# Episode: 966/1500, epsilon: 0.01, score: 17
# Episode: 967/1500, epsilon: 0.01, score: 26
# Episode: 968/1500, epsilon: 0.01, score: 30
# Episode: 969/1500, epsilon: 0.01, score: 105
# Episode: 970/1500, epsilon: 0.01, score: 101
# Episode: 971/1500, epsilon: 0.01, score: 96
# Episode: 972/1500, epsilon: 0.01, score: 113
# Episode: 973/1500, epsilon: 0.01, score: 143
# Episode: 974/1500, epsilon: 0.01, score: 168
# Episode: 975/1500, epsilon: 0.01, score: 126
# Episode: 976/1500, epsilon: 0.01, score: 139
# Episode: 977/1500, epsilon: 0.01, score: 58
# Episode: 978/1500, epsilon: 0.01, score: 63
# Episode: 979/1500, epsilon: 0.01, score: 178
# Episode: 980/1500, epsilon: 0.01, score: 114
# Episode: 981/1500, epsilon: 0.01, score: 161
# Episode: 982/1500, epsilon: 0.01, score: 25
# Episode: 983/1500, epsilon: 0.01, score: 34
# Episode: 984/1500, epsilon: 0.01, score: 17
# Episode: 985/1500, epsilon: 0.01, score: 13
# Episode: 986/1500, epsilon: 0.01, score: 27
# Episode: 987/1500, epsilon: 0.01, score: 185
# Episode: 988/1500, epsilon: 0.01, score: 180
# Episode: 989/1500, epsilon: 0.01, score: 14
# Episode: 990/1500, epsilon: 0.01, score: 59
# Episode: 991/1500, epsilon: 0.01, score: 152
# Episode: 992/1500, epsilon: 0.01, score: 38
# Episode: 993/1500, epsilon: 0.01, score: 10
# Episode: 994/1500, epsilon: 0.01, score: 15
# Episode: 995/1500, epsilon: 0.01, score: 15
# Episode: 996/1500, epsilon: 0.01, score: 133
# Episode: 997/1500, epsilon: 0.01, score: 34
# Episode: 998/1500, epsilon: 0.01, score: 73
# Episode: 999/1500, epsilon: 0.01, score: 141
# Episode: 1000/1500, epsilon: 0.01, score: 110
# Episode: 1001/1500, epsilon: 0.01, score: 123
# Episode: 1002/1500, epsilon: 0.01, score: 73
# Episode: 1003/1500, epsilon: 0.01, score: 90
# Episode: 1004/1500, epsilon: 0.01, score: 199
# Episode: 1005/1500, epsilon: 0.01, score: 180
# Episode: 1006/1500, epsilon: 0.01, score: 141
# Episode: 1007/1500, epsilon: 0.01, score: 117
# Episode: 1008/1500, epsilon: 0.01, score: 100
# Episode: 1009/1500, epsilon: 0.01, score: 147
# Episode: 1010/1500, epsilon: 0.01, score: 131
# Episode: 1011/1500, epsilon: 0.01, score: 199
# Episode: 1012/1500, epsilon: 0.01, score: 143
# Episode: 1013/1500, epsilon: 0.01, score: 150
# Episode: 1014/1500, epsilon: 0.01, score: 151
# Episode: 1015/1500, epsilon: 0.01, score: 164
# Episode: 1016/1500, epsilon: 0.01, score: 119
# Episode: 1017/1500, epsilon: 0.01, score: 121
# Episode: 1018/1500, epsilon: 0.01, score: 149
# Episode: 1019/1500, epsilon: 0.01, score: 118
# Episode: 1020/1500, epsilon: 0.01, score: 106
# Episode: 1021/1500, epsilon: 0.01, score: 135
# Episode: 1022/1500, epsilon: 0.01, score: 120
# Episode: 1023/1500, epsilon: 0.01, score: 106
# Episode: 1024/1500, epsilon: 0.01, score: 124
# Episode: 1025/1500, epsilon: 0.01, score: 176
# Episode: 1026/1500, epsilon: 0.01, score: 133
# Episode: 1027/1500, epsilon: 0.01, score: 76
# Episode: 1028/1500, epsilon: 0.01, score: 169
# Episode: 1029/1500, epsilon: 0.01, score: 176
# Episode: 1030/1500, epsilon: 0.01, score: 199
# ...
# Episode: 1151/1500, epsilon: 0.01, score: 138
# Episode: 1152/1500, epsilon: 0.01, score: 129
# Episode: 1153/1500, epsilon: 0.01, score: 120
# Episode: 1154/1500, epsilon: 0.01, score: 129
# Episode: 1155/1500, epsilon: 0.01, score: 154
# Episode: 1156/1500, epsilon: 0.01, score: 141
# Episode: 1157/1500, epsilon: 0.01, score: 136
# Episode: 1158/1500, epsilon: 0.01, score: 124
# Episode: 1159/1500, epsilon: 0.01, score: 107
# Episode: 1160/1500, epsilon: 0.01, score: 118
# Episode: 1161/1500, epsilon: 0.01, score: 162
# Episode: 1162/1500, epsilon: 0.01, score: 129
# Episode: 1163/1500, epsilon: 0.01, score: 157
# Episode: 1164/1500, epsilon: 0.01, score: 135
# Episode: 1165/1500, epsilon: 0.01, score: 105
# Episode: 1166/1500, epsilon: 0.01, score: 127
# Episode: 1167/1500, epsilon: 0.01, score: 8
# Episode: 1168/1500, epsilon: 0.01, score: 199
# Episode: 1169/1500, epsilon: 0.01, score: 124
# Episode: 1170/1500, epsilon: 0.01, score: 125
# Episode: 1171/1500, epsilon: 0.01, score: 111
# Episode: 1172/1500, epsilon: 0.01, score: 129
# Episode: 1173/1500, epsilon: 0.01, score: 199
# Episode: 1174/1500, epsilon: 0.01, score: 177
# Episode: 1175/1500, epsilon: 0.01, score: 109
# Episode: 1176/1500, epsilon: 0.01, score: 146
# Episode: 1177/1500, epsilon: 0.01, score: 199
# Episode: 1178/1500, epsilon: 0.01, score: 127
# Episode: 1179/1500, epsilon: 0.01, score: 107
# Episode: 1180/1500, epsilon: 0.01, score: 179
# Episode: 1181/1500, epsilon: 0.01, score: 136
# Episode: 1182/1500, epsilon: 0.01, score: 130
# Episode: 1183/1500, epsilon: 0.01, score: 169
# Episode: 1184/1500, epsilon: 0.01, score: 163
# Episode: 1185/1500, epsilon: 0.01, score: 168
# Episode: 1186/1500, epsilon: 0.01, score: 113
# Episode: 1187/1500, epsilon: 0.01, score: 170
# Episode: 1188/1500, epsilon: 0.01, score: 175
# Episode: 1189/1500, epsilon: 0.01, score: 45
# Episode: 1190/1500, epsilon: 0.01, score: 81
# Episode: 1191/1500, epsilon: 0.01, score: 148
# Episode: 1192/1500, epsilon: 0.01, score: 154
# Episode: 1193/1500, epsilon: 0.01, score: 182
# Episode: 1194/1500, epsilon: 0.01, score: 199
# Episode: 1195/1500, epsilon: 0.01, score: 133
# Episode: 1196/1500, epsilon: 0.01, score: 199
# Episode: 1197/1500, epsilon: 0.01, score: 108
# Episode: 1198/1500, epsilon: 0.01, score: 166
# Episode: 1199/1500, epsilon: 0.01, score: 123
# Episode: 1200/1500, epsilon: 0.01, score: 191
# Episode: 1201/1500, epsilon: 0.01, score: 199
# Episode: 1202/1500, epsilon: 0.01, score: 158
# Episode: 1203/1500, epsilon: 0.01, score: 167
# Episode: 1204/1500, epsilon: 0.01, score: 199
# Episode: 1205/1500, epsilon: 0.01, score: 109
# Episode: 1206/1500, epsilon: 0.01, score: 151
# Episode: 1207/1500, epsilon: 0.01, score: 123
# Episode: 1208/1500, epsilon: 0.01, score: 112
# Episode: 1209/1500, epsilon: 0.01, score: 157
# Episode: 1210/1500, epsilon: 0.01, score: 186
# Episode: 1211/1500, epsilon: 0.01, score: 122
# Episode: 1212/1500, epsilon: 0.01, score: 112
# Episode: 1213/1500, epsilon: 0.01, score: 130
# Episode: 1214/1500, epsilon: 0.01, score: 133
# Episode: 1215/1500, epsilon: 0.01, score: 137
# Episode: 1216/1500, epsilon: 0.01, score: 125
# Episode: 1217/1500, epsilon: 0.01, score: 115
# Episode: 1218/1500, epsilon: 0.01, score: 19
# Episode: 1219/1500, epsilon: 0.01, score: 99
# Episode: 1220/1500, epsilon: 0.01, score: 103
# Episode: 1221/1500, epsilon: 0.01, score: 106
# Episode: 1222/1500, epsilon: 0.01, score: 115
# Episode: 1223/1500, epsilon: 0.01, score: 132
# Episode: 1224/1500, epsilon: 0.01, score: 169
# Episode: 1225/1500, epsilon: 0.01, score: 199
# Episode: 1226/1500, epsilon: 0.01, score: 106
# Episode: 1227/1500, epsilon: 0.01, score: 131
# Episode: 1228/1500, epsilon: 0.01, score: 96
# Episode: 1229/1500, epsilon: 0.01, score: 132
# Episode: 1230/1500, epsilon: 0.01, score: 179
# Episode: 1231/1500, epsilon: 0.01, score: 96
# Episode: 1232/1500, epsilon: 0.01, score: 104
# Episode: 1233/1500, epsilon: 0.01, score: 165
# Episode: 1234/1500, epsilon: 0.01, score: 14
# Episode: 1235/1500, epsilon: 0.01, score: 199
# Episode: 1236/1500, epsilon: 0.01, score: 199
# Episode: 1237/1500, epsilon: 0.01, score: 199
# Episode: 1238/1500, epsilon: 0.01, score: 199
# Episode: 1239/1500, epsilon: 0.01, score: 101
# Episode: 1240/1500, epsilon: 0.01, score: 199
# Episode: 1241/1500, epsilon: 0.01, score: 199
# Episode: 1242/1500, epsilon: 0.01, score: 199
# Episode: 1243/1500, epsilon: 0.01, score: 199
# Episode: 1244/1500, epsilon: 0.01, score: 199
# Episode: 1245/1500, epsilon: 0.01, score: 199
# Episode: 1246/1500, epsilon: 0.01, score: 199
# Episode: 1247/1500, epsilon: 0.01, score: 199
# Episode: 1248/1500, epsilon: 0.01, score: 199
# Episode: 1249/1500, epsilon: 0.01, score: 199
# Episode: 1250/1500, epsilon: 0.01, score: 199
# Episode: 1251/1500, epsilon: 0.01, score: 199
# Episode: 1252/1500, epsilon: 0.01, score: 199
# Episode: 1253/1500, epsilon: 0.01, score: 199
# Episode: 1254/1500, epsilon: 0.01, score: 199
# Episode: 1255/1500, epsilon: 0.01, score: 199
# Episode: 1256/1500, epsilon: 0.01, score: 199
# Episode: 1257/1500, epsilon: 0.01, score: 199
# Episode: 1258/1500, epsilon: 0.01, score: 199
# Episode: 1259/1500, epsilon: 0.01, score: 199
# Episode: 1260/1500, epsilon: 0.01, score: 199
# Episode: 1261/1500, epsilon: 0.01, score: 199
# Episode: 1262/1500, epsilon: 0.01, score: 199
# Episode: 1263/1500, epsilon: 0.01, score: 16
# Episode: 1264/1500, epsilon: 0.01, score: 119
# Episode: 1265/1500, epsilon: 0.01, score: 9
# Episode: 1266/1500, epsilon: 0.01, score: 199
# Episode: 1267/1500, epsilon: 0.01, score: 111
# Episode: 1268/1500, epsilon: 0.01, score: 122
# Episode: 1269/1500, epsilon: 0.01, score: 8
# Episode: 1270/1500, epsilon: 0.01, score: 199
# Episode: 1271/1500, epsilon: 0.01, score: 11
# Episode: 1272/1500, epsilon: 0.01, score: 15
# Episode: 1273/1500, epsilon: 0.01, score: 199
# Episode: 1274/1500, epsilon: 0.01, score: 162
# Episode: 1275/1500, epsilon: 0.01, score: 81
# Episode: 1276/1500, epsilon: 0.01, score: 199
# Episode: 1277/1500, epsilon: 0.01, score: 199
# Episode: 1278/1500, epsilon: 0.01, score: 174
# Episode: 1279/1500, epsilon: 0.01, score: 9
# Episode: 1280/1500, epsilon: 0.01, score: 199
# Episode: 1281/1500, epsilon: 0.01, score: 15
# Episode: 1282/1500, epsilon: 0.01, score: 199
# Episode: 1283/1500, epsilon: 0.01, score: 199
# Episode: 1284/1500, epsilon: 0.01, score: 99
# Episode: 1285/1500, epsilon: 0.01, score: 199
# Episode: 1286/1500, epsilon: 0.01, score: 199
# Episode: 1287/1500, epsilon: 0.01, score: 199
# Episode: 1288/1500, epsilon: 0.01, score: 199
# Episode: 1289/1500, epsilon: 0.01, score: 199
# Episode: 1290/1500, epsilon: 0.01, score: 199
# Episode: 1291/1500, epsilon: 0.01, score: 199
# Episode: 1292/1500, epsilon: 0.01, score: 12
# Episode: 1293/1500, epsilon: 0.01, score: 14
# Episode: 1294/1500, epsilon: 0.01, score: 199
# Episode: 1295/1500, epsilon: 0.01, score: 199
# Episode: 1296/1500, epsilon: 0.01, score: 15
# Episode: 1297/1500, epsilon: 0.01, score: 199
# Episode: 1298/1500, epsilon: 0.01, score: 199
# Episode: 1299/1500, epsilon: 0.01, score: 199
# Episode: 1300/1500, epsilon: 0.01, score: 199
# Episode: 1301/1500, epsilon: 0.01, score: 199
# Episode: 1302/1500, epsilon: 0.01, score: 12
# Episode: 1303/1500, epsilon: 0.01, score: 199
# Episode: 1304/1500, epsilon: 0.01, score: 199
# Episode: 1305/1500, epsilon: 0.01, score: 199
# Episode: 1306/1500, epsilon: 0.01, score: 14
# Episode: 1307/1500, epsilon: 0.01, score: 199
# Episode: 1308/1500, epsilon: 0.01, score: 199
# Episode: 1309/1500, epsilon: 0.01, score: 164
# Episode: 1310/1500, epsilon: 0.01, score: 16
# Episode: 1311/1500, epsilon: 0.01, score: 199
# Episode: 1312/1500, epsilon: 0.01, score: 196
# Episode: 1313/1500, epsilon: 0.01, score: 199
# Episode: 1314/1500, epsilon: 0.01, score: 199
# Episode: 1315/1500, epsilon: 0.01, score: 199
# Episode: 1316/1500, epsilon: 0.01, score: 11
# Episode: 1317/1500, epsilon: 0.01, score: 13
# Episode: 1318/1500, epsilon: 0.01, score: 199
# Episode: 1319/1500, epsilon: 0.01, score: 199
# Episode: 1320/1500, epsilon: 0.01, score: 15
# Episode: 1321/1500, epsilon: 0.01, score: 199
# Episode: 1322/1500, epsilon: 0.01, score: 199
# Episode: 1323/1500, epsilon: 0.01, score: 199
# Episode: 1324/1500, epsilon: 0.01, score: 199
# Episode: 1325/1500, epsilon: 0.01, score: 199
# Episode: 1326/1500, epsilon: 0.01, score: 199
# Episode: 1327/1500, epsilon: 0.01, score: 199
# Episode: 1328/1500, epsilon: 0.01, score: 17
# Episode: 1329/1500, epsilon: 0.01, score: 199
# Episode: 1330/1500, epsilon: 0.01, score: 199
# Episode: 1331/1500, epsilon: 0.01, score: 199
# Episode: 1332/1500, epsilon: 0.01, score: 152
# Episode: 1333/1500, epsilon: 0.01, score: 199
# Episode: 1334/1500, epsilon: 0.01, score: 8
# Episode: 1335/1500, epsilon: 0.01, score: 12
# Episode: 1336/1500, epsilon: 0.01, score: 199
# Episode: 1337/1500, epsilon: 0.01, score: 199
# Episode: 1338/1500, epsilon: 0.01, score: 199
# Episode: 1339/1500, epsilon: 0.01, score: 199
# Episode: 1340/1500, epsilon: 0.01, score: 199
# Episode: 1341/1500, epsilon: 0.01, score: 199
# Episode: 1342/1500, epsilon: 0.01, score: 199
# Episode: 1343/1500, epsilon: 0.01, score: 199
# Episode: 1344/1500, epsilon: 0.01, score: 199
# Episode: 1345/1500, epsilon: 0.01, score: 14
# Episode: 1346/1500, epsilon: 0.01, score: 199
# Episode: 1347/1500, epsilon: 0.01, score: 199
# Episode: 1348/1500, epsilon: 0.01, score: 199
# Episode: 1349/1500, epsilon: 0.01, score: 199
# Episode: 1350/1500, epsilon: 0.01, score: 199
# Episode: 1351/1500, epsilon: 0.01, score: 199
# Episode: 1352/1500, epsilon: 0.01, score: 199
# Episode: 1353/1500, epsilon: 0.01, score: 199
# Episode: 1354/1500, epsilon: 0.01, score: 199
# Episode: 1355/1500, epsilon: 0.01, score: 199
# Episode: 1356/1500, epsilon: 0.01, score: 199
# Episode: 1357/1500, epsilon: 0.01, score: 199
# Episode: 1358/1500, epsilon: 0.01, score: 199
# Episode: 1359/1500, epsilon: 0.01, score: 199
# Episode: 1360/1500, epsilon: 0.01, score: 199
# Episode: 1361/1500, epsilon: 0.01, score: 199
# Episode: 1362/1500, epsilon: 0.01, score: 11
# Episode: 1363/1500, epsilon: 0.01, score: 199
# Episode: 1364/1500, epsilon: 0.01, score: 12
# Episode: 1365/1500, epsilon: 0.01, score: 199
# Episode: 1366/1500, epsilon: 0.01, score: 199
# Episode: 1367/1500, epsilon: 0.01, score: 199
# Episode: 1368/1500, epsilon: 0.01, score: 199
# Episode: 1369/1500, epsilon: 0.01, score: 199
# Episode: 1370/1500, epsilon: 0.01, score: 199
# Episode: 1371/1500, epsilon: 0.01, score: 199
# Episode: 1372/1500, epsilon: 0.01, score: 199
# Episode: 1373/1500, epsilon: 0.01, score: 199
# Episode: 1374/1500, epsilon: 0.01, score: 199
# Episode: 1375/1500, epsilon: 0.01, score: 14
# Episode: 1376/1500, epsilon: 0.01, score: 199
# Episode: 1377/1500, epsilon: 0.01, score: 199
# Episode: 1378/1500, epsilon: 0.01, score: 199
# Episode: 1379/1500, epsilon: 0.01, score: 199
# Episode: 1380/1500, epsilon: 0.01, score: 16
# Episode: 1381/1500, epsilon: 0.01, score: 199
# Episode: 1382/1500, epsilon: 0.01, score: 199
# Episode: 1383/1500, epsilon: 0.01, score: 199
# Episode: 1384/1500, epsilon: 0.01, score: 199
# Episode: 1385/1500, epsilon: 0.01, score: 199
# Episode: 1386/1500, epsilon: 0.01, score: 121
# Episode: 1387/1500, epsilon: 0.01, score: 16
# Episode: 1388/1500, epsilon: 0.01, score: 22
# Episode: 1389/1500, epsilon: 0.01, score: 20
# Episode: 1390/1500, epsilon: 0.01, score: 21
# Episode: 1391/1500, epsilon: 0.01, score: 17
# Episode: 1392/1500, epsilon: 0.01, score: 26
# Episode: 1393/1500, epsilon: 0.01, score: 19
# Episode: 1394/1500, epsilon: 0.01, score: 21
# Episode: 1395/1500, epsilon: 0.01, score: 8
# Episode: 1396/1500, epsilon: 0.01, score: 199
# Episode: 1397/1500, epsilon: 0.01, score: 10
# Episode: 1398/1500, epsilon: 0.01, score: 8
# Episode: 1399/1500, epsilon: 0.01, score: 199
# Episode: 1400/1500, epsilon: 0.01, score: 199
# Episode: 1401/1500, epsilon: 0.01, score: 11
# Episode: 1402/1500, epsilon: 0.01, score: 199
# Episode: 1403/1500, epsilon: 0.01, score: 199
# Episode: 1404/1500, epsilon: 0.01, score: 199
# Episode: 1405/1500, epsilon: 0.01, score: 89
# Episode: 1406/1500, epsilon: 0.01, score: 10
# Episode: 1407/1500, epsilon: 0.01, score: 16
# Episode: 1408/1500, epsilon: 0.01, score: 199
# Episode: 1409/1500, epsilon: 0.01, score: 29
# Episode: 1410/1500, epsilon: 0.01, score: 66
# Episode: 1411/1500, epsilon: 0.01, score: 199
# Episode: 1412/1500, epsilon: 0.01, score: 25
# Episode: 1413/1500, epsilon: 0.01, score: 13
# Episode: 1414/1500, epsilon: 0.01, score: 13
# Episode: 1415/1500, epsilon: 0.01, score: 58
# Episode: 1416/1500, epsilon: 0.01, score: 199
# Episode: 1417/1500, epsilon: 0.01, score: 55
# Episode: 1418/1500, epsilon: 0.01, score: 87
# Episode: 1419/1500, epsilon: 0.01, score: 18
# Episode: 1420/1500, epsilon: 0.01, score: 198
# Episode: 1421/1500, epsilon: 0.01, score: 199
# Episode: 1422/1500, epsilon: 0.01, score: 13
# Episode: 1423/1500, epsilon: 0.01, score: 99
# Episode: 1424/1500, epsilon: 0.01, score: 154
# Episode: 1425/1500, epsilon: 0.01, score: 111
# Episode: 1426/1500, epsilon: 0.01, score: 70
# Episode: 1427/1500, epsilon: 0.01, score: 111
# Episode: 1428/1500, epsilon: 0.01, score: 115
# Episode: 1429/1500, epsilon: 0.01, score: 199
# Episode: 1430/1500, epsilon: 0.01, score: 199
# Episode: 1431/1500, epsilon: 0.01, score: 111
# Episode: 1432/1500, epsilon: 0.01, score: 199
# Episode: 1433/1500, epsilon: 0.01, score: 129
# Episode: 1434/1500, epsilon: 0.01, score: 21
# Episode: 1435/1500, epsilon: 0.01, score: 82
# Episode: 1436/1500, epsilon: 0.01, score: 126
# Episode: 1437/1500, epsilon: 0.01, score: 124
# Episode: 1438/1500, epsilon: 0.01, score: 149
# Episode: 1439/1500, epsilon: 0.01, score: 105
# Episode: 1440/1500, epsilon: 0.01, score: 199
# Episode: 1441/1500, epsilon: 0.01, score: 117
# Episode: 1442/1500, epsilon: 0.01, score: 135
# Episode: 1443/1500, epsilon: 0.01, score: 115
# Episode: 1444/1500, epsilon: 0.01, score: 101
# Episode: 1445/1500, epsilon: 0.01, score: 83
# Episode: 1446/1500, epsilon: 0.01, score: 101
# Episode: 1447/1500, epsilon: 0.01, score: 118
# Episode: 1448/1500, epsilon: 0.01, score: 121
# Episode: 1449/1500, epsilon: 0.01, score: 107
# Episode: 1450/1500, epsilon: 0.01, score: 109
# Episode: 1451/1500, epsilon: 0.01, score: 103
# Episode: 1452/1500, epsilon: 0.01, score: 111
# Episode: 1453/1500, epsilon: 0.01, score: 17
# Episode: 1454/1500, epsilon: 0.01, score: 8
# Episode: 1455/1500, epsilon: 0.01, score: 9
# Episode: 1456/1500, epsilon: 0.01, score: 199
# Episode: 1457/1500, epsilon: 0.01, score: 199
# Episode: 1458/1500, epsilon: 0.01, score: 149
# Episode: 1459/1500, epsilon: 0.01, score: 16
# Episode: 1460/1500, epsilon: 0.01, score: 89
# Episode: 1461/1500, epsilon: 0.01, score: 106
# Episode: 1462/1500, epsilon: 0.01, score: 199
# Episode: 1463/1500, epsilon: 0.01, score: 84
# Episode: 1464/1500, epsilon: 0.01, score: 75
# Episode: 1465/1500, epsilon: 0.01, score: 97
# Episode: 1466/1500, epsilon: 0.01, score: 32
# Episode: 1467/1500, epsilon: 0.01, score: 57
# Episode: 1468/1500, epsilon: 0.01, score: 85
# Episode: 1469/1500, epsilon: 0.01, score: 135
# Episode: 1470/1500, epsilon: 0.01, score: 107
# Episode: 1471/1500, epsilon: 0.01, score: 107
# Episode: 1472/1500, epsilon: 0.01, score: 119
# Episode: 1473/1500, epsilon: 0.01, score: 113
# Episode: 1474/1500, epsilon: 0.01, score: 116
# Episode: 1475/1500, epsilon: 0.01, score: 199
# Episode: 1476/1500, epsilon: 0.01, score: 162
# Episode: 1477/1500, epsilon: 0.01, score: 199
# Episode: 1478/1500, epsilon: 0.01, score: 122
# Episode: 1479/1500, epsilon: 0.01, score: 111
# Episode: 1480/1500, epsilon: 0.01, score: 180
# Episode: 1481/1500, epsilon: 0.01, score: 120
# Episode: 1482/1500, epsilon: 0.01, score: 131
# Episode: 1483/1500, epsilon: 0.01, score: 152
# Episode: 1484/1500, epsilon: 0.01, score: 199
# Episode: 1485/1500, epsilon: 0.01, score: 130
# Episode: 1486/1500, epsilon: 0.01, score: 117
# Episode: 1487/1500, epsilon: 0.01, score: 139
# Episode: 1488/1500, epsilon: 0.01, score: 199
# Episode: 1489/1500, epsilon: 0.01, score: 120
# Episode: 1490/1500, epsilon: 0.01, score: 95
# Episode: 1491/1500, epsilon: 0.01, score: 199
# Episode: 1492/1500, epsilon: 0.01, score: 130
# Episode: 1493/1500, epsilon: 0.01, score: 199
# Episode: 1494/1500, epsilon: 0.01, score: 143
# Episode: 1495/1500, epsilon: 0.01, score: 123
# Episode: 1496/1500, epsilon: 0.01, score: 139
# Episode: 1497/1500, epsilon: 0.01, score: 146
# Episode: 1498/1500, epsilon: 0.01, score: 155
# Episode: 1499/1500, epsilon: 0.01, score: 136

# %% [markdown]
# # Výsledky

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import copy

def analysis(scores, episodesList):
    score1 = copy.copy(scores)
    score2 = copy.copy(scores)
    score3 = copy.copy(scores)

    for i in range (len(scores)):
        if i > 1 and i < (len(scores)-2):
            score1[i] = (scores[i - 2] + scores[i - 1] + scores[i] + scores[i + 1] + scores[i + 2])/5

    for i in range (len(scores)):
        if i > 4 and i < (len(scores)-5):
            score2[i] += scores[i - 5] + scores[i - 4] + scores[i - 3] + scores[i - 2] + scores[i - 1]
            score2[i] += scores[i + 5] + scores[i + 4] + scores[i + 3] + scores[i + 2] + scores[i + 1]
            score2[i] = score2[i]/11

    for i in range (len(scores)):
        if i > 49 and i < (len(scores) - 50):
            for e in range (1,50):
                score3[i] += scores[i - e] + scores[i + e] 
            score3[i] = score3[i]/101      

    plt.plot(episodesList, scores, 'ro')
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Vysledky")
    plt.show()

    plt.plot(scores)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku")
    plt.show()

    plt.plot(score1)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku (filtr - prumer 5-ti prvku)")
    plt.show()

    plt.plot(score2)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 11-cti prvku)")
    plt.show()

    plt.plot(score3)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 101 prvku)")
    plt.show()
    
analysis(scores, episodesList)

# %% [markdown]
# # Hra

# %%
agent.loadNN("./DDQN-CartPole-v0.h5")
observation = env.reset()
scores = []                                # Vycisteni pole pro ulozeni vysledku na analyzu
episodesList = []                          # Vycisteni pole pro ulozeni cisel epizod na analyzu

for g in range (games):
    state = env.reset()
    state = np.reshape(state, [1, stateSize])
    
    state1 = copy.copy(state)
    state2 = copy.copy(state)
    state3 = copy.copy(state)
    
    state = np.concatenate((state, state1))
    state = np.concatenate((state, state2))
    state = np.concatenate((state, state3))

    state = np.expand_dims(state, axis=0)
    
    totalReward = 0
    done = False
    
    while not done:
        #env.render()
        
        action = agent.getAction(state)
        newState, reward, done, info = env.step(action)

        nextState = np.reshape(newState, [1, stateSize])

        temp = copy.copy(nextState)
        
        nextState = np.concatenate((nextState, state1))
        nextState = np.concatenate((nextState, state2))
        nextState = np.concatenate((nextState, state3))
        
        state3 = copy.copy(state2)
        state2 = copy.copy(state1)
        state1 = copy.copy(temp)
        
        nextState = np.expand_dims(nextState, axis=0)
        
        state = nextState

        totalReward += reward
        
    scores.append(totalReward) #ulozeni aktualniho skore
    episodesList.append(g) #ulozeni aktualniho cisla epizody

    print('Game {}/{}, score: {}'.format(g, games, totalReward))

analysis(scores, episodesList)
# Out:
# Game 0/100, score: 171.0
# Game 1/100, score: 175.0
# Game 2/100, score: 178.0
# Game 3/100, score: 176.0
# Game 4/100, score: 173.0
# Game 5/100, score: 174.0
# Game 6/100, score: 176.0
# Game 7/100, score: 176.0
# Game 8/100, score: 178.0
# Game 9/100, score: 178.0
# Game 10/100, score: 177.0
# Game 11/100, score: 173.0
# Game 12/100, score: 177.0
# Game 13/100, score: 169.0
# Game 14/100, score: 168.0
# Game 15/100, score: 180.0
# Game 16/100, score: 169.0
# Game 17/100, score: 174.0
# Game 18/100, score: 183.0
# Game 19/100, score: 167.0
# Game 20/100, score: 174.0
# Game 21/100, score: 178.0
# Game 22/100, score: 175.0
# Game 23/100, score: 170.0
# Game 24/100, score: 169.0
# Game 25/100, score: 169.0
# Game 26/100, score: 173.0
# Game 27/100, score: 168.0
# Game 28/100, score: 185.0
# Game 29/100, score: 167.0
# Game 30/100, score: 170.0
# Game 31/100, score: 178.0
# Game 32/100, score: 179.0
# Game 33/100, score: 171.0
# Game 34/100, score: 177.0
# Game 35/100, score: 167.0
# Game 36/100, score: 170.0
# Game 37/100, score: 183.0
# Game 38/100, score: 182.0
# Game 39/100, score: 178.0
# Game 40/100, score: 183.0
# Game 41/100, score: 171.0
# Game 42/100, score: 169.0
# Game 43/100, score: 173.0
# Game 44/100, score: 181.0
# Game 45/100, score: 170.0
# Game 46/100, score: 173.0
# Game 47/100, score: 186.0
# Game 48/100, score: 176.0
# Game 49/100, score: 172.0
# Game 50/100, score: 167.0
# Game 51/100, score: 184.0
# Game 52/100, score: 166.0
# Game 53/100, score: 180.0
# Game 54/100, score: 171.0
# Game 55/100, score: 165.0
# Game 56/100, score: 182.0
# Game 57/100, score: 167.0
# Game 58/100, score: 162.0
# Game 59/100, score: 181.0
# Game 60/100, score: 175.0
# Game 61/100, score: 175.0
# Game 62/100, score: 175.0
# Game 63/100, score: 178.0
# Game 64/100, score: 181.0
# Game 65/100, score: 176.0
# Game 66/100, score: 176.0
# Game 67/100, score: 165.0
# Game 68/100, score: 165.0
# Game 69/100, score: 180.0
# Game 70/100, score: 167.0
# Game 71/100, score: 186.0
# Game 72/100, score: 172.0
# Game 73/100, score: 161.0
# Game 74/100, score: 176.0
# Game 75/100, score: 180.0
# Game 76/100, score: 163.0
# Game 77/100, score: 174.0
# Game 78/100, score: 168.0
# Game 79/100, score: 174.0
# Game 80/100, score: 180.0
# Game 81/100, score: 173.0
# Game 82/100, score: 175.0
# Game 83/100, score: 164.0
