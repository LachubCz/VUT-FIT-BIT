# %% [markdown]
# # Inicializace

# %%
from collections import deque                # Trida pro ukladani stavu
from __future__ import division              # Deleni realnych cisel (kvuli verzi Pythonu 2.6)

import numpy as np                           # Knihovna pro matematicke operace
import random                                # Knihovna pro nahodny vyber samplu z pameti
import sys                                   # Pro pripojeni knihovny Open AI Gym
sys.path.append('/home/xbucha02/libraries')  # Pripojeni knihovny Open AI Gym
import gym                                   # Knihovna Open AI Gym
#from gym import wrappers                    # Nahravani zaznamu
env = gym.make('Acrobot-v1')             # Konkretni hra z Open AI Gym
actionCount = env.action_space.n             # Pocet vstupu do prostredi
stateSize = env.observation_space.shape[0]   # Pocet vystupu z prostredi
#env = wrappers.Monitor(env, '/home/lachubcz/tmp/cartpole-experiment-1', force=True) #Nahravani zaznamu

#gpuMemoryUsage=1                            # Vyuziti pameti GPU
#import tensorflow as tf                     # Knihovna TensorFlow
#from keras.backend.tensorflow_backend import set_session
#config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = gpuMemoryUsage
#set_session(tf.Session(config=config))

# Parametry
observetime = 500                          # Delka pozorovani
episodes = 1500                            # Pocet epizod
games = 100                                # Pocet her
trainingAfterSucces = 100                  # Pocet trenovani na uspesnem datasetu
scores = []                                # Pole pro ulozeni vysledku na analyzu
episodesList = []                          # Pole pro ulozeni cisel epizod na analyzu
bestScore = 199                            # Promenna pro ukladani nejlepsiho prubezneho vysledku

# %% [markdown]
# # Agent

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import regularizers
from keras import optimizers
from keras import losses
from keras import metrics

class Agent:
    def __init__(self, env):
        self.startEpsilon = 0.25                           # Pravdepodobnost konani nahodneho tahu na zacatku
        self.endEpsilon = 0.01                          # Pravdepodobnost konani nahodneho tahu na konci
        self.currentEpsilon = self.startEpsilon         # Soucasna pravdepodobnost konani nahodneho tahu
        self.epsilonDiminution = 0.995                  # Hodnota snizovani epsilonu
        self.gamma = 0.95                               # Discount faktor
        self.minibatchSize = 32                         # Velikost minibatche
        self.actionCount = env.action_space.n           # Pocet vstupu do prostredi
        self.stateSize = env.observation_space.shape[0] # Pocet vystupu z prostredi
        self.learningRate = 0.005                       # Learning rate
        self.fractionUpdate = 0.125
        self.memorySize = 2000                          # Velikost Replay memory
        self.primaryMemory = deque(maxlen=self.memorySize)
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
        self.net = self.getNN(env)
        self.netTarget = self.getNN(env)
        self.updateTargetNet()

    def getNN(self, env):
        net = Sequential()
        net.add(Dense(32, activation="relu", input_shape=(2,) + env.observation_space.shape ))
        net.add(Flatten())
        net.add(Dense(16, activation="relu"))
        
        net.add(Dense(self.actionCount, activation="linear"))

        net.summary()

        net.compile(loss=losses.mean_squared_error, optimizer=optimizers.Adam(lr=self.learningRate), metrics=['accuracy'])

        return net
    
    def updateTargetNet(self):
        self.netTarget.set_weights(self.net.get_weights())
    
    def updateTargetNetPartially(self):
        weights = self.net.get_weights()
        weightsTarget = self.netTarget.get_weights()
        
        for i in range(len(weightsTarget)):
            weightsTarget[i] = weights[i] * self.fractionUpdate + weightsTarget[i] * (1 - self.fractionUpdate)
            
        self.netTarget.set_weights(weightsTarget)
        
    def rememberPrimMem(self, state, action, reward, nextState, done):
        self.primaryMemory.append((state, action, reward, nextState, done))
    
    def rememberSecMem(self, state, action, reward, nextState, done):
        self.secondaryMemory.append((state, action, reward, nextState, done))
        
    def clearSecMem(self):
        self.secondaryMemory.clear()
        
    def epsilonActulization(self):
        if self.currentEpsilon > self.endEpsilon:
            if (self.currentEpsilon * self.epsilonDiminution) > self.endEpsilon:
                self.currentEpsilon = self.currentEpsilon * self.epsilonDiminution
            else:
                self.currentEpsilon = self.endEpsilon
    
    def getActionWE(self, state):
        if np.random.rand() <= self.currentEpsilon:
            return np.random.randint(0, self.actionCount, size=1)[0]
        else:
            Q = self.net.predict(state)
            return np.argmax(Q)

    def getAction(self, state):
        Q = self.net.predict(state)
        return np.argmax(Q)
    
    def resetSecMem(self):
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
    def resetEpsilon(self):
        self.currentEpsilon = self.startEpsilon
    
    def trainDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize)
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize)
            else:
                return
        else:
            return

        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]

            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]

                target_f[0][action] = reward + self.gamma * np.max(aNet)

            self.net.fit(state, target_f, epochs=1, verbose=0)
                
    def trainDDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        else:
            return
        
        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]
            
            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]
                tNet = self.netTarget.predict(nextState)[0]
                target_f[0][action] = reward + self.gamma * tNet[np.argmax(aNet)]
            
            self.net.fit(state, target_f, epochs=1, verbose=0)
    
    def loadNN(self, name):
        self.net.load_weights(name)

    def saveNN(self, name):
        self.net.save_weights(name)

# %% [markdown]
# # Algoritmus

# %%
import copy
agent = Agent(env) #vytvoreni agenta
    
agent.loadNN("./DDQN-CartPole-v0.h5") #nacteni NN
agent.updateTargetNet() #nacteni NN do netTarget

for eps in range (episodes):
    state = env.reset() #resetovani prostredi
    state = np.reshape(state, [1, stateSize]) #formatovani

    state1 = copy.copy(state)
    #state2 = copy.copy(state)
    #state3 = copy.copy(state)
    
    state = np.concatenate((state, state1))
    #state = np.concatenate((state, state2))
    #state = np.concatenate((state, state3))

    state = np.expand_dims(state, axis=0)
    
    agent.epsilonActulization() #aktualizace epsilon
    
    #env.render()

    for t in range(observetime):

        action = agent.getActionWE(state) #ziskani akce

        newState, reward, done, info = env.step(action) #provedeni akce
        
        nextState = np.reshape(newState, [1, stateSize]) #formatovani
        
        temp = copy.copy(nextState)
        
        nextState = np.concatenate((nextState, state1))
        #nextState = np.concatenate((nextState, state2))
        #nextState = np.concatenate((nextState, state3))
        
        #state3 = copy.copy(state2)
        #state2 = copy.copy(state1)
        state1 = copy.copy(temp)
        
        nextState = np.expand_dims(nextState, axis=0)
        
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do primarni pameti
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do sekundarni pameti
        
        agent.trainDDQN(1) #trenovani na primarni pameti
        
        state = nextState #zmena stavu
        
        if done: #konec epizody
            print("Episode: {}/{}, epsilon: {:.2}, score: {}".format(eps, episodes, agent.currentEpsilon, t))
            #agent.trainDDQN(1)
            scores.append(t) #ulozeni aktualniho skore
            episodesList.append(eps) #ulozeni aktualniho cisla epizody
            
            agent.updateTargetNet() #aktualizace target site
            
            agent.saveNN("./DDQN-CartPole-v0.h5") #ulozeni site
            
            #if t > bestScore: #bylo dosazeno njelepsiho skore
            #    bestScore = t #nove nejlepsi skore
            #    for i in range(trainingAfterSucces): #pocet trenovani
            #        agent.trainDDQN(2) #trenovani na sekundarni pameti
            #    agent.saveNN("./DDQN-CartPole-v0-{}.h5" .format(eps)) #ulozeni site
            #    #agent.resetEpsilon() #resetovani epsilonu
            
            #agent.resetSecMem() #vycisteni sekundarni pameti
            
            break
            
agent.saveNN("./DDQN-CartPole-v0.h5") #ulozeni site
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 2, 32)             224
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 2, 32)             224
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
# Episode: 0/1500, epsilon: 0.25, score: 499
# Episode: 1/1500, epsilon: 0.25, score: 499
# Episode: 2/1500, epsilon: 0.25, score: 499
# Episode: 3/1500, epsilon: 0.25, score: 499
# Episode: 4/1500, epsilon: 0.24, score: 499
# Episode: 5/1500, epsilon: 0.24, score: 499
# Episode: 6/1500, epsilon: 0.24, score: 499
# Episode: 7/1500, epsilon: 0.24, score: 499
# Episode: 8/1500, epsilon: 0.24, score: 499
# Episode: 9/1500, epsilon: 0.24, score: 499
# Episode: 10/1500, epsilon: 0.24, score: 499
# Episode: 11/1500, epsilon: 0.24, score: 499
# Episode: 12/1500, epsilon: 0.23, score: 499
# Episode: 13/1500, epsilon: 0.23, score: 499
# Episode: 14/1500, epsilon: 0.23, score: 499
# Episode: 15/1500, epsilon: 0.23, score: 499
# Episode: 16/1500, epsilon: 0.23, score: 499
# Episode: 17/1500, epsilon: 0.23, score: 499
# Episode: 18/1500, epsilon: 0.23, score: 499
# Episode: 19/1500, epsilon: 0.23, score: 499
# Episode: 20/1500, epsilon: 0.23, score: 499
# Episode: 21/1500, epsilon: 0.22, score: 499
# Episode: 22/1500, epsilon: 0.22, score: 499
# Episode: 23/1500, epsilon: 0.22, score: 499
# Episode: 24/1500, epsilon: 0.22, score: 499
# Episode: 25/1500, epsilon: 0.22, score: 499
# Episode: 26/1500, epsilon: 0.22, score: 499
# Episode: 27/1500, epsilon: 0.22, score: 499
# Episode: 28/1500, epsilon: 0.22, score: 499
# Episode: 29/1500, epsilon: 0.22, score: 499
# Episode: 30/1500, epsilon: 0.21, score: 499
# Episode: 31/1500, epsilon: 0.21, score: 499
# Episode: 32/1500, epsilon: 0.21, score: 499
# Episode: 33/1500, epsilon: 0.21, score: 499
# Episode: 34/1500, epsilon: 0.21, score: 499
# Episode: 35/1500, epsilon: 0.21, score: 499
# Episode: 36/1500, epsilon: 0.21, score: 499
# Episode: 37/1500, epsilon: 0.21, score: 499
# Episode: 38/1500, epsilon: 0.21, score: 499
# Episode: 39/1500, epsilon: 0.2, score: 499
# Episode: 40/1500, epsilon: 0.2, score: 499
# Episode: 41/1500, epsilon: 0.2, score: 376
# Episode: 42/1500, epsilon: 0.2, score: 499
# Episode: 43/1500, epsilon: 0.2, score: 499
# Episode: 44/1500, epsilon: 0.2, score: 499
# Episode: 45/1500, epsilon: 0.2, score: 499
# Episode: 46/1500, epsilon: 0.2, score: 499
# Episode: 47/1500, epsilon: 0.2, score: 499
# Episode: 48/1500, epsilon: 0.2, score: 499
# Episode: 49/1500, epsilon: 0.19, score: 499
# Episode: 50/1500, epsilon: 0.19, score: 499
# Episode: 51/1500, epsilon: 0.19, score: 499
# Episode: 52/1500, epsilon: 0.19, score: 499
# Episode: 53/1500, epsilon: 0.19, score: 377
# Episode: 54/1500, epsilon: 0.19, score: 499
# Episode: 55/1500, epsilon: 0.19, score: 499
# Episode: 56/1500, epsilon: 0.19, score: 499
# Episode: 57/1500, epsilon: 0.19, score: 499
# Episode: 58/1500, epsilon: 0.19, score: 499
# Episode: 59/1500, epsilon: 0.19, score: 499
# Episode: 60/1500, epsilon: 0.18, score: 499
# Episode: 61/1500, epsilon: 0.18, score: 499
# Episode: 62/1500, epsilon: 0.18, score: 499
# Episode: 63/1500, epsilon: 0.18, score: 391
# Episode: 64/1500, epsilon: 0.18, score: 499
# Episode: 65/1500, epsilon: 0.18, score: 499
# Episode: 66/1500, epsilon: 0.18, score: 499
# Episode: 67/1500, epsilon: 0.18, score: 499
# Episode: 68/1500, epsilon: 0.18, score: 499
# Episode: 69/1500, epsilon: 0.18, score: 499
# Episode: 70/1500, epsilon: 0.18, score: 499
# Episode: 71/1500, epsilon: 0.17, score: 499
# Episode: 72/1500, epsilon: 0.17, score: 499
# Episode: 73/1500, epsilon: 0.17, score: 499
# Episode: 74/1500, epsilon: 0.17, score: 499
# Episode: 75/1500, epsilon: 0.17, score: 499
# Episode: 76/1500, epsilon: 0.17, score: 499
# Episode: 77/1500, epsilon: 0.17, score: 499
# Episode: 78/1500, epsilon: 0.17, score: 499
# Episode: 79/1500, epsilon: 0.17, score: 499
# Episode: 80/1500, epsilon: 0.17, score: 499
# Episode: 81/1500, epsilon: 0.17, score: 499
# Episode: 82/1500, epsilon: 0.16, score: 499
# Episode: 83/1500, epsilon: 0.16, score: 499
# Episode: 84/1500, epsilon: 0.16, score: 499
# Episode: 85/1500, epsilon: 0.16, score: 499
# Episode: 86/1500, epsilon: 0.16, score: 499
# Episode: 87/1500, epsilon: 0.16, score: 499
# Episode: 88/1500, epsilon: 0.16, score: 499
# Episode: 89/1500, epsilon: 0.16, score: 391
# Episode: 90/1500, epsilon: 0.16, score: 499
# Episode: 91/1500, epsilon: 0.16, score: 499
# Episode: 92/1500, epsilon: 0.16, score: 499
# Episode: 93/1500, epsilon: 0.16, score: 499
# Episode: 94/1500, epsilon: 0.16, score: 499
# Episode: 95/1500, epsilon: 0.15, score: 499
# Episode: 96/1500, epsilon: 0.15, score: 499
# Episode: 97/1500, epsilon: 0.15, score: 499
# Episode: 98/1500, epsilon: 0.15, score: 499
# Episode: 99/1500, epsilon: 0.15, score: 499
# Episode: 100/1500, epsilon: 0.15, score: 499
# Episode: 101/1500, epsilon: 0.15, score: 499
# Episode: 102/1500, epsilon: 0.15, score: 499
# Episode: 103/1500, epsilon: 0.15, score: 492
# Episode: 104/1500, epsilon: 0.15, score: 499
# Episode: 105/1500, epsilon: 0.15, score: 499
# Episode: 106/1500, epsilon: 0.15, score: 499
# Episode: 107/1500, epsilon: 0.15, score: 499
# Episode: 108/1500, epsilon: 0.14, score: 499
# Episode: 109/1500, epsilon: 0.14, score: 499
# Episode: 110/1500, epsilon: 0.14, score: 499
# Episode: 111/1500, epsilon: 0.14, score: 499
# Episode: 112/1500, epsilon: 0.14, score: 499
# Episode: 113/1500, epsilon: 0.14, score: 499
# Episode: 114/1500, epsilon: 0.14, score: 499
# Episode: 115/1500, epsilon: 0.14, score: 499
# Episode: 116/1500, epsilon: 0.14, score: 499
# Episode: 117/1500, epsilon: 0.14, score: 499
# Episode: 118/1500, epsilon: 0.14, score: 499
# Episode: 119/1500, epsilon: 0.14, score: 499
# Episode: 120/1500, epsilon: 0.14, score: 499
# Episode: 121/1500, epsilon: 0.14, score: 499
# Episode: 122/1500, epsilon: 0.13, score: 499
# Episode: 123/1500, epsilon: 0.13, score: 499
# Episode: 124/1500, epsilon: 0.13, score: 499
# Episode: 125/1500, epsilon: 0.13, score: 499
# Episode: 126/1500, epsilon: 0.13, score: 499
# Episode: 127/1500, epsilon: 0.13, score: 499
# Episode: 128/1500, epsilon: 0.13, score: 499
# Episode: 129/1500, epsilon: 0.13, score: 499
# Episode: 130/1500, epsilon: 0.13, score: 499
# Episode: 131/1500, epsilon: 0.13, score: 499
# Episode: 132/1500, epsilon: 0.13, score: 499
# Episode: 133/1500, epsilon: 0.13, score: 499
# Episode: 134/1500, epsilon: 0.13, score: 499
# Episode: 135/1500, epsilon: 0.13, score: 499
# Episode: 136/1500, epsilon: 0.13, score: 402
# Episode: 137/1500, epsilon: 0.13, score: 499
# Episode: 138/1500, epsilon: 0.12, score: 499
# Episode: 139/1500, epsilon: 0.12, score: 499
# Episode: 140/1500, epsilon: 0.12, score: 499
# Episode: 141/1500, epsilon: 0.12, score: 499
# Episode: 142/1500, epsilon: 0.12, score: 499
# Episode: 143/1500, epsilon: 0.12, score: 499
# Episode: 144/1500, epsilon: 0.12, score: 499
# Episode: 145/1500, epsilon: 0.12, score: 499
# Episode: 146/1500, epsilon: 0.12, score: 499
# Episode: 147/1500, epsilon: 0.12, score: 499
# Episode: 148/1500, epsilon: 0.12, score: 499
# Episode: 149/1500, epsilon: 0.12, score: 499
# Episode: 150/1500, epsilon: 0.12, score: 499
# Episode: 151/1500, epsilon: 0.12, score: 499
# Episode: 152/1500, epsilon: 0.12, score: 499
# Episode: 153/1500, epsilon: 0.12, score: 499
# Episode: 154/1500, epsilon: 0.11, score: 499
# Episode: 155/1500, epsilon: 0.11, score: 499
# Episode: 156/1500, epsilon: 0.11, score: 499
# Episode: 157/1500, epsilon: 0.11, score: 499
# Episode: 158/1500, epsilon: 0.11, score: 499
# Episode: 159/1500, epsilon: 0.11, score: 499
# Episode: 160/1500, epsilon: 0.11, score: 499
# Episode: 161/1500, epsilon: 0.11, score: 499
# Episode: 162/1500, epsilon: 0.11, score: 499
# Episode: 163/1500, epsilon: 0.11, score: 499
# Episode: 164/1500, epsilon: 0.11, score: 499
# Episode: 165/1500, epsilon: 0.11, score: 499
# Episode: 166/1500, epsilon: 0.11, score: 499
# Episode: 167/1500, epsilon: 0.11, score: 499
# Episode: 168/1500, epsilon: 0.11, score: 499
# Episode: 169/1500, epsilon: 0.11, score: 499
# Episode: 170/1500, epsilon: 0.11, score: 499
# Episode: 171/1500, epsilon: 0.11, score: 499
# Episode: 172/1500, epsilon: 0.11, score: 499
# Episode: 173/1500, epsilon: 0.1, score: 499
# Episode: 174/1500, epsilon: 0.1, score: 499
# Episode: 175/1500, epsilon: 0.1, score: 499
# Episode: 176/1500, epsilon: 0.1, score: 499
# Episode: 177/1500, epsilon: 0.1, score: 499
# Episode: 178/1500, epsilon: 0.1, score: 499
# Episode: 179/1500, epsilon: 0.1, score: 499
# Episode: 180/1500, epsilon: 0.1, score: 499
# Episode: 181/1500, epsilon: 0.1, score: 499
# Episode: 182/1500, epsilon: 0.1, score: 499
# Episode: 183/1500, epsilon: 0.099, score: 499
# Episode: 184/1500, epsilon: 0.099, score: 499
# Episode: 185/1500, epsilon: 0.098, score: 499
# Episode: 186/1500, epsilon: 0.098, score: 499
# Episode: 187/1500, epsilon: 0.097, score: 499
# Episode: 188/1500, epsilon: 0.097, score: 499
# Episode: 189/1500, epsilon: 0.096, score: 499
# Episode: 190/1500, epsilon: 0.096, score: 499
# Episode: 191/1500, epsilon: 0.095, score: 499
# Episode: 192/1500, epsilon: 0.095, score: 499
# Episode: 193/1500, epsilon: 0.095, score: 499
# Episode: 194/1500, epsilon: 0.094, score: 499
# Episode: 195/1500, epsilon: 0.094, score: 499
# Episode: 196/1500, epsilon: 0.093, score: 499
# Episode: 197/1500, epsilon: 0.093, score: 499
# Episode: 198/1500, epsilon: 0.092, score: 499
# Episode: 199/1500, epsilon: 0.092, score: 499
# Episode: 200/1500, epsilon: 0.091, score: 499
# Episode: 201/1500, epsilon: 0.091, score: 206
# Episode: 202/1500, epsilon: 0.09, score: 499
# Episode: 203/1500, epsilon: 0.09, score: 499
# Episode: 204/1500, epsilon: 0.089, score: 499
# Episode: 205/1500, epsilon: 0.089, score: 499
# Episode: 206/1500, epsilon: 0.089, score: 499
# Episode: 207/1500, epsilon: 0.088, score: 499
# Episode: 208/1500, epsilon: 0.088, score: 499
# Episode: 209/1500, epsilon: 0.087, score: 499
# Episode: 210/1500, epsilon: 0.087, score: 499
# Episode: 211/1500, epsilon: 0.086, score: 151
# Episode: 212/1500, epsilon: 0.086, score: 499
# Episode: 213/1500, epsilon: 0.086, score: 499
# Episode: 214/1500, epsilon: 0.085, score: 499
# Episode: 215/1500, epsilon: 0.085, score: 499
# Episode: 216/1500, epsilon: 0.084, score: 499
# Episode: 217/1500, epsilon: 0.084, score: 499
# Episode: 218/1500, epsilon: 0.083, score: 499
# Episode: 219/1500, epsilon: 0.083, score: 499
# Episode: 220/1500, epsilon: 0.083, score: 499
# Episode: 221/1500, epsilon: 0.082, score: 499
# Episode: 222/1500, epsilon: 0.082, score: 499
# Episode: 223/1500, epsilon: 0.081, score: 499
# Episode: 224/1500, epsilon: 0.081, score: 499
# Episode: 225/1500, epsilon: 0.081, score: 499
# Episode: 226/1500, epsilon: 0.08, score: 499
# Episode: 227/1500, epsilon: 0.08, score: 499
# Episode: 228/1500, epsilon: 0.079, score: 499
# Episode: 229/1500, epsilon: 0.079, score: 499
# Episode: 230/1500, epsilon: 0.079, score: 499
# Episode: 231/1500, epsilon: 0.078, score: 499
# Episode: 232/1500, epsilon: 0.078, score: 489
# Episode: 233/1500, epsilon: 0.077, score: 499
# Episode: 234/1500, epsilon: 0.077, score: 499
# Episode: 235/1500, epsilon: 0.077, score: 499
# Episode: 236/1500, epsilon: 0.076, score: 499
# Episode: 237/1500, epsilon: 0.076, score: 499
# Episode: 238/1500, epsilon: 0.075, score: 302
# Episode: 239/1500, epsilon: 0.075, score: 499
# Episode: 240/1500, epsilon: 0.075, score: 499
# Episode: 241/1500, epsilon: 0.074, score: 499
# Episode: 242/1500, epsilon: 0.074, score: 499
# Episode: 243/1500, epsilon: 0.074, score: 499
# Episode: 244/1500, epsilon: 0.073, score: 499
# Episode: 245/1500, epsilon: 0.073, score: 499
# Episode: 246/1500, epsilon: 0.072, score: 499
# Episode: 247/1500, epsilon: 0.072, score: 499
# Episode: 248/1500, epsilon: 0.072, score: 499
# Episode: 249/1500, epsilon: 0.071, score: 499
# Episode: 250/1500, epsilon: 0.071, score: 499
# Episode: 251/1500, epsilon: 0.071, score: 499
# Episode: 252/1500, epsilon: 0.07, score: 499
# Episode: 253/1500, epsilon: 0.07, score: 499
# Episode: 254/1500, epsilon: 0.07, score: 499
# Episode: 255/1500, epsilon: 0.069, score: 499
# Episode: 256/1500, epsilon: 0.069, score: 499
# Episode: 257/1500, epsilon: 0.069, score: 499
# Episode: 258/1500, epsilon: 0.068, score: 499
# Episode: 259/1500, epsilon: 0.068, score: 499
# Episode: 260/1500, epsilon: 0.068, score: 499
# Episode: 261/1500, epsilon: 0.067, score: 499
# Episode: 262/1500, epsilon: 0.067, score: 499
# Episode: 263/1500, epsilon: 0.067, score: 499
# Episode: 264/1500, epsilon: 0.066, score: 499
# Episode: 265/1500, epsilon: 0.066, score: 499
# Episode: 266/1500, epsilon: 0.066, score: 499
# Episode: 267/1500, epsilon: 0.065, score: 499
# Episode: 268/1500, epsilon: 0.065, score: 499
# Episode: 269/1500, epsilon: 0.065, score: 499
# Episode: 270/1500, epsilon: 0.064, score: 499
# Episode: 271/1500, epsilon: 0.064, score: 499
# Episode: 272/1500, epsilon: 0.064, score: 499
# Episode: 273/1500, epsilon: 0.063, score: 499
# Episode: 274/1500, epsilon: 0.063, score: 499
# Episode: 275/1500, epsilon: 0.063, score: 499
# Episode: 276/1500, epsilon: 0.062, score: 499
# Episode: 277/1500, epsilon: 0.062, score: 499
# Episode: 278/1500, epsilon: 0.062, score: 499
# Episode: 279/1500, epsilon: 0.061, score: 499
# Episode: 280/1500, epsilon: 0.061, score: 499
# Episode: 281/1500, epsilon: 0.061, score: 499
# Episode: 282/1500, epsilon: 0.061, score: 499
# Episode: 283/1500, epsilon: 0.06, score: 499
# Episode: 284/1500, epsilon: 0.06, score: 499
# Episode: 285/1500, epsilon: 0.06, score: 499
# Episode: 286/1500, epsilon: 0.059, score: 499
# Episode: 287/1500, epsilon: 0.059, score: 499
# Episode: 288/1500, epsilon: 0.059, score: 499
# Episode: 289/1500, epsilon: 0.058, score: 499
# Episode: 290/1500, epsilon: 0.058, score: 499
# Episode: 291/1500, epsilon: 0.058, score: 499
# Episode: 292/1500, epsilon: 0.058, score: 499
# Episode: 293/1500, epsilon: 0.057, score: 499
# Episode: 294/1500, epsilon: 0.057, score: 499
# Episode: 295/1500, epsilon: 0.057, score: 499
# Episode: 296/1500, epsilon: 0.056, score: 499
# Episode: 297/1500, epsilon: 0.056, score: 499
# Episode: 298/1500, epsilon: 0.056, score: 499
# Episode: 299/1500, epsilon: 0.056, score: 499
# Episode: 300/1500, epsilon: 0.055, score: 499
# Episode: 301/1500, epsilon: 0.055, score: 499
# Episode: 302/1500, epsilon: 0.055, score: 499
# Episode: 303/1500, epsilon: 0.054, score: 499
# Episode: 304/1500, epsilon: 0.054, score: 499
# Episode: 305/1500, epsilon: 0.054, score: 499
# Episode: 306/1500, epsilon: 0.054, score: 499
# Episode: 307/1500, epsilon: 0.053, score: 499
# Episode: 308/1500, epsilon: 0.053, score: 499
# Episode: 309/1500, epsilon: 0.053, score: 499
# Episode: 310/1500, epsilon: 0.053, score: 499
# Episode: 311/1500, epsilon: 0.052, score: 499
# Episode: 312/1500, epsilon: 0.052, score: 499
# Episode: 313/1500, epsilon: 0.052, score: 499
# Episode: 314/1500, epsilon: 0.052, score: 499
# Episode: 315/1500, epsilon: 0.051, score: 499
# Episode: 316/1500, epsilon: 0.051, score: 499
# Episode: 317/1500, epsilon: 0.051, score: 499
# Episode: 318/1500, epsilon: 0.051, score: 297
# Episode: 319/1500, epsilon: 0.05, score: 499
# Episode: 320/1500, epsilon: 0.05, score: 499
# Episode: 321/1500, epsilon: 0.05, score: 499
# Episode: 322/1500, epsilon: 0.05, score: 499
# Episode: 323/1500, epsilon: 0.049, score: 499
# Episode: 324/1500, epsilon: 0.049, score: 499
# Episode: 325/1500, epsilon: 0.049, score: 499
# Episode: 326/1500, epsilon: 0.049, score: 499
# Episode: 327/1500, epsilon: 0.048, score: 499
# Episode: 328/1500, epsilon: 0.048, score: 499
# Episode: 329/1500, epsilon: 0.048, score: 499
# Episode: 330/1500, epsilon: 0.048, score: 499
# Episode: 331/1500, epsilon: 0.047, score: 499
# Episode: 332/1500, epsilon: 0.047, score: 499
# Episode: 333/1500, epsilon: 0.047, score: 499
# Episode: 334/1500, epsilon: 0.047, score: 499
# Episode: 335/1500, epsilon: 0.046, score: 499
# Episode: 336/1500, epsilon: 0.046, score: 499
# Episode: 337/1500, epsilon: 0.046, score: 499
# Episode: 338/1500, epsilon: 0.046, score: 499
# Episode: 339/1500, epsilon: 0.045, score: 499
# Episode: 340/1500, epsilon: 0.045, score: 499
# Episode: 341/1500, epsilon: 0.045, score: 499
# Episode: 342/1500, epsilon: 0.045, score: 499
# Episode: 343/1500, epsilon: 0.045, score: 499
# Episode: 344/1500, epsilon: 0.044, score: 499
# Episode: 345/1500, epsilon: 0.044, score: 499
# Episode: 346/1500, epsilon: 0.044, score: 499
# Episode: 347/1500, epsilon: 0.044, score: 499
# Episode: 348/1500, epsilon: 0.043, score: 499
# Episode: 349/1500, epsilon: 0.043, score: 499
# Episode: 350/1500, epsilon: 0.043, score: 499
# Episode: 351/1500, epsilon: 0.043, score: 499
# Episode: 352/1500, epsilon: 0.043, score: 499
# Episode: 353/1500, epsilon: 0.042, score: 499
# Episode: 354/1500, epsilon: 0.042, score: 499
# Episode: 355/1500, epsilon: 0.042, score: 499
# Episode: 356/1500, epsilon: 0.042, score: 499
# Episode: 357/1500, epsilon: 0.042, score: 499
# Episode: 358/1500, epsilon: 0.041, score: 499
# Episode: 359/1500, epsilon: 0.041, score: 499
# Episode: 360/1500, epsilon: 0.041, score: 499
# Episode: 361/1500, epsilon: 0.041, score: 499
# Episode: 362/1500, epsilon: 0.041, score: 499
# Episode: 363/1500, epsilon: 0.04, score: 499
# Episode: 364/1500, epsilon: 0.04, score: 499
# Episode: 365/1500, epsilon: 0.04, score: 499
# Episode: 366/1500, epsilon: 0.04, score: 499
# Episode: 367/1500, epsilon: 0.04, score: 499
# Episode: 368/1500, epsilon: 0.039, score: 499
# Episode: 369/1500, epsilon: 0.039, score: 499
# Episode: 370/1500, epsilon: 0.039, score: 499
# Episode: 371/1500, epsilon: 0.039, score: 499
# Episode: 372/1500, epsilon: 0.039, score: 499
# Episode: 373/1500, epsilon: 0.038, score: 499
# Episode: 374/1500, epsilon: 0.038, score: 499
# Episode: 375/1500, epsilon: 0.038, score: 499
# Episode: 376/1500, epsilon: 0.038, score: 499
# Episode: 377/1500, epsilon: 0.038, score: 499
# Episode: 378/1500, epsilon: 0.037, score: 499
# Episode: 379/1500, epsilon: 0.037, score: 499
# Episode: 380/1500, epsilon: 0.037, score: 499
# Episode: 381/1500, epsilon: 0.037, score: 499
# Episode: 382/1500, epsilon: 0.037, score: 499
# Episode: 383/1500, epsilon: 0.036, score: 499
# Episode: 384/1500, epsilon: 0.036, score: 499
# Episode: 385/1500, epsilon: 0.036, score: 499
# Episode: 386/1500, epsilon: 0.036, score: 499
# Episode: 387/1500, epsilon: 0.036, score: 499
# Episode: 388/1500, epsilon: 0.036, score: 499
# Episode: 389/1500, epsilon: 0.035, score: 499
# Episode: 390/1500, epsilon: 0.035, score: 499
# Episode: 391/1500, epsilon: 0.035, score: 499
# Episode: 392/1500, epsilon: 0.035, score: 499
# Episode: 393/1500, epsilon: 0.035, score: 499
# Episode: 394/1500, epsilon: 0.035, score: 499
# Episode: 395/1500, epsilon: 0.034, score: 499
# Episode: 396/1500, epsilon: 0.034, score: 499
# Episode: 397/1500, epsilon: 0.034, score: 499
# Episode: 398/1500, epsilon: 0.034, score: 499
# Episode: 399/1500, epsilon: 0.034, score: 499
# Episode: 400/1500, epsilon: 0.033, score: 499
# Episode: 401/1500, epsilon: 0.033, score: 499
# Episode: 402/1500, epsilon: 0.033, score: 380
# Episode: 403/1500, epsilon: 0.033, score: 499
# Episode: 404/1500, epsilon: 0.033, score: 499
# Episode: 405/1500, epsilon: 0.033, score: 499
# Episode: 406/1500, epsilon: 0.033, score: 499
# Episode: 407/1500, epsilon: 0.032, score: 499
# Episode: 408/1500, epsilon: 0.032, score: 499
# Episode: 409/1500, epsilon: 0.032, score: 499
# Episode: 410/1500, epsilon: 0.032, score: 499
# Episode: 411/1500, epsilon: 0.032, score: 499
# Episode: 412/1500, epsilon: 0.032, score: 499
# Episode: 413/1500, epsilon: 0.031, score: 499
# Episode: 414/1500, epsilon: 0.031, score: 499
# Episode: 415/1500, epsilon: 0.031, score: 499
# Episode: 416/1500, epsilon: 0.031, score: 499
# Episode: 417/1500, epsilon: 0.031, score: 499
# Episode: 418/1500, epsilon: 0.031, score: 499
# Episode: 419/1500, epsilon: 0.03, score: 499
# Episode: 420/1500, epsilon: 0.03, score: 499
# Episode: 421/1500, epsilon: 0.03, score: 499
# Episode: 422/1500, epsilon: 0.03, score: 499
# Episode: 423/1500, epsilon: 0.03, score: 499
# Episode: 424/1500, epsilon: 0.03, score: 499
# Episode: 425/1500, epsilon: 0.03, score: 499
# Episode: 426/1500, epsilon: 0.029, score: 499
# Episode: 427/1500, epsilon: 0.029, score: 499
# Episode: 428/1500, epsilon: 0.029, score: 499
# Episode: 429/1500, epsilon: 0.029, score: 499
# Episode: 430/1500, epsilon: 0.029, score: 499
# Episode: 431/1500, epsilon: 0.029, score: 499
# Episode: 432/1500, epsilon: 0.029, score: 499
# Episode: 433/1500, epsilon: 0.028, score: 499
# Episode: 434/1500, epsilon: 0.028, score: 499
# Episode: 435/1500, epsilon: 0.028, score: 499
# Episode: 436/1500, epsilon: 0.028, score: 499
# Episode: 437/1500, epsilon: 0.028, score: 499
# Episode: 438/1500, epsilon: 0.028, score: 499
# Episode: 439/1500, epsilon: 0.028, score: 499
# Episode: 440/1500, epsilon: 0.027, score: 499
# Episode: 441/1500, epsilon: 0.027, score: 499
# Episode: 442/1500, epsilon: 0.027, score: 499
# Episode: 443/1500, epsilon: 0.027, score: 499
# Episode: 444/1500, epsilon: 0.027, score: 499
# Episode: 445/1500, epsilon: 0.027, score: 499
# Episode: 446/1500, epsilon: 0.027, score: 499
# Episode: 447/1500, epsilon: 0.026, score: 499
# Episode: 448/1500, epsilon: 0.026, score: 499
# Episode: 449/1500, epsilon: 0.026, score: 499
# Episode: 450/1500, epsilon: 0.026, score: 499
# Episode: 451/1500, epsilon: 0.026, score: 499
# Episode: 452/1500, epsilon: 0.026, score: 499
# Episode: 453/1500, epsilon: 0.026, score: 499
# Episode: 454/1500, epsilon: 0.026, score: 499
# Episode: 455/1500, epsilon: 0.025, score: 499
# Episode: 456/1500, epsilon: 0.025, score: 499
# Episode: 457/1500, epsilon: 0.025, score: 499
# Episode: 458/1500, epsilon: 0.025, score: 499
# Episode: 459/1500, epsilon: 0.025, score: 499
# Episode: 460/1500, epsilon: 0.025, score: 499
# Episode: 461/1500, epsilon: 0.025, score: 499
# Episode: 462/1500, epsilon: 0.025, score: 499
# Episode: 463/1500, epsilon: 0.024, score: 499
# Episode: 464/1500, epsilon: 0.024, score: 499
# Episode: 465/1500, epsilon: 0.024, score: 499
# Episode: 466/1500, epsilon: 0.024, score: 499
# Episode: 467/1500, epsilon: 0.024, score: 499
# Episode: 468/1500, epsilon: 0.024, score: 499
# Episode: 469/1500, epsilon: 0.024, score: 499
# Episode: 470/1500, epsilon: 0.024, score: 499
# Episode: 471/1500, epsilon: 0.023, score: 499
# Episode: 472/1500, epsilon: 0.023, score: 499
# Episode: 473/1500, epsilon: 0.023, score: 499
# Episode: 474/1500, epsilon: 0.023, score: 499
# Episode: 475/1500, epsilon: 0.023, score: 499
# Episode: 476/1500, epsilon: 0.023, score: 499
# Episode: 477/1500, epsilon: 0.023, score: 499
# Episode: 478/1500, epsilon: 0.023, score: 499
# Episode: 479/1500, epsilon: 0.023, score: 499
# Episode: 480/1500, epsilon: 0.022, score: 499
# Episode: 481/1500, epsilon: 0.022, score: 499
# Episode: 482/1500, epsilon: 0.022, score: 499
# Episode: 483/1500, epsilon: 0.022, score: 499
# Episode: 484/1500, epsilon: 0.022, score: 499
# Episode: 485/1500, epsilon: 0.022, score: 499
# Episode: 486/1500, epsilon: 0.022, score: 499
# Episode: 487/1500, epsilon: 0.022, score: 499
# Episode: 488/1500, epsilon: 0.022, score: 499
# Episode: 489/1500, epsilon: 0.021, score: 499
# Episode: 490/1500, epsilon: 0.021, score: 499
# Episode: 491/1500, epsilon: 0.021, score: 499
# Episode: 492/1500, epsilon: 0.021, score: 499
# Episode: 493/1500, epsilon: 0.021, score: 499
# Episode: 494/1500, epsilon: 0.021, score: 499
# Episode: 495/1500, epsilon: 0.021, score: 499
# Episode: 496/1500, epsilon: 0.021, score: 499
# Episode: 497/1500, epsilon: 0.021, score: 499
# Episode: 498/1500, epsilon: 0.02, score: 499
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1bfbdaf12eb2> in <module>()
#      46         agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do sekundarni pameti
#      47
# ---> 48         agent.trainDDQN(1) #trenovani na primarni pameti
#      49
#      50         state = nextState #zmena stavu
#
# <ipython-input-5-e9ab2c889181> in trainDDQN(self, typeOfMem)
#     144             else:
#     145                 aNet = self.net.predict(nextState)[0]
# --> 146                 tNet = self.netTarget.predict(nextState)[0]
#     147                 target_f[0][action] = reward + self.gamma * tNet[np.argmax(aNet)]
#     148
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     911         if not self.built:
#     912             self.build()
# --> 913         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     914
#     915     def predict_on_batch(self, x):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1711         f = self.predict_function
#    1712         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1713                                   verbose=verbose, steps=steps)
#    1714
#    1715     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1267                 else:
#    1268                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1269                 batch_outs = f(ins_batch)
#    1270                 if not isinstance(batch_outs, list):
#    1271                     batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # Výsledky

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import copy

def analysis(scores, episodesList):
    score1 = copy.copy(scores)
    score2 = copy.copy(scores)
    score3 = copy.copy(scores)

    for i in range (len(scores)):
        if i > 1 and i < (len(scores)-2):
            score1[i] = (scores[i - 2] + scores[i - 1] + scores[i] + scores[i + 1] + scores[i + 2])/5

    for i in range (len(scores)):
        if i > 4 and i < (len(scores)-5):
            score2[i] += scores[i - 5] + scores[i - 4] + scores[i - 3] + scores[i - 2] + scores[i - 1]
            score2[i] += scores[i + 5] + scores[i + 4] + scores[i + 3] + scores[i + 2] + scores[i + 1]
            score2[i] = score2[i]/11

    for i in range (len(scores)):
        if i > 49 and i < (len(scores) - 50):
            for e in range (1,50):
                score3[i] += scores[i - e] + scores[i + e] 
            score3[i] = score3[i]/101      

    plt.plot(episodesList, scores, 'ro')
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Vysledky")
    plt.show()

    plt.plot(scores)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku")
    plt.show()

    plt.plot(score1)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku (filtr - prumer 5-ti prvku)")
    plt.show()

    plt.plot(score2)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 11-cti prvku)")
    plt.show()

    plt.plot(score3)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 101 prvku)")
    plt.show()
    
analysis(scores, episodesList)

# %% [markdown]
# # Hra

# %%
agent.loadNN("./DDQN-CartPole-v0.h5")
observation = env.reset()
scores = []                                # Vycisteni pole pro ulozeni vysledku na analyzu
episodesList = []                          # Vycisteni pole pro ulozeni cisel epizod na analyzu

for g in range (games):
    state = env.reset()
    state = np.reshape(state, [1, stateSize])
    
    state1 = copy.copy(state)
    state2 = copy.copy(state)
    state3 = copy.copy(state)
    
    state = np.concatenate((state, state1))
    state = np.concatenate((state, state2))
    state = np.concatenate((state, state3))

    state = np.expand_dims(state, axis=0)
    
    totalReward = 0
    done = False
    
    while not done:
        #env.render()
        
        action = agent.getAction(state)
        newState, reward, done, info = env.step(action)

        nextState = np.reshape(newState, [1, stateSize])

        temp = copy.copy(nextState)
        
        nextState = np.concatenate((nextState, state1))
        nextState = np.concatenate((nextState, state2))
        nextState = np.concatenate((nextState, state3))
        
        state3 = copy.copy(state2)
        state2 = copy.copy(state1)
        state1 = copy.copy(temp)
        
        nextState = np.expand_dims(nextState, axis=0)
        
        state = nextState

        totalReward += reward
        
    scores.append(totalReward) #ulozeni aktualniho skore
    episodesList.append(g) #ulozeni aktualniho cisla epizody

    print('Game {}/{}, score: {}'.format(g, games, totalReward))

analysis(scores, episodesList)
