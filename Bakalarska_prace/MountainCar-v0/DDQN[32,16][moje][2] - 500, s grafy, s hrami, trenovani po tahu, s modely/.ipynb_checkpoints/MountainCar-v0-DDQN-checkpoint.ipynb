# %% [markdown]
# # Inicializace

# %%
from collections import deque                # Trida pro ukladani stavu
from __future__ import division              # Deleni realnych cisel (kvuli verzi Pythonu 2.6)

import numpy as np                           # Knihovna pro matematicke operace
import random                                # Knihovna pro nahodny vyber samplu z pameti
import sys                                   # Pro pripojeni knihovny Open AI Gym
sys.path.append('/home/xbucha02/libraries')  # Pripojeni knihovny Open AI Gym
import gym                                   # Knihovna Open AI Gym
#from gym import wrappers                    # Nahravani zaznamu
env = gym.make('MountainCar-v0')             # Konkretni hra z Open AI Gym
actionCount = env.action_space.n             # Pocet vstupu do prostredi
stateSize = env.observation_space.shape[0]   # Pocet vystupu z prostredi
#env = wrappers.Monitor(env, '/home/lachubcz/tmp/cartpole-experiment-1', force=True) #Nahravani zaznamu

#gpuMemoryUsage=1                            # Vyuziti pameti GPU
#import tensorflow as tf                     # Knihovna TensorFlow
#from keras.backend.tensorflow_backend import set_session
#config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = gpuMemoryUsage
#set_session(tf.Session(config=config))

# Parametry
observetime = 500                          # Delka pozorovani
episodes = 500                             # Pocet epizod
games = 500                                # Pocet her
trainingAfterSucces = 100                  # Pocet trenovani na uspesnem datasetu
scores = []                                # Pole pro ulozeni vysledku na analyzu
episodesList = []                          # Pole pro ulozeni cisel epizod na analyzu
bestScore = 199                            # Promenna pro ukladani nejlepsiho prubezneho vysledku

# %% [markdown]
# # Agent

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import regularizers
from keras import optimizers
from keras import losses
from keras import metrics

class Agent:
    def __init__(self, env):
        self.startEpsilon = 1                           # Pravdepodobnost konani nahodneho tahu na zacatku
        self.endEpsilon = 0.01                          # Pravdepodobnost konani nahodneho tahu na konci
        self.currentEpsilon = self.startEpsilon         # Soucasna pravdepodobnost konani nahodneho tahu
        self.epsilonDiminution = 0.995                  # Hodnota snizovani epsilonu
        self.gamma = 0.99                               # Discount faktor
        self.minibatchSize = 32                         # Velikost minibatche
        self.actionCount = env.action_space.n           # Pocet vstupu do prostredi
        self.stateSize = env.observation_space.shape[0] # Pocet vystupu z prostredi
        self.learningRate = 0.005                       # Learning rate
        self.fractionUpdate = 0.125
        self.memorySize = 2000                          # Velikost Replay memory
        self.primaryMemory = deque(maxlen=self.memorySize)
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
        self.net = self.getNN()
        self.netTarget = self.getNN()
        self.updateTargetNet()

    def getNN(self):
        net = Sequential()
        net.add(Dense(32, activation="relu", input_dim=self.stateSize))
        net.add(Dense(16, activation="relu"))
        net.add(Dense(self.actionCount, activation="linear"))

        net.summary()

        net.compile(loss=losses.mean_squared_error, optimizer=optimizers.Adam(lr=self.learningRate), metrics=['accuracy'])

        return net
    
    def updateTargetNet(self):
        self.netTarget.set_weights(self.net.get_weights())
    
    def updateTargetNetPartially(self):
        weights = self.net.get_weights()
        weightsTarget = self.netTarget.get_weights()
        
        for i in range(len(weightsTarget)):
            weightsTarget[i] = weights[i] * self.fractionUpdate + weightsTarget[i] * (1 - self.fractionUpdate)
            
        self.netTarget.set_weights(weightsTarget)
        
    def rememberPrimMem(self, state, action, reward, nextState, done):
        self.primaryMemory.append((state, action, reward, nextState, done))
    
    def rememberSecMem(self, state, action, reward, nextState, done):
        self.secondaryMemory.append((state, action, reward, nextState, done))
        
    def clearSecMem(self):
        self.secondaryMemory.clear()
        
    def epsilonActulization(self):
        if self.currentEpsilon > self.endEpsilon:
            if (self.currentEpsilon * self.epsilonDiminution) > self.endEpsilon:
                self.currentEpsilon = self.currentEpsilon * self.epsilonDiminution
            else:
                self.currentEpsilon = self.endEpsilon
    
    def getActionWE(self, state):
        if np.random.rand() <= self.currentEpsilon:
            return np.random.randint(0, self.actionCount, size=1)[0]
        else:
            Q = self.net.predict(state)
            return np.argmax(Q)

    def getAction(self, state):
        Q = self.net.predict(state)
        return np.argmax(Q)
    
    def resetSecMem(self):
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
    def resetEpsilon(self):
        self.currentEpsilon = self.startEpsilon
    
    def trainDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize)
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize)
            else:
                return
        else:
            return

        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]

            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]

                target_f[0][action] = reward + self.gamma * np.max(aNet)

            self.net.fit(state, target_f, epochs=1, verbose=0)
                
    def trainDDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        else:
            return

        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]

            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]
                tNet = self.netTarget.predict(nextState)[0]
                target_f[0][action] = reward + self.gamma * tNet[np.argmax(aNet)]

            self.net.fit(state, target_f, epochs=1, verbose=0)
    
    def loadNN(self, name):
        self.net.load_weights(name)

    def saveNN(self, name):
        self.net.save_weights(name)

# %% [markdown]
# # Algoritmus

# %%
agent = Agent(env) #vytvoreni agenta
    
#agent.loadNN("./DDQN-MountainCar-v0.h5") #nacteni NN
#agent.updateTargetNet() #nacteni NN do netTarget

for eps in range (episodes):
    state = env.reset() #resetovani prostredi
    state = np.reshape(state, [1, stateSize]) #formatovani
    
    #env.render()

    for t in range(observetime):

        agent.epsilonActulization() #aktualizace epsilon
            
        action = agent.getActionWE(state) #ziskani akce

        newState, reward, done, info = env.step(action) #provedeni akce
        
        nextState = np.reshape(newState, [1, stateSize]) #formatovani

        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do primarni pameti
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do sekundarni pameti
        
        agent.trainDDQN(1) #trenovani na primarni pameti
        
        state = nextState #zmena stavu
        
        if done: #konec epizody
            print("Episode: {}/{}, epsilon: {:.2}, score: {}".format(eps, episodes, agent.currentEpsilon, t))
            
            scores.append(t) #ulozeni aktualniho skore
            episodesList.append(eps) #ulozeni aktualniho cisla epizody
            
            agent.updateTargetNet() #aktualizace target site
            
            if t < bestScore: #bylo dosazeno njelepsiho skore
                bestScore = t #nove nejlepsi skore
                for i in range(trainingAfterSucces): #pocet trenovani
                    agent.trainDDQN(2) #trenovani na sekundarni pameti
                agent.saveNN("./DDQN-MountainCar-v0-{}(1).h5" .format(eps)) #ulozeni site
                agent.resetEpsilon() #resetovani epsilonu
            
            agent.resetSecMem() #vycisteni sekundarni pameti
            
            break
            
agent.saveNN("./DDQN-MountainCar-v0(1).h5") #ulozeni site
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 32)                96
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 675
# Trainable params: 675
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 32)                96
# _________________________________________________________________
# dense_17 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 675
# Trainable params: 675
# Non-trainable params: 0
# _________________________________________________________________
# Episode: 0/500, epsilon: 0.37, score: 199
# Episode: 1/500, epsilon: 0.13, score: 199
# Episode: 2/500, epsilon: 0.049, score: 199
# Episode: 3/500, epsilon: 0.018, score: 199
# Episode: 4/500, epsilon: 0.01, score: 199
# Episode: 5/500, epsilon: 0.01, score: 199
# Episode: 6/500, epsilon: 0.01, score: 199
# Episode: 7/500, epsilon: 0.01, score: 199
# Episode: 8/500, epsilon: 0.01, score: 199
# Episode: 9/500, epsilon: 0.01, score: 199
# Episode: 10/500, epsilon: 0.01, score: 199
# Episode: 11/500, epsilon: 0.01, score: 199
# Episode: 12/500, epsilon: 0.01, score: 199
# Episode: 13/500, epsilon: 0.01, score: 199
# Episode: 14/500, epsilon: 0.01, score: 199
# Episode: 15/500, epsilon: 0.01, score: 199
# Episode: 16/500, epsilon: 0.01, score: 199
# Episode: 17/500, epsilon: 0.01, score: 199
# Episode: 18/500, epsilon: 0.01, score: 199
# Episode: 19/500, epsilon: 0.01, score: 199
# Episode: 20/500, epsilon: 0.01, score: 199
# Episode: 21/500, epsilon: 0.01, score: 199
# Episode: 22/500, epsilon: 0.01, score: 199
# Episode: 23/500, epsilon: 0.01, score: 199
# Episode: 24/500, epsilon: 0.01, score: 199
# Episode: 25/500, epsilon: 0.01, score: 199
# Episode: 26/500, epsilon: 0.01, score: 199
# Episode: 27/500, epsilon: 0.01, score: 199
# Episode: 28/500, epsilon: 0.01, score: 199
# Episode: 29/500, epsilon: 0.01, score: 199
# Episode: 30/500, epsilon: 0.01, score: 199
# Episode: 31/500, epsilon: 0.01, score: 199
# Episode: 32/500, epsilon: 0.01, score: 199
# Episode: 33/500, epsilon: 0.01, score: 199
# Episode: 34/500, epsilon: 0.01, score: 199
# Episode: 35/500, epsilon: 0.01, score: 199
# Episode: 36/500, epsilon: 0.01, score: 199
# Episode: 37/500, epsilon: 0.01, score: 199
# Episode: 38/500, epsilon: 0.01, score: 199
# Episode: 39/500, epsilon: 0.01, score: 199
# Episode: 40/500, epsilon: 0.01, score: 199
# Episode: 41/500, epsilon: 0.01, score: 130
# Episode: 42/500, epsilon: 0.37, score: 199
# Episode: 43/500, epsilon: 0.13, score: 199
# Episode: 44/500, epsilon: 0.049, score: 199
# Episode: 45/500, epsilon: 0.018, score: 199
# Episode: 46/500, epsilon: 0.01, score: 199
# Episode: 47/500, epsilon: 0.01, score: 199
# Episode: 48/500, epsilon: 0.01, score: 199
# Episode: 49/500, epsilon: 0.01, score: 199
# Episode: 50/500, epsilon: 0.01, score: 199
# Episode: 51/500, epsilon: 0.01, score: 199
# Episode: 52/500, epsilon: 0.01, score: 199
# Episode: 53/500, epsilon: 0.01, score: 199
# Episode: 54/500, epsilon: 0.01, score: 199
# Episode: 55/500, epsilon: 0.01, score: 199
# Episode: 56/500, epsilon: 0.01, score: 199
# Episode: 57/500, epsilon: 0.01, score: 199
# Episode: 58/500, epsilon: 0.01, score: 199
# Episode: 59/500, epsilon: 0.01, score: 199
# Episode: 60/500, epsilon: 0.01, score: 199
# Episode: 61/500, epsilon: 0.01, score: 199
# Episode: 62/500, epsilon: 0.01, score: 199
# Episode: 63/500, epsilon: 0.01, score: 199
# Episode: 64/500, epsilon: 0.01, score: 199
# Episode: 65/500, epsilon: 0.01, score: 199
# Episode: 66/500, epsilon: 0.01, score: 199
# Episode: 67/500, epsilon: 0.01, score: 199
# Episode: 68/500, epsilon: 0.01, score: 199
# Episode: 69/500, epsilon: 0.01, score: 199
# Episode: 70/500, epsilon: 0.01, score: 199
# Episode: 71/500, epsilon: 0.01, score: 199
# Episode: 72/500, epsilon: 0.01, score: 199
# Episode: 73/500, epsilon: 0.01, score: 199
# Episode: 74/500, epsilon: 0.01, score: 199
# Episode: 75/500, epsilon: 0.01, score: 199
# Episode: 76/500, epsilon: 0.01, score: 199
# Episode: 77/500, epsilon: 0.01, score: 199
# Episode: 78/500, epsilon: 0.01, score: 199
# Episode: 79/500, epsilon: 0.01, score: 199
# Episode: 80/500, epsilon: 0.01, score: 199
# Episode: 81/500, epsilon: 0.01, score: 199
# Episode: 82/500, epsilon: 0.01, score: 199
# Episode: 83/500, epsilon: 0.01, score: 199
# Episode: 84/500, epsilon: 0.01, score: 199
# Episode: 85/500, epsilon: 0.01, score: 199
# Episode: 86/500, epsilon: 0.01, score: 199
# Episode: 87/500, epsilon: 0.01, score: 199
# Episode: 88/500, epsilon: 0.01, score: 199
# Episode: 89/500, epsilon: 0.01, score: 199
# Episode: 90/500, epsilon: 0.01, score: 199
# Episode: 91/500, epsilon: 0.01, score: 199
# Episode: 92/500, epsilon: 0.01, score: 199
# Episode: 93/500, epsilon: 0.01, score: 199
# Episode: 94/500, epsilon: 0.01, score: 199
# Episode: 95/500, epsilon: 0.01, score: 199
# Episode: 96/500, epsilon: 0.01, score: 199
# Episode: 97/500, epsilon: 0.01, score: 199
# Episode: 98/500, epsilon: 0.01, score: 199
# Episode: 99/500, epsilon: 0.01, score: 199
# Episode: 100/500, epsilon: 0.01, score: 199
# Episode: 101/500, epsilon: 0.01, score: 199
# Episode: 102/500, epsilon: 0.01, score: 199
# Episode: 103/500, epsilon: 0.01, score: 199
# Episode: 104/500, epsilon: 0.01, score: 199
# Episode: 105/500, epsilon: 0.01, score: 199
# Episode: 106/500, epsilon: 0.01, score: 199
# Episode: 107/500, epsilon: 0.01, score: 199
# Episode: 108/500, epsilon: 0.01, score: 199
# Episode: 109/500, epsilon: 0.01, score: 199
# Episode: 110/500, epsilon: 0.01, score: 199
# Episode: 111/500, epsilon: 0.01, score: 199
# Episode: 112/500, epsilon: 0.01, score: 199
# Episode: 113/500, epsilon: 0.01, score: 199
# Episode: 114/500, epsilon: 0.01, score: 199
# Episode: 115/500, epsilon: 0.01, score: 199
# Episode: 116/500, epsilon: 0.01, score: 199
# Episode: 117/500, epsilon: 0.01, score: 199
# Episode: 118/500, epsilon: 0.01, score: 199
# Episode: 119/500, epsilon: 0.01, score: 199
# Episode: 120/500, epsilon: 0.01, score: 199
# Episode: 121/500, epsilon: 0.01, score: 159
# Episode: 122/500, epsilon: 0.01, score: 199
# Episode: 123/500, epsilon: 0.01, score: 199
# Episode: 124/500, epsilon: 0.01, score: 199
# Episode: 125/500, epsilon: 0.01, score: 199
# Episode: 126/500, epsilon: 0.01, score: 199
# Episode: 127/500, epsilon: 0.01, score: 199
# Episode: 128/500, epsilon: 0.01, score: 199
# Episode: 129/500, epsilon: 0.01, score: 199
# Episode: 130/500, epsilon: 0.01, score: 199
# Episode: 131/500, epsilon: 0.01, score: 199
# Episode: 132/500, epsilon: 0.01, score: 199
# Episode: 133/500, epsilon: 0.01, score: 199
# Episode: 134/500, epsilon: 0.01, score: 199
# Episode: 135/500, epsilon: 0.01, score: 199
# Episode: 136/500, epsilon: 0.01, score: 199
# Episode: 137/500, epsilon: 0.01, score: 199
# Episode: 138/500, epsilon: 0.01, score: 199
# Episode: 139/500, epsilon: 0.01, score: 199
# Episode: 140/500, epsilon: 0.01, score: 199
# Episode: 141/500, epsilon: 0.01, score: 199
# Episode: 142/500, epsilon: 0.01, score: 199
# Episode: 143/500, epsilon: 0.01, score: 199
# Episode: 144/500, epsilon: 0.01, score: 199
# Episode: 145/500, epsilon: 0.01, score: 199
# Episode: 146/500, epsilon: 0.01, score: 199
# Episode: 147/500, epsilon: 0.01, score: 199
# Episode: 148/500, epsilon: 0.01, score: 199
# Episode: 149/500, epsilon: 0.01, score: 199
# Episode: 150/500, epsilon: 0.01, score: 199
# Episode: 151/500, epsilon: 0.01, score: 199
# Episode: 152/500, epsilon: 0.01, score: 199
# Episode: 153/500, epsilon: 0.01, score: 199
# Episode: 154/500, epsilon: 0.01, score: 199
# Episode: 155/500, epsilon: 0.01, score: 199
# Episode: 156/500, epsilon: 0.01, score: 199
# Episode: 157/500, epsilon: 0.01, score: 199
# Episode: 158/500, epsilon: 0.01, score: 199
# Episode: 159/500, epsilon: 0.01, score: 199
# Episode: 160/500, epsilon: 0.01, score: 199
# Episode: 161/500, epsilon: 0.01, score: 199
# Episode: 162/500, epsilon: 0.01, score: 199
# Episode: 163/500, epsilon: 0.01, score: 199
# Episode: 164/500, epsilon: 0.01, score: 199
# Episode: 165/500, epsilon: 0.01, score: 199
# Episode: 166/500, epsilon: 0.01, score: 199
# Episode: 167/500, epsilon: 0.01, score: 199
# Episode: 168/500, epsilon: 0.01, score: 199
# Episode: 169/500, epsilon: 0.01, score: 199
# Episode: 170/500, epsilon: 0.01, score: 199
# Episode: 171/500, epsilon: 0.01, score: 199
# Episode: 172/500, epsilon: 0.01, score: 199
# Episode: 173/500, epsilon: 0.01, score: 199
# Episode: 174/500, epsilon: 0.01, score: 199
# Episode: 175/500, epsilon: 0.01, score: 199
# Episode: 176/500, epsilon: 0.01, score: 199
# Episode: 177/500, epsilon: 0.01, score: 199
# Episode: 178/500, epsilon: 0.01, score: 199
# Episode: 179/500, epsilon: 0.01, score: 199
# Episode: 180/500, epsilon: 0.01, score: 199
# Episode: 181/500, epsilon: 0.01, score: 199
# Episode: 182/500, epsilon: 0.01, score: 199
# Episode: 183/500, epsilon: 0.01, score: 199
# Episode: 184/500, epsilon: 0.01, score: 199
# Episode: 185/500, epsilon: 0.01, score: 199
# Episode: 186/500, epsilon: 0.01, score: 199
# Episode: 187/500, epsilon: 0.01, score: 199
# Episode: 188/500, epsilon: 0.01, score: 199
# Episode: 189/500, epsilon: 0.01, score: 199
# Episode: 190/500, epsilon: 0.01, score: 199
# Episode: 191/500, epsilon: 0.01, score: 199
# Episode: 192/500, epsilon: 0.01, score: 199
# Episode: 193/500, epsilon: 0.01, score: 199
# Episode: 194/500, epsilon: 0.01, score: 199
# Episode: 195/500, epsilon: 0.01, score: 199
# Episode: 196/500, epsilon: 0.01, score: 199
# Episode: 197/500, epsilon: 0.01, score: 199
# Episode: 198/500, epsilon: 0.01, score: 199
# Episode: 199/500, epsilon: 0.01, score: 199
# Episode: 200/500, epsilon: 0.01, score: 199
# Episode: 201/500, epsilon: 0.01, score: 199
# Episode: 202/500, epsilon: 0.01, score: 199
# Episode: 203/500, epsilon: 0.01, score: 199
# Episode: 204/500, epsilon: 0.01, score: 199
# Episode: 205/500, epsilon: 0.01, score: 199
# Episode: 206/500, epsilon: 0.01, score: 199
# Episode: 207/500, epsilon: 0.01, score: 199
# Episode: 208/500, epsilon: 0.01, score: 199
# Episode: 209/500, epsilon: 0.01, score: 199
# Episode: 210/500, epsilon: 0.01, score: 199
# Episode: 211/500, epsilon: 0.01, score: 199
# Episode: 212/500, epsilon: 0.01, score: 199
# Episode: 213/500, epsilon: 0.01, score: 199
# Episode: 214/500, epsilon: 0.01, score: 199
# Episode: 215/500, epsilon: 0.01, score: 199
# Episode: 216/500, epsilon: 0.01, score: 199
# Episode: 217/500, epsilon: 0.01, score: 199
# Episode: 218/500, epsilon: 0.01, score: 199
# Episode: 219/500, epsilon: 0.01, score: 199
# Episode: 220/500, epsilon: 0.01, score: 199
# Episode: 221/500, epsilon: 0.01, score: 199
# Episode: 222/500, epsilon: 0.01, score: 199
# Episode: 223/500, epsilon: 0.01, score: 199
# Episode: 224/500, epsilon: 0.01, score: 199
# Episode: 225/500, epsilon: 0.01, score: 199
# Episode: 226/500, epsilon: 0.01, score: 199
# Episode: 227/500, epsilon: 0.01, score: 199
# Episode: 228/500, epsilon: 0.01, score: 199
# Episode: 229/500, epsilon: 0.01, score: 199
# Episode: 230/500, epsilon: 0.01, score: 125
# Episode: 231/500, epsilon: 0.37, score: 199
# Episode: 232/500, epsilon: 0.13, score: 199
# Episode: 233/500, epsilon: 0.049, score: 199
# Episode: 234/500, epsilon: 0.018, score: 199
# Episode: 235/500, epsilon: 0.01, score: 199
# Episode: 236/500, epsilon: 0.01, score: 199
# Episode: 237/500, epsilon: 0.01, score: 199
# Episode: 238/500, epsilon: 0.01, score: 199
# Episode: 239/500, epsilon: 0.01, score: 199
# Episode: 240/500, epsilon: 0.01, score: 199
# Episode: 241/500, epsilon: 0.01, score: 199
# Episode: 242/500, epsilon: 0.01, score: 199
# Episode: 243/500, epsilon: 0.01, score: 199
# Episode: 244/500, epsilon: 0.01, score: 199
# Episode: 245/500, epsilon: 0.01, score: 199
# Episode: 246/500, epsilon: 0.01, score: 199
# Episode: 247/500, epsilon: 0.01, score: 199
# Episode: 248/500, epsilon: 0.01, score: 199
# Episode: 249/500, epsilon: 0.01, score: 199
# Episode: 250/500, epsilon: 0.01, score: 199
# Episode: 251/500, epsilon: 0.01, score: 199
# Episode: 252/500, epsilon: 0.01, score: 199
# Episode: 253/500, epsilon: 0.01, score: 199
# Episode: 254/500, epsilon: 0.01, score: 199
# Episode: 255/500, epsilon: 0.01, score: 199
# Episode: 256/500, epsilon: 0.01, score: 199
# Episode: 257/500, epsilon: 0.01, score: 199
# Episode: 258/500, epsilon: 0.01, score: 199
# Episode: 259/500, epsilon: 0.01, score: 199
# Episode: 260/500, epsilon: 0.01, score: 199
# Episode: 261/500, epsilon: 0.01, score: 199
# Episode: 262/500, epsilon: 0.01, score: 199
# Episode: 263/500, epsilon: 0.01, score: 199
# Episode: 264/500, epsilon: 0.01, score: 199
# Episode: 265/500, epsilon: 0.01, score: 199
# Episode: 266/500, epsilon: 0.01, score: 199
# Episode: 267/500, epsilon: 0.01, score: 199
# Episode: 268/500, epsilon: 0.01, score: 199
# Episode: 269/500, epsilon: 0.01, score: 199
# Episode: 270/500, epsilon: 0.01, score: 199
# Episode: 271/500, epsilon: 0.01, score: 199
# Episode: 272/500, epsilon: 0.01, score: 199
# Episode: 273/500, epsilon: 0.01, score: 199
# Episode: 274/500, epsilon: 0.01, score: 199
# Episode: 275/500, epsilon: 0.01, score: 199
# Episode: 276/500, epsilon: 0.01, score: 199
# Episode: 277/500, epsilon: 0.01, score: 199
# Episode: 278/500, epsilon: 0.01, score: 199
# Episode: 279/500, epsilon: 0.01, score: 199
# Episode: 280/500, epsilon: 0.01, score: 199
# Episode: 281/500, epsilon: 0.01, score: 199
# Episode: 282/500, epsilon: 0.01, score: 199
# Episode: 283/500, epsilon: 0.01, score: 199
# Episode: 284/500, epsilon: 0.01, score: 199
# Episode: 285/500, epsilon: 0.01, score: 199
# Episode: 286/500, epsilon: 0.01, score: 199
# Episode: 287/500, epsilon: 0.01, score: 199
# Episode: 288/500, epsilon: 0.01, score: 199
# Episode: 289/500, epsilon: 0.01, score: 199
# Episode: 290/500, epsilon: 0.01, score: 199
# Episode: 291/500, epsilon: 0.01, score: 199
# Episode: 292/500, epsilon: 0.01, score: 199
# Episode: 293/500, epsilon: 0.01, score: 199
# Episode: 294/500, epsilon: 0.01, score: 199
# Episode: 295/500, epsilon: 0.01, score: 199
# Episode: 296/500, epsilon: 0.01, score: 199
# Episode: 297/500, epsilon: 0.01, score: 199
# Episode: 298/500, epsilon: 0.01, score: 199
# Episode: 299/500, epsilon: 0.01, score: 199
# Episode: 300/500, epsilon: 0.01, score: 199
# Episode: 301/500, epsilon: 0.01, score: 199
# Episode: 302/500, epsilon: 0.01, score: 199
# Episode: 303/500, epsilon: 0.01, score: 199
# Episode: 304/500, epsilon: 0.01, score: 199
# Episode: 305/500, epsilon: 0.01, score: 199
# Episode: 306/500, epsilon: 0.01, score: 199
# Episode: 307/500, epsilon: 0.01, score: 199
# Episode: 308/500, epsilon: 0.01, score: 199
# Episode: 309/500, epsilon: 0.01, score: 199
# Episode: 310/500, epsilon: 0.01, score: 199
# Episode: 311/500, epsilon: 0.01, score: 199
# Episode: 312/500, epsilon: 0.01, score: 199
# Episode: 313/500, epsilon: 0.01, score: 199
# Episode: 314/500, epsilon: 0.01, score: 199
# Episode: 315/500, epsilon: 0.01, score: 199
# Episode: 316/500, epsilon: 0.01, score: 199
# Episode: 317/500, epsilon: 0.01, score: 199
# Episode: 318/500, epsilon: 0.01, score: 199
# Episode: 319/500, epsilon: 0.01, score: 199
# Episode: 320/500, epsilon: 0.01, score: 199
# Episode: 321/500, epsilon: 0.01, score: 199
# Episode: 322/500, epsilon: 0.01, score: 199
# Episode: 323/500, epsilon: 0.01, score: 199
# Episode: 324/500, epsilon: 0.01, score: 199
# Episode: 325/500, epsilon: 0.01, score: 199
# Episode: 326/500, epsilon: 0.01, score: 199
# Episode: 327/500, epsilon: 0.01, score: 199
# Episode: 328/500, epsilon: 0.01, score: 199
# Episode: 329/500, epsilon: 0.01, score: 199
# Episode: 330/500, epsilon: 0.01, score: 199
# Episode: 331/500, epsilon: 0.01, score: 199
# Episode: 332/500, epsilon: 0.01, score: 199
# Episode: 333/500, epsilon: 0.01, score: 199
# Episode: 334/500, epsilon: 0.01, score: 199
# Episode: 335/500, epsilon: 0.01, score: 199
# Episode: 336/500, epsilon: 0.01, score: 199
# Episode: 337/500, epsilon: 0.01, score: 199
# Episode: 338/500, epsilon: 0.01, score: 199
# Episode: 339/500, epsilon: 0.01, score: 199
# Episode: 340/500, epsilon: 0.01, score: 199
# Episode: 341/500, epsilon: 0.01, score: 199
# Episode: 342/500, epsilon: 0.01, score: 199
# Episode: 343/500, epsilon: 0.01, score: 199
# Episode: 344/500, epsilon: 0.01, score: 199
# Episode: 345/500, epsilon: 0.01, score: 199
# Episode: 346/500, epsilon: 0.01, score: 199
# Episode: 347/500, epsilon: 0.01, score: 199
# Episode: 348/500, epsilon: 0.01, score: 199
# Episode: 349/500, epsilon: 0.01, score: 199
# Episode: 350/500, epsilon: 0.01, score: 199
# Episode: 351/500, epsilon: 0.01, score: 199
# Episode: 352/500, epsilon: 0.01, score: 199
# Episode: 353/500, epsilon: 0.01, score: 199
# Episode: 354/500, epsilon: 0.01, score: 199
# Episode: 355/500, epsilon: 0.01, score: 199
# Episode: 356/500, epsilon: 0.01, score: 199
# Episode: 357/500, epsilon: 0.01, score: 199
# Episode: 358/500, epsilon: 0.01, score: 199
# Episode: 359/500, epsilon: 0.01, score: 199
# Episode: 360/500, epsilon: 0.01, score: 199
# Episode: 361/500, epsilon: 0.01, score: 199
# Episode: 362/500, epsilon: 0.01, score: 199
# Episode: 363/500, epsilon: 0.01, score: 199
# Episode: 364/500, epsilon: 0.01, score: 199
# Episode: 365/500, epsilon: 0.01, score: 199
# Episode: 366/500, epsilon: 0.01, score: 199
# Episode: 367/500, epsilon: 0.01, score: 199
# Episode: 368/500, epsilon: 0.01, score: 199
# Episode: 369/500, epsilon: 0.01, score: 199
# Episode: 370/500, epsilon: 0.01, score: 199
# Episode: 371/500, epsilon: 0.01, score: 199
# Episode: 372/500, epsilon: 0.01, score: 199
# Episode: 373/500, epsilon: 0.01, score: 199
# Episode: 374/500, epsilon: 0.01, score: 199
# Episode: 375/500, epsilon: 0.01, score: 199
# Episode: 376/500, epsilon: 0.01, score: 199
# Episode: 377/500, epsilon: 0.01, score: 199
# Episode: 378/500, epsilon: 0.01, score: 199
# Episode: 379/500, epsilon: 0.01, score: 199
# Episode: 380/500, epsilon: 0.01, score: 199
# Episode: 381/500, epsilon: 0.01, score: 199
# Episode: 382/500, epsilon: 0.01, score: 199
# Episode: 383/500, epsilon: 0.01, score: 199
# Episode: 384/500, epsilon: 0.01, score: 199
# Episode: 385/500, epsilon: 0.01, score: 199
# Episode: 386/500, epsilon: 0.01, score: 199
# Episode: 387/500, epsilon: 0.01, score: 199
# Episode: 388/500, epsilon: 0.01, score: 199
# Episode: 389/500, epsilon: 0.01, score: 199
# Episode: 390/500, epsilon: 0.01, score: 199
# Episode: 391/500, epsilon: 0.01, score: 199
# Episode: 392/500, epsilon: 0.01, score: 199
# Episode: 393/500, epsilon: 0.01, score: 199
# Episode: 394/500, epsilon: 0.01, score: 199
# Episode: 395/500, epsilon: 0.01, score: 199
# Episode: 396/500, epsilon: 0.01, score: 199
# Episode: 397/500, epsilon: 0.01, score: 199
# Episode: 398/500, epsilon: 0.01, score: 199
# Episode: 399/500, epsilon: 0.01, score: 199
# Episode: 400/500, epsilon: 0.01, score: 199
# Episode: 401/500, epsilon: 0.01, score: 199
# Episode: 402/500, epsilon: 0.01, score: 199
# Episode: 403/500, epsilon: 0.01, score: 199
# Episode: 404/500, epsilon: 0.01, score: 199
# Episode: 405/500, epsilon: 0.01, score: 199
# Episode: 406/500, epsilon: 0.01, score: 199
# Episode: 407/500, epsilon: 0.01, score: 199
# Episode: 408/500, epsilon: 0.01, score: 199
# Episode: 409/500, epsilon: 0.01, score: 199
# Episode: 410/500, epsilon: 0.01, score: 199
# Episode: 411/500, epsilon: 0.01, score: 199
# Episode: 412/500, epsilon: 0.01, score: 199
# Episode: 413/500, epsilon: 0.01, score: 199
# Episode: 414/500, epsilon: 0.01, score: 199
# Episode: 415/500, epsilon: 0.01, score: 199
# Episode: 416/500, epsilon: 0.01, score: 199
# Episode: 417/500, epsilon: 0.01, score: 199
# Episode: 418/500, epsilon: 0.01, score: 199
# Episode: 419/500, epsilon: 0.01, score: 199
# Episode: 420/500, epsilon: 0.01, score: 199
# Episode: 421/500, epsilon: 0.01, score: 199
# Episode: 422/500, epsilon: 0.01, score: 199
# Episode: 423/500, epsilon: 0.01, score: 199
# Episode: 424/500, epsilon: 0.01, score: 199
# Episode: 425/500, epsilon: 0.01, score: 199
# Episode: 426/500, epsilon: 0.01, score: 199
# Episode: 427/500, epsilon: 0.01, score: 199
# Episode: 428/500, epsilon: 0.01, score: 199
# Episode: 429/500, epsilon: 0.01, score: 199
# Episode: 430/500, epsilon: 0.01, score: 199
# Episode: 431/500, epsilon: 0.01, score: 199
# Episode: 432/500, epsilon: 0.01, score: 199
# Episode: 433/500, epsilon: 0.01, score: 199
# Episode: 434/500, epsilon: 0.01, score: 199
# Episode: 435/500, epsilon: 0.01, score: 199
# Episode: 436/500, epsilon: 0.01, score: 199
# Episode: 437/500, epsilon: 0.01, score: 199
# Episode: 438/500, epsilon: 0.01, score: 199
# Episode: 439/500, epsilon: 0.01, score: 199
# Episode: 440/500, epsilon: 0.01, score: 199
# Episode: 441/500, epsilon: 0.01, score: 199
# Episode: 442/500, epsilon: 0.01, score: 199
# Episode: 443/500, epsilon: 0.01, score: 199
# Episode: 444/500, epsilon: 0.01, score: 199
# Episode: 445/500, epsilon: 0.01, score: 199
# Episode: 446/500, epsilon: 0.01, score: 199
# Episode: 447/500, epsilon: 0.01, score: 199
# Episode: 448/500, epsilon: 0.01, score: 199
# Episode: 449/500, epsilon: 0.01, score: 199
# Episode: 450/500, epsilon: 0.01, score: 199
# Episode: 451/500, epsilon: 0.01, score: 199
# Episode: 452/500, epsilon: 0.01, score: 199
# Episode: 453/500, epsilon: 0.01, score: 199
# Episode: 454/500, epsilon: 0.01, score: 199
# Episode: 455/500, epsilon: 0.01, score: 199
# Episode: 456/500, epsilon: 0.01, score: 199
# Episode: 457/500, epsilon: 0.01, score: 199
# Episode: 458/500, epsilon: 0.01, score: 199
# Episode: 459/500, epsilon: 0.01, score: 199
# Episode: 460/500, epsilon: 0.01, score: 199
# Episode: 461/500, epsilon: 0.01, score: 199
# Episode: 462/500, epsilon: 0.01, score: 199
# Episode: 463/500, epsilon: 0.01, score: 199
# Episode: 464/500, epsilon: 0.01, score: 199
# Episode: 465/500, epsilon: 0.01, score: 199
# Episode: 466/500, epsilon: 0.01, score: 199
# Episode: 467/500, epsilon: 0.01, score: 199
# Episode: 468/500, epsilon: 0.01, score: 199
# Episode: 469/500, epsilon: 0.01, score: 199
# Episode: 470/500, epsilon: 0.01, score: 199
# Episode: 471/500, epsilon: 0.01, score: 199
# Episode: 472/500, epsilon: 0.01, score: 199
# Episode: 473/500, epsilon: 0.01, score: 199
# Episode: 474/500, epsilon: 0.01, score: 199
# Episode: 475/500, epsilon: 0.01, score: 199
# Episode: 476/500, epsilon: 0.01, score: 199
# Episode: 477/500, epsilon: 0.01, score: 199
# Episode: 478/500, epsilon: 0.01, score: 199
# Episode: 479/500, epsilon: 0.01, score: 199
# Episode: 480/500, epsilon: 0.01, score: 199
# Episode: 481/500, epsilon: 0.01, score: 199
# Episode: 482/500, epsilon: 0.01, score: 199
# Episode: 483/500, epsilon: 0.01, score: 199
# Episode: 484/500, epsilon: 0.01, score: 199
# Episode: 485/500, epsilon: 0.01, score: 199
# Episode: 486/500, epsilon: 0.01, score: 199
# Episode: 487/500, epsilon: 0.01, score: 199
# Episode: 488/500, epsilon: 0.01, score: 199
# Episode: 489/500, epsilon: 0.01, score: 199
# Episode: 490/500, epsilon: 0.01, score: 199
# Episode: 491/500, epsilon: 0.01, score: 199
# Episode: 492/500, epsilon: 0.01, score: 199
# Episode: 493/500, epsilon: 0.01, score: 199
# Episode: 494/500, epsilon: 0.01, score: 199
# Episode: 495/500, epsilon: 0.01, score: 199
# Episode: 496/500, epsilon: 0.01, score: 199
# Episode: 497/500, epsilon: 0.01, score: 199
# Episode: 498/500, epsilon: 0.01, score: 199
# Episode: 499/500, epsilon: 0.01, score: 199

# %% [markdown]
# # Výsledky

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import copy

def analysis(scores, episodesList):
    score1 = copy.copy(scores)
    score2 = copy.copy(scores)
    score3 = copy.copy(scores)

    for i in range (len(scores)):
        if i > 1 and i < (len(scores)-2):
            score1[i] = (scores[i - 2] + scores[i - 1] + scores[i] + scores[i + 1] + scores[i + 2])/5

    for i in range (len(scores)):
        if i > 4 and i < (len(scores)-5):
            score2[i] += scores[i - 5] + scores[i - 4] + scores[i - 3] + scores[i - 2] + scores[i - 1]
            score2[i] += scores[i + 5] + scores[i + 4] + scores[i + 3] + scores[i + 2] + scores[i + 1]
            score2[i] = score2[i]/11

    for i in range (len(scores)):
        if i > 49 and i < (len(scores) - 50):
            for e in range (1,50):
                score3[i] += scores[i - e] + scores[i + e] 
            score3[i] = score3[i]/101      

    plt.plot(episodesList, scores, 'ro')
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Vysledky")
    plt.show()

    plt.plot(scores)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku")
    plt.show()

    plt.plot(score1)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku (filtr - prumer 5-ti prvku)")
    plt.show()

    plt.plot(score2)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 11-cti prvku)")
    plt.show()

    plt.plot(score3)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 101 prvku)")
    plt.show()
    
analysis(scores, episodesList)

# %% [markdown]
# # Hra

# %%
agent.loadNN("./DDQN-MountainCar-v0(1).h5")
observation = env.reset()
scores = []                                # Vycisteni pole pro ulozeni vysledku na analyzu
episodesList = []                          # Vycisteni pole pro ulozeni cisel epizod na analyzu

for g in range (games):
    state = env.reset()
    state = np.reshape(state, [1, stateSize])
    
    totalReward = 0
    done = False
    
    while not done:
        #env.render()
        
        action = agent.getAction(state)
        newState, reward, done, info = env.step(action)

        nextState = np.reshape(newState, [1, stateSize])
        state = nextState

        totalReward += reward
        
    scores.append(totalReward) #ulozeni aktualniho skore
    episodesList.append(g) #ulozeni aktualniho cisla epizody

    print('Game {}/{}, score: {}'.format(g, games, totalReward))

analysis(scores, episodesList)
# Out:
# Game 0/500, score: -200.0
# Game 1/500, score: -200.0
# Game 2/500, score: -200.0
# Game 3/500, score: -200.0
# Game 4/500, score: -200.0
# Game 5/500, score: -200.0
# Game 6/500, score: -200.0
# Game 7/500, score: -200.0
# Game 8/500, score: -200.0
# Game 9/500, score: -200.0
# Game 10/500, score: -200.0
# Game 11/500, score: -200.0
# Game 12/500, score: -200.0
# Game 13/500, score: -200.0
# Game 14/500, score: -200.0
# Game 15/500, score: -200.0
# Game 16/500, score: -200.0
# Game 17/500, score: -200.0
# Game 18/500, score: -200.0
# Game 19/500, score: -200.0
# Game 20/500, score: -200.0
# Game 21/500, score: -200.0
# Game 22/500, score: -200.0
# Game 23/500, score: -200.0
# Game 24/500, score: -200.0
# Game 25/500, score: -200.0
# Game 26/500, score: -200.0
# Game 27/500, score: -200.0
# Game 28/500, score: -200.0
# Game 29/500, score: -200.0
# Game 30/500, score: -200.0
# Game 31/500, score: -200.0
# Game 32/500, score: -200.0
# Game 33/500, score: -200.0
# Game 34/500, score: -200.0
# Game 35/500, score: -200.0
# Game 36/500, score: -200.0
# Game 37/500, score: -200.0
# Game 38/500, score: -200.0
# Game 39/500, score: -200.0
# Game 40/500, score: -200.0
# Game 41/500, score: -200.0
# Game 42/500, score: -200.0
# Game 43/500, score: -200.0
# Game 44/500, score: -200.0
# Game 45/500, score: -200.0
# Game 46/500, score: -200.0
# Game 47/500, score: -200.0
# Game 48/500, score: -200.0
# Game 49/500, score: -200.0
# Game 50/500, score: -200.0
# Game 51/500, score: -200.0
# Game 52/500, score: -200.0
# Game 53/500, score: -200.0
# Game 54/500, score: -200.0
# Game 55/500, score: -200.0
# Game 56/500, score: -200.0
# Game 57/500, score: -200.0
# Game 58/500, score: -200.0
# Game 59/500, score: -200.0
# Game 60/500, score: -200.0
# Game 61/500, score: -200.0
# Game 62/500, score: -200.0
# Game 63/500, score: -200.0
# Game 64/500, score: -200.0
# Game 65/500, score: -200.0
# Game 66/500, score: -200.0
# Game 67/500, score: -200.0
# Game 68/500, score: -200.0
# Game 69/500, score: -200.0
# Game 70/500, score: -200.0
# Game 71/500, score: -200.0
# Game 72/500, score: -200.0
# Game 73/500, score: -200.0
# Game 74/500, score: -200.0
# Game 75/500, score: -200.0
# Game 76/500, score: -200.0
# Game 77/500, score: -200.0
# Game 78/500, score: -200.0
# Game 79/500, score: -200.0
# Game 80/500, score: -200.0
# Game 81/500, score: -200.0
# Game 82/500, score: -200.0
# Game 83/500, score: -200.0
# Game 84/500, score: -200.0
# Game 85/500, score: -200.0
# Game 86/500, score: -200.0
# Game 87/500, score: -200.0
# Game 88/500, score: -200.0
# Game 89/500, score: -200.0
# Game 90/500, score: -200.0
# Game 91/500, score: -200.0
# Game 92/500, score: -200.0
# Game 93/500, score: -200.0
# Game 94/500, score: -200.0
# Game 95/500, score: -200.0
# Game 96/500, score: -200.0
# Game 97/500, score: -200.0
# Game 98/500, score: -200.0
# Game 99/500, score: -200.0
# Game 100/500, score: -200.0
# Game 101/500, score: -200.0
# Game 102/500, score: -200.0
# Game 103/500, score: -200.0
# Game 104/500, score: -200.0
# Game 105/500, score: -200.0
# Game 106/500, score: -200.0
# Game 107/500, score: -200.0
# Game 108/500, score: -200.0
# Game 109/500, score: -200.0
# Game 110/500, score: -200.0
# Game 111/500, score: -200.0
# Game 112/500, score: -200.0
# Game 113/500, score: -200.0
# Game 114/500, score: -200.0
# Game 115/500, score: -200.0
# Game 116/500, score: -200.0
# Game 117/500, score: -200.0
# Game 118/500, score: -200.0
# Game 119/500, score: -200.0
# Game 120/500, score: -200.0
# Game 121/500, score: -200.0
# Game 122/500, score: -200.0
# Game 123/500, score: -200.0
# Game 124/500, score: -200.0
# Game 125/500, score: -200.0
# Game 126/500, score: -200.0
# Game 127/500, score: -200.0
# Game 128/500, score: -200.0
# Game 129/500, score: -200.0
# Game 130/500, score: -200.0
# Game 131/500, score: -200.0
# Game 132/500, score: -200.0
# Game 133/500, score: -200.0
# Game 134/500, score: -200.0
# Game 135/500, score: -200.0
# Game 136/500, score: -200.0
# Game 137/500, score: -200.0
# Game 138/500, score: -200.0
# Game 139/500, score: -200.0
# Game 140/500, score: -200.0
# Game 141/500, score: -200.0
# Game 142/500, score: -200.0
# Game 143/500, score: -200.0
# Game 144/500, score: -200.0
# Game 145/500, score: -200.0
# Game 146/500, score: -200.0
# Game 147/500, score: -200.0
# Game 148/500, score: -200.0
# Game 149/500, score: -200.0
# Game 150/500, score: -200.0
# Game 151/500, score: -200.0
# Game 152/500, score: -200.0
# Game 153/500, score: -200.0
# Game 154/500, score: -200.0
# Game 155/500, score: -200.0
# Game 156/500, score: -200.0
# Game 157/500, score: -200.0
# Game 158/500, score: -200.0
# Game 159/500, score: -200.0
# Game 160/500, score: -200.0
# Game 161/500, score: -200.0
# Game 162/500, score: -200.0
# Game 163/500, score: -200.0
# Game 164/500, score: -200.0
# Game 165/500, score: -200.0
# Game 166/500, score: -200.0
# Game 167/500, score: -200.0
# Game 168/500, score: -200.0
# Game 169/500, score: -200.0
# Game 170/500, score: -200.0
# Game 171/500, score: -200.0
# Game 172/500, score: -200.0
# Game 173/500, score: -200.0
# Game 174/500, score: -200.0
# Game 175/500, score: -200.0
# Game 176/500, score: -200.0
# Game 177/500, score: -200.0
# Game 178/500, score: -200.0
# Game 179/500, score: -200.0
# Game 180/500, score: -200.0
# Game 181/500, score: -200.0
# Game 182/500, score: -200.0
# Game 183/500, score: -200.0
# Game 184/500, score: -200.0
# Game 185/500, score: -200.0
# Game 186/500, score: -200.0
# Game 187/500, score: -200.0
# Game 188/500, score: -200.0
# Game 189/500, score: -200.0
# Game 190/500, score: -200.0
# Game 191/500, score: -200.0
# Game 192/500, score: -200.0
# Game 193/500, score: -200.0
# Game 194/500, score: -200.0
# Game 195/500, score: -200.0
# Game 196/500, score: -200.0
# Game 197/500, score: -200.0
# Game 198/500, score: -200.0
# Game 199/500, score: -200.0
# Game 200/500, score: -200.0
# Game 201/500, score: -200.0
# Game 202/500, score: -200.0
# Game 203/500, score: -200.0
# Game 204/500, score: -200.0
# Game 205/500, score: -200.0
# Game 206/500, score: -200.0
# Game 207/500, score: -200.0
# Game 208/500, score: -200.0
# Game 209/500, score: -200.0
# Game 210/500, score: -200.0
# Game 211/500, score: -200.0
# Game 212/500, score: -200.0
# Game 213/500, score: -200.0
# Game 214/500, score: -200.0
# Game 215/500, score: -200.0
# Game 216/500, score: -200.0
# Game 217/500, score: -200.0
# Game 218/500, score: -200.0
# Game 219/500, score: -200.0
# Game 220/500, score: -200.0
# Game 221/500, score: -200.0
# Game 222/500, score: -200.0
# Game 223/500, score: -200.0
# Game 224/500, score: -200.0
# Game 225/500, score: -200.0
# Game 226/500, score: -200.0
# Game 227/500, score: -200.0
# Game 228/500, score: -200.0
# Game 229/500, score: -200.0
# Game 230/500, score: -200.0
# Game 231/500, score: -200.0
# Game 232/500, score: -200.0
# Game 233/500, score: -200.0
# Game 234/500, score: -200.0
# Game 235/500, score: -200.0
# Game 236/500, score: -200.0
# Game 237/500, score: -200.0
# Game 238/500, score: -200.0
# Game 239/500, score: -200.0
# Game 240/500, score: -200.0
# Game 241/500, score: -200.0
# Game 242/500, score: -200.0
# Game 243/500, score: -200.0
# Game 244/500, score: -200.0
# Game 245/500, score: -200.0
# Game 246/500, score: -200.0
# Game 247/500, score: -200.0
# Game 248/500, score: -200.0
# Game 249/500, score: -200.0
# Game 250/500, score: -200.0
# Game 251/500, score: -200.0
# Game 252/500, score: -200.0
# Game 253/500, score: -200.0
# Game 254/500, score: -200.0
# Game 255/500, score: -200.0
# Game 256/500, score: -200.0
# Game 257/500, score: -200.0
# Game 258/500, score: -200.0
# Game 259/500, score: -200.0
# Game 260/500, score: -200.0
# Game 261/500, score: -200.0
# Game 262/500, score: -200.0
# Game 263/500, score: -200.0
# Game 264/500, score: -200.0
# Game 265/500, score: -200.0
# Game 266/500, score: -200.0
# Game 267/500, score: -200.0
# Game 268/500, score: -200.0
# Game 269/500, score: -200.0
# Game 270/500, score: -200.0
# Game 271/500, score: -200.0
# Game 272/500, score: -200.0
# Game 273/500, score: -200.0
# Game 274/500, score: -200.0
# Game 275/500, score: -200.0
# Game 276/500, score: -200.0
# Game 277/500, score: -200.0
# Game 278/500, score: -200.0
# Game 279/500, score: -200.0
# Game 280/500, score: -200.0
# Game 281/500, score: -200.0
# Game 282/500, score: -200.0
# Game 283/500, score: -200.0
# Game 284/500, score: -200.0
# Game 285/500, score: -200.0
# Game 286/500, score: -200.0
# Game 287/500, score: -200.0
# Game 288/500, score: -200.0
# Game 289/500, score: -200.0
# Game 290/500, score: -200.0
# Game 291/500, score: -200.0
# Game 292/500, score: -200.0
# Game 293/500, score: -200.0
# Game 294/500, score: -200.0
# Game 295/500, score: -200.0
# Game 296/500, score: -200.0
# Game 297/500, score: -200.0
# Game 298/500, score: -200.0
# Game 299/500, score: -200.0
# Game 300/500, score: -200.0
# Game 301/500, score: -200.0
# Game 302/500, score: -200.0
# Game 303/500, score: -200.0
# Game 304/500, score: -200.0
# Game 305/500, score: -200.0
# Game 306/500, score: -200.0
# Game 307/500, score: -200.0
# Game 308/500, score: -200.0
# Game 309/500, score: -200.0
# Game 310/500, score: -200.0
# Game 311/500, score: -200.0
# Game 312/500, score: -200.0
# Game 313/500, score: -200.0
# Game 314/500, score: -200.0
# Game 315/500, score: -200.0
# Game 316/500, score: -200.0
# Game 317/500, score: -200.0
# Game 318/500, score: -200.0
# Game 319/500, score: -200.0
# Game 320/500, score: -200.0
# Game 321/500, score: -200.0
# Game 322/500, score: -200.0
# Game 323/500, score: -200.0
# Game 324/500, score: -200.0
# Game 325/500, score: -200.0
# Game 326/500, score: -200.0
# Game 327/500, score: -200.0
# Game 328/500, score: -200.0
# Game 329/500, score: -200.0
# Game 330/500, score: -200.0
# Game 331/500, score: -200.0
# Game 332/500, score: -200.0
# Game 333/500, score: -200.0
# Game 334/500, score: -200.0
# Game 335/500, score: -200.0
# Game 336/500, score: -200.0
# Game 337/500, score: -200.0
# Game 338/500, score: -200.0
# Game 339/500, score: -200.0
# Game 340/500, score: -200.0
# Game 341/500, score: -200.0
# Game 342/500, score: -200.0
# Game 343/500, score: -200.0
# Game 344/500, score: -200.0
# Game 345/500, score: -200.0
# Game 346/500, score: -200.0
# Game 347/500, score: -200.0
# Game 348/500, score: -200.0
# Game 349/500, score: -200.0
# Game 350/500, score: -200.0
# Game 351/500, score: -200.0
# Game 352/500, score: -200.0
# Game 353/500, score: -200.0
# Game 354/500, score: -200.0
# Game 355/500, score: -200.0
# Game 356/500, score: -200.0
# Game 357/500, score: -200.0
# Game 358/500, score: -200.0
# Game 359/500, score: -200.0
# Game 360/500, score: -200.0
# Game 361/500, score: -200.0
# Game 362/500, score: -200.0
# Game 363/500, score: -200.0
# Game 364/500, score: -200.0
# Game 365/500, score: -200.0
# Game 366/500, score: -200.0
# Game 367/500, score: -200.0
# Game 368/500, score: -200.0
# Game 369/500, score: -200.0
# Game 370/500, score: -200.0
# Game 371/500, score: -200.0
# Game 372/500, score: -200.0
# Game 373/500, score: -200.0
# Game 374/500, score: -200.0
# Game 375/500, score: -200.0
# Game 376/500, score: -200.0
# Game 377/500, score: -200.0
# Game 378/500, score: -200.0
# Game 379/500, score: -200.0
# Game 380/500, score: -200.0
# Game 381/500, score: -200.0
# Game 382/500, score: -200.0
# Game 383/500, score: -200.0
# Game 384/500, score: -200.0
# Game 385/500, score: -200.0
# Game 386/500, score: -200.0
# Game 387/500, score: -200.0
# Game 388/500, score: -200.0
# Game 389/500, score: -200.0
# Game 390/500, score: -200.0
# Game 391/500, score: -200.0
# Game 392/500, score: -200.0
# Game 393/500, score: -200.0
# Game 394/500, score: -200.0
# Game 395/500, score: -200.0
# Game 396/500, score: -200.0
# Game 397/500, score: -200.0
# Game 398/500, score: -200.0
# Game 399/500, score: -200.0
# Game 400/500, score: -200.0
# Game 401/500, score: -200.0
# Game 402/500, score: -200.0
# Game 403/500, score: -200.0
# Game 404/500, score: -200.0
# Game 405/500, score: -200.0
# Game 406/500, score: -200.0
# Game 407/500, score: -200.0
# Game 408/500, score: -200.0
# Game 409/500, score: -200.0
# Game 410/500, score: -200.0
# Game 411/500, score: -200.0
# Game 412/500, score: -200.0
# Game 413/500, score: -200.0
# Game 414/500, score: -200.0
# Game 415/500, score: -200.0
# Game 416/500, score: -200.0
# Game 417/500, score: -200.0
# Game 418/500, score: -200.0
# Game 419/500, score: -200.0
# Game 420/500, score: -200.0
# Game 421/500, score: -200.0
# Game 422/500, score: -200.0
# Game 423/500, score: -200.0
# Game 424/500, score: -200.0
# Game 425/500, score: -200.0
# Game 426/500, score: -200.0
# Game 427/500, score: -200.0
# Game 428/500, score: -200.0
# Game 429/500, score: -200.0
# Game 430/500, score: -200.0
# Game 431/500, score: -200.0
# Game 432/500, score: -200.0
# Game 433/500, score: -200.0
# Game 434/500, score: -200.0
# Game 435/500, score: -200.0
# Game 436/500, score: -200.0
# Game 437/500, score: -200.0
# Game 438/500, score: -200.0
# Game 439/500, score: -200.0
# Game 440/500, score: -200.0
# Game 441/500, score: -200.0
# Game 442/500, score: -200.0
# Game 443/500, score: -200.0
# Game 444/500, score: -200.0
# Game 445/500, score: -200.0
# Game 446/500, score: -200.0
# Game 447/500, score: -200.0
# Game 448/500, score: -200.0
# Game 449/500, score: -200.0
# Game 450/500, score: -200.0
# Game 451/500, score: -200.0
# Game 452/500, score: -200.0
# Game 453/500, score: -200.0
# Game 454/500, score: -200.0
# Game 455/500, score: -200.0
# Game 456/500, score: -200.0
# Game 457/500, score: -200.0
# Game 458/500, score: -200.0
# Game 459/500, score: -200.0
# Game 460/500, score: -200.0
# Game 461/500, score: -200.0
# Game 462/500, score: -200.0
# Game 463/500, score: -200.0
# Game 464/500, score: -200.0
# Game 465/500, score: -200.0
# Game 466/500, score: -200.0
# Game 467/500, score: -200.0
# Game 468/500, score: -200.0
# Game 469/500, score: -200.0
# Game 470/500, score: -200.0
# Game 471/500, score: -200.0
# Game 472/500, score: -200.0
# Game 473/500, score: -200.0
# Game 474/500, score: -200.0
# Game 475/500, score: -200.0
# Game 476/500, score: -200.0
# Game 477/500, score: -200.0
# Game 478/500, score: -200.0
# Game 479/500, score: -200.0
# Game 480/500, score: -200.0
# Game 481/500, score: -200.0
# Game 482/500, score: -200.0
# Game 483/500, score: -200.0
# Game 484/500, score: -200.0
# Game 485/500, score: -200.0
# Game 486/500, score: -200.0
# Game 487/500, score: -200.0
# Game 488/500, score: -200.0
# Game 489/500, score: -200.0
# Game 490/500, score: -200.0
# Game 491/500, score: -200.0
# Game 492/500, score: -200.0
# Game 493/500, score: -200.0
# Game 494/500, score: -200.0
# Game 495/500, score: -200.0
# Game 496/500, score: -200.0
# Game 497/500, score: -200.0
# Game 498/500, score: -200.0
# Game 499/500, score: -200.0
