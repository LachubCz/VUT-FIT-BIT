# %% [markdown]
# # Inicializace

# %%
from collections import deque                # Trida pro ukladani stavu
from __future__ import division              # Deleni realnych cisel (kvuli verzi Pythonu 2.6)

import numpy as np                           # Knihovna pro matematicke operace
import random                                # Knihovna pro nahodny vyber samplu z pameti
import sys                                   # Pro pripojeni knihovny Open AI Gym
sys.path.append('/home/xbucha02/libraries')  # Pripojeni knihovny Open AI Gym
import gym                                   # Knihovna Open AI Gym
#from gym import wrappers                    # Nahravani zaznamu
env = gym.make('Acrobot-v1')             # Konkretni hra z Open AI Gym
actionCount = env.action_space.n             # Pocet vstupu do prostredi
stateSize = env.observation_space.shape[0]   # Pocet vystupu z prostredi
#env = wrappers.Monitor(env, '/home/lachubcz/tmp/cartpole-experiment-1', force=True) #Nahravani zaznamu

gpuMemoryUsage=0.99                            # Vyuziti pameti GPU
import tensorflow as tf                     # Knihovna TensorFlow
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = gpuMemoryUsage
set_session(tf.Session(config=config))

# Parametry
observetime = 500                          # Delka pozorovani
episodes = 1500                            # Pocet epizod
games = 100                                # Pocet her
trainingAfterSucces = 100                  # Pocet trenovani na uspesnem datasetu
scores = []                                # Pole pro ulozeni vysledku na analyzu
episodesList = []                          # Pole pro ulozeni cisel epizod na analyzu
bestScore = 199                            # Promenna pro ukladani nejlepsiho prubezneho vysledku

# %% [markdown]
# # Agent

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import regularizers
from keras import optimizers
from keras import losses
from keras import metrics

class Agent:
    def __init__(self, env):
        self.startEpsilon = 1                           # Pravdepodobnost konani nahodneho tahu na zacatku
        self.endEpsilon = 0.01                          # Pravdepodobnost konani nahodneho tahu na konci
        self.currentEpsilon = self.startEpsilon         # Soucasna pravdepodobnost konani nahodneho tahu
        self.epsilonDiminution = 0.995                  # Hodnota snizovani epsilonu
        self.gamma = 0.95                               # Discount faktor
        self.minibatchSize = 32                         # Velikost minibatche
        self.actionCount = env.action_space.n           # Pocet vstupu do prostredi
        self.stateSize = env.observation_space.shape[0] # Pocet vystupu z prostredi
        self.learningRate = 0.005                       # Learning rate
        self.fractionUpdate = 0.125
        self.memorySize = 2000                          # Velikost Replay memory
        self.primaryMemory = deque(maxlen=self.memorySize)
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
        self.net = self.getNN(env)
        self.netTarget = self.getNN(env)
        self.updateTargetNet()

    def getNN(self, env):
        net = Sequential()
        net.add(Dense(32, activation="relu", input_shape=(2,) + env.observation_space.shape ))
        net.add(Flatten())
        net.add(Dense(16, activation="relu"))
        
        net.add(Dense(self.actionCount, activation="linear"))

        net.summary()

        net.compile(loss=losses.mean_squared_error, optimizer=optimizers.Adam(lr=self.learningRate), metrics=['accuracy'])

        return net
    
    def updateTargetNet(self):
        self.netTarget.set_weights(self.net.get_weights())
    
    def updateTargetNetPartially(self):
        weights = self.net.get_weights()
        weightsTarget = self.netTarget.get_weights()
        
        for i in range(len(weightsTarget)):
            weightsTarget[i] = weights[i] * self.fractionUpdate + weightsTarget[i] * (1 - self.fractionUpdate)
            
        self.netTarget.set_weights(weightsTarget)
        
    def rememberPrimMem(self, state, action, reward, nextState, done):
        self.primaryMemory.append((state, action, reward, nextState, done))
    
    def rememberSecMem(self, state, action, reward, nextState, done):
        self.secondaryMemory.append((state, action, reward, nextState, done))
        
    def clearSecMem(self):
        self.secondaryMemory.clear()
        
    def epsilonActulization(self):
        if self.currentEpsilon > self.endEpsilon:
            if (self.currentEpsilon * self.epsilonDiminution) > self.endEpsilon:
                self.currentEpsilon = self.currentEpsilon * self.epsilonDiminution
            else:
                self.currentEpsilon = self.endEpsilon
    
    def getActionWE(self, state):
        if np.random.rand() <= self.currentEpsilon:
            return np.random.randint(0, self.actionCount, size=1)[0]
        else:
            Q = self.net.predict(state)
            return np.argmax(Q)

    def getAction(self, state):
        Q = self.net.predict(state)
        return np.argmax(Q)
    
    def resetSecMem(self):
        self.secondaryMemory = deque(maxlen=self.memorySize)
        
    def resetEpsilon(self):
        self.currentEpsilon = self.startEpsilon
    
    def trainDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize)
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize)
            else:
                return
        else:
            return

        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]

            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]

                target_f[0][action] = reward + self.gamma * np.max(aNet)

            self.net.fit(state, target_f, epochs=1, verbose=0)
                
    def trainDDQN(self, typeOfMem):
        if typeOfMem == 1:
            if len(self.primaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.primaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        elif typeOfMem == 2:
            if len(self.secondaryMemory) >= self.minibatchSize:
                minibatch = random.sample(self.secondaryMemory, self.minibatchSize) #z D vybere pocet mb_size samplu
            else:
                return
        else:
            return
        
        for i in range(0, self.minibatchSize):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            nextState = minibatch[i][3]
            done = minibatch[i][4]
            
            target_f = self.net.predict(state)

            if done:
                target_f[0][action] = reward
            else:
                aNet = self.net.predict(nextState)[0]
                tNet = self.netTarget.predict(nextState)[0]
                target_f[0][action] = reward + self.gamma * tNet[np.argmax(aNet)]
            
            self.net.fit(state, target_f, epochs=1, verbose=0)
    
    def loadNN(self, name):
        self.net.load_weights(name)

    def saveNN(self, name):
        self.net.save_weights(name)

# %% [markdown]
# # Algoritmus

# %%
import copy
agent = Agent(env) #vytvoreni agenta
    
#agent.loadNN("./DDQN-MountainCar-v0.h5") #nacteni NN
#agent.updateTargetNet() #nacteni NN do netTarget

for eps in range (episodes):
    state = env.reset() #resetovani prostredi
    state = np.reshape(state, [1, stateSize]) #formatovani

    state1 = copy.copy(state)
    #state2 = copy.copy(state)
    #state3 = copy.copy(state)
    
    state = np.concatenate((state, state1))
    #state = np.concatenate((state, state2))
    #state = np.concatenate((state, state3))

    state = np.expand_dims(state, axis=0)
    
    agent.epsilonActulization() #aktualizace epsilon
    
    #env.render()

    for t in range(observetime):

        action = agent.getActionWE(state) #ziskani akce

        newState, reward, done, info = env.step(action) #provedeni akce
        
        nextState = np.reshape(newState, [1, stateSize]) #formatovani
        
        temp = copy.copy(nextState)
        
        nextState = np.concatenate((nextState, state1))
        #nextState = np.concatenate((nextState, state2))
        #nextState = np.concatenate((nextState, state3))
        
        #state3 = copy.copy(state2)
        #state2 = copy.copy(state1)
        state1 = copy.copy(temp)
        
        nextState = np.expand_dims(nextState, axis=0)
        
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do primarni pameti
        agent.rememberPrimMem(state, action, reward, nextState, done) #ulozeni do sekundarni pameti
        
        agent.trainDDQN(1) #trenovani na primarni pameti
        
        state = nextState #zmena stavu
        
        if done: #konec epizody
            print("Episode: {}/{}, epsilon: {:.2}, score: {}".format(eps, episodes, agent.currentEpsilon, t))
            #agent.trainDDQN(1)
            scores.append(t) #ulozeni aktualniho skore
            episodesList.append(eps) #ulozeni aktualniho cisla epizody
            
            agent.updateTargetNet() #aktualizace target site
            
            agent.saveNN("./DDQN-CartPole-v0.h5") #ulozeni site
            
            if t > bestScore: #bylo dosazeno njelepsiho skore
                bestScore = t #nove nejlepsi skore
            #    for i in range(trainingAfterSucces): #pocet trenovani
            #        agent.trainDDQN(2) #trenovani na sekundarni pameti
                agent.saveNN("./DDQN-CartPole-v0-{}.h5" .format(eps)) #ulozeni site
            #    #agent.resetEpsilon() #resetovani epsilonu
            
            #agent.resetSecMem() #vycisteni sekundarni pameti
            
            break
            
agent.saveNN("./DDQN-CartPole-v0.h5") #ulozeni site
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 2, 32)             224
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 1,315.0
# Trainable params: 1,315.0
# Non-trainable params: 0.0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 2, 32)             224
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 1,315.0
# Trainable params: 1,315.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Episode: 0/1500, epsilon: 0.99, score: 499
# Episode: 1/1500, epsilon: 0.99, score: 499
# Episode: 2/1500, epsilon: 0.99, score: 499
# Episode: 3/1500, epsilon: 0.98, score: 499
# Episode: 4/1500, epsilon: 0.98, score: 499
# Episode: 5/1500, epsilon: 0.97, score: 499
# Episode: 6/1500, epsilon: 0.97, score: 499
# Episode: 7/1500, epsilon: 0.96, score: 499
# Episode: 8/1500, epsilon: 0.96, score: 499
# Episode: 9/1500, epsilon: 0.95, score: 499
# Episode: 10/1500, epsilon: 0.95, score: 499
# Episode: 11/1500, epsilon: 0.94, score: 499
# Episode: 12/1500, epsilon: 0.94, score: 499
# Episode: 13/1500, epsilon: 0.93, score: 499
# Episode: 14/1500, epsilon: 0.93, score: 499
# Episode: 15/1500, epsilon: 0.92, score: 499
# Episode: 16/1500, epsilon: 0.92, score: 499
# Episode: 17/1500, epsilon: 0.91, score: 499
# Episode: 18/1500, epsilon: 0.91, score: 499
# Episode: 19/1500, epsilon: 0.9, score: 499
# Episode: 20/1500, epsilon: 0.9, score: 499
# Episode: 21/1500, epsilon: 0.9, score: 499
# Episode: 22/1500, epsilon: 0.89, score: 499
# Episode: 23/1500, epsilon: 0.89, score: 499
# Episode: 24/1500, epsilon: 0.88, score: 499
# Episode: 25/1500, epsilon: 0.88, score: 499
# Episode: 26/1500, epsilon: 0.87, score: 499
# Episode: 27/1500, epsilon: 0.87, score: 499
# Episode: 28/1500, epsilon: 0.86, score: 499
# Episode: 29/1500, epsilon: 0.86, score: 499
# Episode: 30/1500, epsilon: 0.86, score: 499
# Episode: 31/1500, epsilon: 0.85, score: 499
# Episode: 32/1500, epsilon: 0.85, score: 499
# Episode: 33/1500, epsilon: 0.84, score: 499
# Episode: 34/1500, epsilon: 0.84, score: 499
# Episode: 35/1500, epsilon: 0.83, score: 499
# Episode: 36/1500, epsilon: 0.83, score: 499
# Episode: 37/1500, epsilon: 0.83, score: 499
# Episode: 38/1500, epsilon: 0.82, score: 499
# Episode: 39/1500, epsilon: 0.82, score: 499
# Episode: 40/1500, epsilon: 0.81, score: 499
# Episode: 41/1500, epsilon: 0.81, score: 499
# Episode: 42/1500, epsilon: 0.81, score: 499
# Episode: 43/1500, epsilon: 0.8, score: 499
# Episode: 44/1500, epsilon: 0.8, score: 499
# Episode: 45/1500, epsilon: 0.79, score: 499
# Episode: 46/1500, epsilon: 0.79, score: 499
# Episode: 47/1500, epsilon: 0.79, score: 499
# Episode: 48/1500, epsilon: 0.78, score: 499
# Episode: 49/1500, epsilon: 0.78, score: 412
# Episode: 50/1500, epsilon: 0.77, score: 499
# Episode: 51/1500, epsilon: 0.77, score: 499
# Episode: 52/1500, epsilon: 0.77, score: 499
# Episode: 53/1500, epsilon: 0.76, score: 499
# Episode: 54/1500, epsilon: 0.76, score: 499
# Episode: 55/1500, epsilon: 0.76, score: 499
# Episode: 56/1500, epsilon: 0.75, score: 499
# Episode: 57/1500, epsilon: 0.75, score: 499
# Episode: 58/1500, epsilon: 0.74, score: 499
# Episode: 59/1500, epsilon: 0.74, score: 499
# Episode: 60/1500, epsilon: 0.74, score: 391
# Episode: 61/1500, epsilon: 0.73, score: 499
# Episode: 62/1500, epsilon: 0.73, score: 499
# Episode: 63/1500, epsilon: 0.73, score: 499
# Episode: 64/1500, epsilon: 0.72, score: 499
# Episode: 65/1500, epsilon: 0.72, score: 499
# Episode: 66/1500, epsilon: 0.71, score: 499
# Episode: 67/1500, epsilon: 0.71, score: 499
# Episode: 68/1500, epsilon: 0.71, score: 499
# Episode: 69/1500, epsilon: 0.7, score: 499
# Episode: 70/1500, epsilon: 0.7, score: 273
# Episode: 71/1500, epsilon: 0.7, score: 499
# Episode: 72/1500, epsilon: 0.69, score: 499
# Episode: 73/1500, epsilon: 0.69, score: 499
# Episode: 74/1500, epsilon: 0.69, score: 499
# Episode: 75/1500, epsilon: 0.68, score: 499
# Episode: 76/1500, epsilon: 0.68, score: 499
# Episode: 77/1500, epsilon: 0.68, score: 499
# Episode: 78/1500, epsilon: 0.67, score: 499
# Episode: 79/1500, epsilon: 0.67, score: 499
# Episode: 80/1500, epsilon: 0.67, score: 499
# Episode: 81/1500, epsilon: 0.66, score: 499
# Episode: 82/1500, epsilon: 0.66, score: 499
# Episode: 83/1500, epsilon: 0.66, score: 347
# Episode: 84/1500, epsilon: 0.65, score: 499
# Episode: 85/1500, epsilon: 0.65, score: 499
# Episode: 86/1500, epsilon: 0.65, score: 499
# Episode: 87/1500, epsilon: 0.64, score: 499
# Episode: 88/1500, epsilon: 0.64, score: 499
# Episode: 89/1500, epsilon: 0.64, score: 499
# Episode: 90/1500, epsilon: 0.63, score: 499
# Episode: 91/1500, epsilon: 0.63, score: 499
# Episode: 92/1500, epsilon: 0.63, score: 499
# Episode: 93/1500, epsilon: 0.62, score: 499
# Episode: 94/1500, epsilon: 0.62, score: 499
# Episode: 95/1500, epsilon: 0.62, score: 499
# Episode: 96/1500, epsilon: 0.61, score: 368
# Episode: 97/1500, epsilon: 0.61, score: 499
# Episode: 98/1500, epsilon: 0.61, score: 499
# Episode: 99/1500, epsilon: 0.61, score: 499
# Episode: 100/1500, epsilon: 0.6, score: 499
# Episode: 101/1500, epsilon: 0.6, score: 499
# Episode: 102/1500, epsilon: 0.6, score: 499
# Episode: 103/1500, epsilon: 0.59, score: 499
# Episode: 104/1500, epsilon: 0.59, score: 499
# Episode: 105/1500, epsilon: 0.59, score: 499
# Episode: 106/1500, epsilon: 0.58, score: 499
# Episode: 107/1500, epsilon: 0.58, score: 214
# Episode: 108/1500, epsilon: 0.58, score: 499
# Episode: 109/1500, epsilon: 0.58, score: 499
# Episode: 110/1500, epsilon: 0.57, score: 242
# Episode: 111/1500, epsilon: 0.57, score: 499
# Episode: 112/1500, epsilon: 0.57, score: 499
# Episode: 113/1500, epsilon: 0.56, score: 499
# Episode: 114/1500, epsilon: 0.56, score: 499
# Episode: 115/1500, epsilon: 0.56, score: 499
# Episode: 116/1500, epsilon: 0.56, score: 376
# Episode: 117/1500, epsilon: 0.55, score: 499
# Episode: 118/1500, epsilon: 0.55, score: 499
# Episode: 119/1500, epsilon: 0.55, score: 499
# Episode: 120/1500, epsilon: 0.55, score: 499
# Episode: 121/1500, epsilon: 0.54, score: 499
# Episode: 122/1500, epsilon: 0.54, score: 499
# Episode: 123/1500, epsilon: 0.54, score: 499
# Episode: 124/1500, epsilon: 0.53, score: 499
# Episode: 125/1500, epsilon: 0.53, score: 499
# Episode: 126/1500, epsilon: 0.53, score: 499
# Episode: 127/1500, epsilon: 0.53, score: 499
# Episode: 128/1500, epsilon: 0.52, score: 499
# Episode: 129/1500, epsilon: 0.52, score: 455
# Episode: 130/1500, epsilon: 0.52, score: 499
# Episode: 131/1500, epsilon: 0.52, score: 499
# Episode: 132/1500, epsilon: 0.51, score: 499
# Episode: 133/1500, epsilon: 0.51, score: 499
# Episode: 134/1500, epsilon: 0.51, score: 499
# Episode: 135/1500, epsilon: 0.51, score: 499
# Episode: 136/1500, epsilon: 0.5, score: 499
# Episode: 137/1500, epsilon: 0.5, score: 499
# Episode: 138/1500, epsilon: 0.5, score: 499
# Episode: 139/1500, epsilon: 0.5, score: 499
# Episode: 140/1500, epsilon: 0.49, score: 499
# Episode: 141/1500, epsilon: 0.49, score: 499
# Episode: 142/1500, epsilon: 0.49, score: 499
# Episode: 143/1500, epsilon: 0.49, score: 499
# Episode: 144/1500, epsilon: 0.48, score: 499
# Episode: 145/1500, epsilon: 0.48, score: 476
# Episode: 146/1500, epsilon: 0.48, score: 499
# Episode: 147/1500, epsilon: 0.48, score: 499
# Episode: 148/1500, epsilon: 0.47, score: 499
# Episode: 149/1500, epsilon: 0.47, score: 499
# Episode: 150/1500, epsilon: 0.47, score: 499
# Episode: 151/1500, epsilon: 0.47, score: 499
# Episode: 152/1500, epsilon: 0.46, score: 499
# Episode: 153/1500, epsilon: 0.46, score: 499
# Episode: 154/1500, epsilon: 0.46, score: 499
# Episode: 155/1500, epsilon: 0.46, score: 499
# Episode: 156/1500, epsilon: 0.46, score: 499
# Episode: 157/1500, epsilon: 0.45, score: 499
# Episode: 158/1500, epsilon: 0.45, score: 499
# Episode: 159/1500, epsilon: 0.45, score: 499
# Episode: 160/1500, epsilon: 0.45, score: 499
# Episode: 161/1500, epsilon: 0.44, score: 499
# Episode: 162/1500, epsilon: 0.44, score: 499
# Episode: 163/1500, epsilon: 0.44, score: 499
# Episode: 164/1500, epsilon: 0.44, score: 499
# Episode: 165/1500, epsilon: 0.44, score: 443
# Episode: 166/1500, epsilon: 0.43, score: 499
# Episode: 167/1500, epsilon: 0.43, score: 499
# Episode: 168/1500, epsilon: 0.43, score: 499
# Episode: 169/1500, epsilon: 0.43, score: 499
# Episode: 170/1500, epsilon: 0.42, score: 499
# Episode: 171/1500, epsilon: 0.42, score: 499
# Episode: 172/1500, epsilon: 0.42, score: 499
# Episode: 173/1500, epsilon: 0.42, score: 499
# Episode: 174/1500, epsilon: 0.42, score: 499
# Episode: 175/1500, epsilon: 0.41, score: 499
# Episode: 176/1500, epsilon: 0.41, score: 499
# Episode: 177/1500, epsilon: 0.41, score: 499
# Episode: 178/1500, epsilon: 0.41, score: 499
# Episode: 179/1500, epsilon: 0.41, score: 499
# Episode: 180/1500, epsilon: 0.4, score: 499
# Episode: 181/1500, epsilon: 0.4, score: 499
# Episode: 182/1500, epsilon: 0.4, score: 499
# Episode: 183/1500, epsilon: 0.4, score: 499
# Episode: 184/1500, epsilon: 0.4, score: 499
# Episode: 185/1500, epsilon: 0.39, score: 499
# Episode: 186/1500, epsilon: 0.39, score: 499
# Episode: 187/1500, epsilon: 0.39, score: 499
# Episode: 188/1500, epsilon: 0.39, score: 499
# Episode: 189/1500, epsilon: 0.39, score: 499
# Episode: 190/1500, epsilon: 0.38, score: 499
# Episode: 191/1500, epsilon: 0.38, score: 499
# Episode: 192/1500, epsilon: 0.38, score: 499
# Episode: 193/1500, epsilon: 0.38, score: 499
# Episode: 194/1500, epsilon: 0.38, score: 499
# Episode: 195/1500, epsilon: 0.37, score: 499
# Episode: 196/1500, epsilon: 0.37, score: 499
# Episode: 197/1500, epsilon: 0.37, score: 499
# Episode: 198/1500, epsilon: 0.37, score: 499
# Episode: 199/1500, epsilon: 0.37, score: 499
# Episode: 200/1500, epsilon: 0.37, score: 329
# Episode: 201/1500, epsilon: 0.36, score: 499
# Episode: 202/1500, epsilon: 0.36, score: 499
# Episode: 203/1500, epsilon: 0.36, score: 499
# Episode: 204/1500, epsilon: 0.36, score: 499
# Episode: 205/1500, epsilon: 0.36, score: 499
# Episode: 206/1500, epsilon: 0.35, score: 499
# Episode: 207/1500, epsilon: 0.35, score: 499
# Episode: 208/1500, epsilon: 0.35, score: 499
# Episode: 209/1500, epsilon: 0.35, score: 499
# Episode: 210/1500, epsilon: 0.35, score: 371
# Episode: 211/1500, epsilon: 0.35, score: 499
# Episode: 212/1500, epsilon: 0.34, score: 499
# Episode: 213/1500, epsilon: 0.34, score: 454
# Episode: 214/1500, epsilon: 0.34, score: 499
# Episode: 215/1500, epsilon: 0.34, score: 499
# Episode: 216/1500, epsilon: 0.34, score: 499
# Episode: 217/1500, epsilon: 0.34, score: 499
# Episode: 218/1500, epsilon: 0.33, score: 499
# Episode: 219/1500, epsilon: 0.33, score: 499
# Episode: 220/1500, epsilon: 0.33, score: 499
# Episode: 221/1500, epsilon: 0.33, score: 499
# Episode: 222/1500, epsilon: 0.33, score: 499
# Episode: 223/1500, epsilon: 0.33, score: 499
# Episode: 224/1500, epsilon: 0.32, score: 499
# Episode: 225/1500, epsilon: 0.32, score: 499
# Episode: 226/1500, epsilon: 0.32, score: 499
# Episode: 227/1500, epsilon: 0.32, score: 427
# Episode: 228/1500, epsilon: 0.32, score: 499
# Episode: 229/1500, epsilon: 0.32, score: 499
# Episode: 230/1500, epsilon: 0.31, score: 499
# Episode: 231/1500, epsilon: 0.31, score: 499
# Episode: 232/1500, epsilon: 0.31, score: 499
# Episode: 233/1500, epsilon: 0.31, score: 499
# Episode: 234/1500, epsilon: 0.31, score: 499
# Episode: 235/1500, epsilon: 0.31, score: 499
# Episode: 236/1500, epsilon: 0.3, score: 499
# Episode: 237/1500, epsilon: 0.3, score: 499
# Episode: 238/1500, epsilon: 0.3, score: 499
# Episode: 239/1500, epsilon: 0.3, score: 499
# Episode: 240/1500, epsilon: 0.3, score: 499
# Episode: 241/1500, epsilon: 0.3, score: 499
# Episode: 242/1500, epsilon: 0.3, score: 499
# Episode: 243/1500, epsilon: 0.29, score: 499
# Episode: 244/1500, epsilon: 0.29, score: 499
# Episode: 245/1500, epsilon: 0.29, score: 385
# Episode: 246/1500, epsilon: 0.29, score: 499
# Episode: 247/1500, epsilon: 0.29, score: 499

# %% [markdown]
# # Výsledky

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
import copy

def analysis(scores, episodesList):
    score1 = copy.copy(scores)
    score2 = copy.copy(scores)
    score3 = copy.copy(scores)

    for i in range (len(scores)):
        if i > 1 and i < (len(scores)-2):
            score1[i] = (scores[i - 2] + scores[i - 1] + scores[i] + scores[i + 1] + scores[i + 2])/5

    for i in range (len(scores)):
        if i > 4 and i < (len(scores)-5):
            score2[i] += scores[i - 5] + scores[i - 4] + scores[i - 3] + scores[i - 2] + scores[i - 1]
            score2[i] += scores[i + 5] + scores[i + 4] + scores[i + 3] + scores[i + 2] + scores[i + 1]
            score2[i] = score2[i]/11

    for i in range (len(scores)):
        if i > 49 and i < (len(scores) - 50):
            for e in range (1,50):
                score3[i] += scores[i - e] + scores[i + e] 
            score3[i] = score3[i]/101      

    plt.plot(episodesList, scores, 'ro')
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Vysledky")
    plt.show()

    plt.plot(scores)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku")
    plt.show()

    plt.plot(score1)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku (filtr - prumer 5-ti prvku)")
    plt.show()

    plt.plot(score2)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 11-cti prvku)")
    plt.show()

    plt.plot(score3)
    plt.ylabel("Score")
    plt.xlabel("Episodes")
    plt.title("Funkce interpolace vysledku  (filtr - prumer 101 prvku)")
    plt.show()
    
analysis(scores, episodesList)

# %% [markdown]
# # Hra

# %%
agent.loadNN("./DDQN-CartPole-v0.h5")
observation = env.reset()
scores = []                                # Vycisteni pole pro ulozeni vysledku na analyzu
episodesList = []                          # Vycisteni pole pro ulozeni cisel epizod na analyzu

for g in range (games):
    state = env.reset()
    state = np.reshape(state, [1, stateSize])
    
    state1 = copy.copy(state)
    state2 = copy.copy(state)
    state3 = copy.copy(state)
    
    state = np.concatenate((state, state1))
    state = np.concatenate((state, state2))
    state = np.concatenate((state, state3))

    state = np.expand_dims(state, axis=0)
    
    totalReward = 0
    done = False
    
    while not done:
        #env.render()
        
        action = agent.getAction(state)
        newState, reward, done, info = env.step(action)

        nextState = np.reshape(newState, [1, stateSize])

        temp = copy.copy(nextState)
        
        nextState = np.concatenate((nextState, state1))
        nextState = np.concatenate((nextState, state2))
        nextState = np.concatenate((nextState, state3))
        
        state3 = copy.copy(state2)
        state2 = copy.copy(state1)
        state1 = copy.copy(temp)
        
        nextState = np.expand_dims(nextState, axis=0)
        
        state = nextState

        totalReward += reward
        
    scores.append(totalReward) #ulozeni aktualniho skore
    episodesList.append(g) #ulozeni aktualniho cisla epizody

    print('Game {}/{}, score: {}'.format(g, games, totalReward))

analysis(scores, episodesList)
