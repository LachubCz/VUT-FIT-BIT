# %%
import sys                                   # Pro pripojeni knihovny Open AI Gym
sys.path.append('/home/xbucha02/libraries')  # Pripojeni knihovny Open AI Gym
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 4000


class DQNAgent:
    def __init__(self, state_size, action_size):
        # Cartpole이 학습하는 것을 보려면 "True"로 바꿀 것
        self.render = True

        # state와 action의 크기를 가져와서 모델을 생성하는데 사용함
        self.state_size = state_size
        self.action_size = action_size

        # Cartpole DQN 학습의 Hyper parameter 들
        # deque를 통해서 replay memory 생성
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_min = 0.005
        self.epsilon_decay = (self.epsilon - self.epsilon_min) / 50000
        self.batch_size = 64
        self.train_start = 1000
        self.memory = deque(maxlen=10000)

        # 학습할 모델과 타겟 모델을 생성
        self.model = self.build_model()
        self.target_model = self.build_model()
        # 학습할 모델을 타겟 모델로 복사 --> 타겟 모델의 초기화(weight를 같게 해주고 시작해야 함)
        self.update_target_model()

    # Deep Neural Network를 통해서 Q Function을 근사
    # state가 입력, 각 행동에 대한 Q Value가 출력인 모델을 생성
    def build_model(self):
        model = Sequential()
        model.add(Dense(32, input_dim=self.state_size, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(16, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear', kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # 일정한 시간 간격마다 타겟 모델을 현재 학습하고 있는 모델로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 행동의 선택은 현재 네트워크에 대해서 epsilon-greedy 정책을 사용
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # <s,a,r,s'>을 replay_memory에 저장함
    def replay_memory(self, state, action, reward, next_state, done):
        if action == 2:
            action = 1
        self.memory.append((state, action, reward, next_state, done))
        if self.epsilon > self.epsilon_min:
            self.epsilon -= self.epsilon_decay
        # print(len(self.memory))

    # replay memory에서 batch_size 만큼의 샘플들을 무작위로 뽑아서 학습
    def train_replay(self):
        if len(self.memory) < self.train_start:
            return
        batch_size = min(self.batch_size, len(self.memory))
        mini_batch = random.sample(self.memory, batch_size)

        update_input = np.zeros((batch_size, self.state_size))
        update_target = np.zeros((batch_size, self.action_size))

        for i in range(batch_size):
            state, action, reward, next_state, done = mini_batch[i]
            target = self.model.predict(state)[0]

            # 큐러닝에서와 같이 s'에서의 최대 Q Value를 가져옴. 단, 타겟 모델에서 가져옴
            if done:
                target[action] = reward
            else:
                target[action] = reward + self.discount_factor * \
                                          np.amax(self.target_model.predict(next_state)[0])
            update_input[i] = state
            update_target[i] = target

        # 학습할 정답인 타겟과 현재 자신의 값의 minibatch를 만들고 그것으로 한 번에 모델 업데이트
        self.model.fit(update_input, update_target, batch_size=batch_size, epochs=1, verbose=0)

    # 저장한 모델을 불러옴
    def load_model(self, name):
        self.model.load_weights(name)

    # 학습된 모델을 저장함
    def save_model(self, name):
        self.model.save_weights(name)


if __name__ == "__main__":
    # CartPole-v1의 경우 500 타임스텝까지 플레이가능
    env = gym.make('MountainCar-v0')
    # 환경으로부터 상태와 행동의 크기를 가져옴
    state_size = env.observation_space.shape[0]
    #action_size = env.action_space.n
    action_size = 2
    # DQN 에이전트의 생성
    agent = DQNAgent(state_size, action_size)
#    agent.load_model("./save_model/MountainCar_DQN.h5")
    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        state = env.reset()
        state = np.reshape(state, [1, state_size])
        print(state)

        # 액션 0(좌), 1(아무것도 안함), 3(아무것도 하지 않는 액션을 하지 않기 위한 fake_action 선언
        fake_action = 0

        # 같은 액션을 4번하기 위한 카운터
        action_count = 0

        while not done:
            #if agent.render:
                #env.render()

            # 현재 상태에서 행동을 선택하고 한 스텝을 진행
            action_count = action_count + 1

            if action_count == 4:
                action = agent.get_action(state)
                action_count = 0

                if action == 0:
                    fake_action = 0
                elif action == 1:
                    fake_action = 2

            # 선택한 액션으로 1 step을 시행한다
            next_state, reward, done, info = env.step(fake_action)
            next_state = np.reshape(next_state, [1, state_size])
            # 에피소드를 끝나게 한 행동에 대해서 -100의 패널티를 줌
            #reward = reward if not done else -100

            # <s, a, r, s'>을 replay memory에 저장
            agent.replay_memory(state, fake_action, reward, next_state, done)
            # 매 타임스텝마다 학습을 진행
            agent.train_replay()
            score += reward
            state = next_state

            if done:
                env.reset()
                # 매 에피소드마다 학습하는 모델을 타겟 모델로 복사
                agent.update_target_model()

                # 각 에피소드마다 cartpole이 서있었던 타임스텝을 plot
                scores.append(score)
                episodes.append(e)
                #pylab.plot(episodes, scores, 'b')
                #pylab.savefig("./save_graph/MountainCar_DQN.png")
                print("episode:", e, "  score:", score, "  memory length:", len(agent.memory),
                      "  epsilon:", agent.epsilon)

        # 50 에피소드마다 학습 모델을 저장
        if e % 50 == 0:
             agent.save_model("./MountainCar_DQN.h5")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 32)                96
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 658
# Trainable params: 658
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 32)                96
# _________________________________________________________________
# dense_23 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 658
# Trainable params: 658
# Non-trainable params: 0
# _________________________________________________________________
# [[-0.54551017  0.        ]]
# ('episode:', 0, '  score:', -200.0, '  memory length:', 200, '  epsilon:', 0.9960200000000077)
# [[-0.45959859  0.        ]]
# ('episode:', 1, '  score:', -200.0, '  memory length:', 400, '  epsilon:', 0.9920400000000154)
# [[-0.45714149  0.        ]]
# ('episode:', 2, '  score:', -200.0, '  memory length:', 600, '  epsilon:', 0.988060000000023)
# [[-0.45455864  0.        ]]
# ('episode:', 3, '  score:', -200.0, '  memory length:', 800, '  epsilon:', 0.9840800000000307)
# [[-0.47444259  0.        ]]
# ('episode:', 4, '  score:', -200.0, '  memory length:', 1000, '  epsilon:', 0.9801000000000384)
# [[-0.45721021  0.        ]]
# ('episode:', 5, '  score:', -200.0, '  memory length:', 1200, '  epsilon:', 0.9761200000000461)
# [[-0.48486106  0.        ]]
# ('episode:', 6, '  score:', -200.0, '  memory length:', 1400, '  epsilon:', 0.9721400000000537)
# [[-0.49646844  0.        ]]
# ('episode:', 7, '  score:', -200.0, '  memory length:', 1600, '  epsilon:', 0.9681600000000614)
# [[-0.45495914  0.        ]]
# ('episode:', 8, '  score:', -200.0, '  memory length:', 1800, '  epsilon:', 0.9641800000000691)
# [[-0.52964401  0.        ]]
# ('episode:', 9, '  score:', -200.0, '  memory length:', 2000, '  epsilon:', 0.9602000000000768)
# [[-0.41007677  0.        ]]
# ('episode:', 10, '  score:', -200.0, '  memory length:', 2200, '  epsilon:', 0.9562200000000844)
# [[-0.59814298  0.        ]]
# ('episode:', 11, '  score:', -200.0, '  memory length:', 2400, '  epsilon:', 0.9522400000000921)
# [[-0.4939113  0.       ]]
# ('episode:', 12, '  score:', -200.0, '  memory length:', 2600, '  epsilon:', 0.9482600000000998)
# [[-0.55847824  0.        ]]
# ('episode:', 13, '  score:', -200.0, '  memory length:', 2800, '  epsilon:', 0.9442800000001075)
# [[-0.51550135  0.        ]]
# ('episode:', 14, '  score:', -200.0, '  memory length:', 3000, '  epsilon:', 0.9403000000001152)
# [[-0.51936302  0.        ]]
# ('episode:', 15, '  score:', -200.0, '  memory length:', 3200, '  epsilon:', 0.9363200000001228)
# [[-0.58007388  0.        ]]
# ('episode:', 16, '  score:', -200.0, '  memory length:', 3400, '  epsilon:', 0.9323400000001305)
# [[-0.45591289  0.        ]]
# ('episode:', 17, '  score:', -200.0, '  memory length:', 3600, '  epsilon:', 0.9283600000001382)
# [[-0.40275271  0.        ]]
# ('episode:', 18, '  score:', -200.0, '  memory length:', 3800, '  epsilon:', 0.9243800000001459)
# [[-0.46612032  0.        ]]
# ('episode:', 19, '  score:', -200.0, '  memory length:', 4000, '  epsilon:', 0.9204000000001535)
# [[-0.45057569  0.        ]]
# ('episode:', 20, '  score:', -200.0, '  memory length:', 4200, '  epsilon:', 0.9164200000001612)
# [[-0.48330833  0.        ]]
# ('episode:', 21, '  score:', -200.0, '  memory length:', 4400, '  epsilon:', 0.9124400000001689)
# [[-0.4018359  0.       ]]
# ('episode:', 22, '  score:', -200.0, '  memory length:', 4600, '  epsilon:', 0.9084600000001766)
# [[-0.52223363  0.        ]]
# ('episode:', 23, '  score:', -200.0, '  memory length:', 4800, '  epsilon:', 0.9044800000001842)
# [[-0.46466987  0.        ]]
# ('episode:', 24, '  score:', -200.0, '  memory length:', 5000, '  epsilon:', 0.9005000000001919)
# [[-0.42341363  0.        ]]
# ('episode:', 25, '  score:', -200.0, '  memory length:', 5200, '  epsilon:', 0.8965200000001996)
# [[-0.49208597  0.        ]]
# ('episode:', 26, '  score:', -200.0, '  memory length:', 5400, '  epsilon:', 0.8925400000002073)
# [[-0.41898622  0.        ]]
# ('episode:', 27, '  score:', -200.0, '  memory length:', 5600, '  epsilon:', 0.888560000000215)
# [[-0.49136171  0.        ]]
# ('episode:', 28, '  score:', -200.0, '  memory length:', 5800, '  epsilon:', 0.8845800000002226)
# [[-0.4064483  0.       ]]
# ('episode:', 29, '  score:', -200.0, '  memory length:', 6000, '  epsilon:', 0.8806000000002303)
# [[-0.42596127  0.        ]]
# ('episode:', 30, '  score:', -200.0, '  memory length:', 6200, '  epsilon:', 0.876620000000238)
# [[-0.59992405  0.        ]]
# ('episode:', 31, '  score:', -200.0, '  memory length:', 6400, '  epsilon:', 0.8726400000002457)
# [[-0.54523014  0.        ]]
# ('episode:', 32, '  score:', -200.0, '  memory length:', 6600, '  epsilon:', 0.8686600000002533)
# [[-0.57120345  0.        ]]
# ('episode:', 33, '  score:', -200.0, '  memory length:', 6800, '  epsilon:', 0.864680000000261)
# [[-0.43336894  0.        ]]
# ('episode:', 34, '  score:', -200.0, '  memory length:', 7000, '  epsilon:', 0.8607000000002687)
# [[-0.54854438  0.        ]]
# ('episode:', 35, '  score:', -200.0, '  memory length:', 7200, '  epsilon:', 0.8567200000002764)
# [[-0.45068596  0.        ]]
# ('episode:', 36, '  score:', -200.0, '  memory length:', 7400, '  epsilon:', 0.852740000000284)
# [[-0.5357067  0.       ]]
# ('episode:', 37, '  score:', -200.0, '  memory length:', 7600, '  epsilon:', 0.8487600000002917)
# [[-0.44477095  0.        ]]
# ('episode:', 38, '  score:', -200.0, '  memory length:', 7800, '  epsilon:', 0.8447800000002994)
# [[-0.59544508  0.        ]]
# ('episode:', 39, '  score:', -200.0, '  memory length:', 8000, '  epsilon:', 0.8408000000003071)
# [[-0.46561992  0.        ]]
# ('episode:', 40, '  score:', -200.0, '  memory length:', 8200, '  epsilon:', 0.8368200000003148)
# [[-0.4742494  0.       ]]
# ('episode:', 41, '  score:', -200.0, '  memory length:', 8400, '  epsilon:', 0.8328400000003224)
# [[-0.56881011  0.        ]]
# ('episode:', 42, '  score:', -200.0, '  memory length:', 8600, '  epsilon:', 0.8288600000003301)
# [[-0.59348751  0.        ]]
# ('episode:', 43, '  score:', -200.0, '  memory length:', 8800, '  epsilon:', 0.8248800000003378)
# [[-0.41860142  0.        ]]
# ('episode:', 44, '  score:', -200.0, '  memory length:', 9000, '  epsilon:', 0.8209000000003455)
# [[-0.45352072  0.        ]]
# ('episode:', 45, '  score:', -200.0, '  memory length:', 9200, '  epsilon:', 0.8169200000003531)
# [[-0.52427519  0.        ]]
# ('episode:', 46, '  score:', -200.0, '  memory length:', 9400, '  epsilon:', 0.8129400000003608)
# [[-0.50305147  0.        ]]
# ('episode:', 47, '  score:', -200.0, '  memory length:', 9600, '  epsilon:', 0.8089600000003685)
# [[-0.51408928  0.        ]]
# ('episode:', 48, '  score:', -200.0, '  memory length:', 9800, '  epsilon:', 0.8049800000003762)
# [[-0.59935831  0.        ]]
# ('episode:', 49, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.8010000000003838)
# [[-0.42047562  0.        ]]
# ('episode:', 50, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7970200000003915)
# [[-0.54846793  0.        ]]
# ('episode:', 51, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7930400000003992)
# [[-0.42811983  0.        ]]
# ('episode:', 52, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7890600000004069)
# [[-0.42683643  0.        ]]
# ('episode:', 53, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7850800000004146)
# [[-0.44807445  0.        ]]
# ('episode:', 54, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7811000000004222)
# [[-0.53214119  0.        ]]
# ('episode:', 55, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7771200000004299)
# [[-0.40884064  0.        ]]
# ('episode:', 56, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7731400000004376)
# [[-0.5217874  0.       ]]
# ('episode:', 57, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7691600000004453)
# [[-0.57531798  0.        ]]
# ('episode:', 58, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7651800000004529)
# [[-0.59851152  0.        ]]
# ('episode:', 59, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7612000000004606)
# [[-0.49021063  0.        ]]
# ('episode:', 60, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7572200000004683)
# [[-0.5312937  0.       ]]
# ('episode:', 61, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.753240000000476)
# [[-0.47410541  0.        ]]
# ('episode:', 62, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7492600000004837)
# [[-0.52848314  0.        ]]
# ('episode:', 63, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7452800000004913)
# [[-0.44929951  0.        ]]
# ('episode:', 64, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.741300000000499)
# [[-0.53053456  0.        ]]
# ('episode:', 65, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7373200000005067)
# [[-0.48608731  0.        ]]
# ('episode:', 66, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7333400000005144)
# [[-0.46153886  0.        ]]
# ('episode:', 67, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.729360000000522)
# [[-0.58242856  0.        ]]
# ('episode:', 68, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7253800000005297)
# [[-0.48019294  0.        ]]
# ('episode:', 69, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7214000000005374)
# [[-0.56727677  0.        ]]
# ('episode:', 70, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7174200000005451)
# [[-0.41351505  0.        ]]
# ('episode:', 71, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7134400000005527)
# [[-0.5888448  0.       ]]
# ('episode:', 72, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7094600000005604)
# [[-0.50633022  0.        ]]
# ('episode:', 73, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7054800000005681)
# [[-0.46836964  0.        ]]
# ('episode:', 74, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7015000000005758)
# [[-0.40158248  0.        ]]
# ('episode:', 75, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6975200000005835)
# [[-0.49462297  0.        ]]
# ('episode:', 76, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6935400000005911)
# [[-0.47050911  0.        ]]
# ('episode:', 77, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6895600000005988)
# [[-0.54331857  0.        ]]
# ('episode:', 78, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6855800000006065)
# [[-0.40690271  0.        ]]
# ('episode:', 79, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6816000000006142)
# [[-0.52662975  0.        ]]
# ('episode:', 80, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6776200000006218)
# [[-0.57825139  0.        ]]
# ('episode:', 81, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6736400000006295)
# [[-0.59086852  0.        ]]
# ('episode:', 82, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6696600000006372)
# [[-0.42163797  0.        ]]
# ('episode:', 83, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6656800000006449)
# [[-0.44357467  0.        ]]
# ('episode:', 84, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6617000000006525)
# [[-0.43425519  0.        ]]
# ('episode:', 85, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6577200000006602)
# [[-0.54521578  0.        ]]
# ('episode:', 86, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6537400000006679)
# [[-0.45191141  0.        ]]
# ('episode:', 87, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6497600000006756)
# [[-0.56737531  0.        ]]
# ('episode:', 88, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6457800000006833)
# [[-0.46583009  0.        ]]
# ('episode:', 89, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6418000000006909)
# [[-0.57882496  0.        ]]
# ('episode:', 90, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6378200000006986)
# [[-0.45183444  0.        ]]
# ('episode:', 91, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6338400000007063)
# [[-0.50147446  0.        ]]
# ('episode:', 92, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.629860000000714)
# [[-0.58439277  0.        ]]
# ('episode:', 93, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6258800000007216)
# [[-0.56891587  0.        ]]
# ('episode:', 94, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6219000000007293)
# [[-0.59598914  0.        ]]
# ('episode:', 95, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.617920000000737)
# [[-0.49775519  0.        ]]
# ('episode:', 96, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6139400000007447)
# [[-0.40339518  0.        ]]
# ('episode:', 97, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6099600000007523)
# [[-0.55702755  0.        ]]
# ('episode:', 98, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.60598000000076)
# [[-0.59489302  0.        ]]
# ('episode:', 99, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6020000000007677)
# [[-0.47734807  0.        ]]
# ('episode:', 100, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5980200000007754)
# [[-0.59316114  0.        ]]
# ('episode:', 101, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.594040000000783)
# [[-0.50315278  0.        ]]
# ('episode:', 102, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5900600000007907)
# [[-0.55426946  0.        ]]
# ('episode:', 103, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5860800000007984)
# [[-0.53964569  0.        ]]
# ('episode:', 104, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5821000000008061)
# [[-0.55099284  0.        ]]
# ('episode:', 105, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5781200000008138)
# [[-0.47419363  0.        ]]
# ('episode:', 106, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5741400000008214)
# [[-0.53858438  0.        ]]
# ('episode:', 107, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5701600000008291)
# [[-0.50340481  0.        ]]
# ('episode:', 108, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5661800000008368)
# [[-0.53067883  0.        ]]
# ('episode:', 109, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5622000000008445)
# [[-0.45608772  0.        ]]
# ('episode:', 110, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5582200000008521)
# [[-0.41901546  0.        ]]
# ('episode:', 111, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5542400000008598)
# [[-0.52170553  0.        ]]
# ('episode:', 112, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5502600000008675)
# [[-0.44101779  0.        ]]
# ('episode:', 113, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5462800000008752)
# [[-0.50186695  0.        ]]
# ('episode:', 114, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5423000000008829)
# [[-0.56125761  0.        ]]
# ('episode:', 115, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5383200000008905)
# [[-0.56134326  0.        ]]
# ('episode:', 116, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5343400000008982)
# [[-0.56097941  0.        ]]
# ('episode:', 117, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5303600000009059)
# [[-0.47658132  0.        ]]
# ('episode:', 118, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5263800000009136)
# [[-0.52879288  0.        ]]
# ('episode:', 119, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5224000000009212)
# [[-0.56492163  0.        ]]
# ('episode:', 120, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5184200000009289)
# [[-0.42122326  0.        ]]
# ('episode:', 121, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5144400000009366)
# [[-0.43625846  0.        ]]
# ('episode:', 122, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5104600000009443)
# [[-0.53485142  0.        ]]
# ('episode:', 123, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.506480000000952)
# [[-0.43803852  0.        ]]
# ('episode:', 124, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5025000000009596)
# [[-0.47603089  0.        ]]
# ('episode:', 125, '  score:', -179.0, '  memory length:', 10000, '  epsilon:', 0.4989379000009635)
# [[-0.4174807  0.       ]]
# ('episode:', 126, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.49495790000096007)
# [[-0.58206984  0.        ]]
# ('episode:', 127, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.49097790000095665)
# [[-0.40708781  0.        ]]
# ('episode:', 128, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4869979000009532)
# [[-0.43617685  0.        ]]
# ('episode:', 129, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4830179000009498)
# [[-0.4789682  0.       ]]
# ('episode:', 130, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.47903790000094637)
# [[-0.46800846  0.        ]]
# ('episode:', 131, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.47505790000094295)
# [[-0.54307543  0.        ]]
# ('episode:', 132, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4710779000009395)
# [[-0.52453102  0.        ]]
# ('episode:', 133, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4670979000009361)
# [[-0.53520554  0.        ]]
# ('episode:', 134, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.46311790000093267)
# [[-0.50482577  0.        ]]
# ('episode:', 135, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.45913790000092924)
# [[-0.4406336  0.       ]]
# ('episode:', 136, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4551579000009258)
# [[-0.47843417  0.        ]]
# ('episode:', 137, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4511779000009224)
# [[-0.51176891  0.        ]]
# ('episode:', 138, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.44719790000091897)
# [[-0.46268572  0.        ]]
# ('episode:', 139, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.44321790000091554)
# [[-0.42662711  0.        ]]
# ('episode:', 140, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4392379000009121)
# [[-0.42636102  0.        ]]
# ('episode:', 141, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4352579000009087)
# [[-0.4211605  0.       ]]
# ('episode:', 142, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.43127790000090527)
# [[-0.51367629  0.        ]]
# ('episode:', 143, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.42729790000090184)
# [[-0.41183444  0.        ]]
# ('episode:', 144, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4233179000008984)
# [[-0.51141386  0.        ]]
# ('episode:', 145, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.419337900000895)
# [[-0.45454316  0.        ]]
# ('episode:', 146, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.41535790000089157)
# [[-0.41612112  0.        ]]
# ('episode:', 147, '  score:', -176.0, '  memory length:', 10000, '  epsilon:', 0.41185550000088855)
# [[-0.56681726  0.        ]]
# ('episode:', 148, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4078755000008851)
# [[-0.59862846  0.        ]]
# ('episode:', 149, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.4038955000008817)
# [[-0.56850089  0.        ]]
# ('episode:', 150, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3999155000008783)
# [[-0.46552713  0.        ]]
# ('episode:', 151, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.39593550000087485)
# [[-0.53040882  0.        ]]
# ('episode:', 152, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3919555000008714)
# [[-0.44623847  0.        ]]
# ('episode:', 153, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.387975500000868)
# [[-0.47730304  0.        ]]
# ('episode:', 154, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3839955000008646)
# [[-0.51165023  0.        ]]
# ('episode:', 155, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.38001550000086115)
# [[-0.43500885  0.        ]]
# ('episode:', 156, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3760355000008577)
# [[-0.50661209  0.        ]]
# ('episode:', 157, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3720555000008543)
# [[-0.4129297  0.       ]]
# ('episode:', 158, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3680755000008509)
# [[-0.42800329  0.        ]]
# ('episode:', 159, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.36409550000084745)
# [[-0.43848412  0.        ]]
# ('episode:', 160, '  score:', -182.0, '  memory length:', 10000, '  epsilon:', 0.36047370000084433)
# [[-0.58251567  0.        ]]
# ('episode:', 161, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3564937000008409)
# [[-0.56778229  0.        ]]
# ('episode:', 162, '  score:', -188.0, '  memory length:', 10000, '  epsilon:', 0.3527525000008377)
# [[-0.57529094  0.        ]]
# ('episode:', 163, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.34877250000083426)
# [[-0.54455527  0.        ]]
# ('episode:', 164, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.34479250000083084)
# [[-0.40040486  0.        ]]
# ('episode:', 165, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3408125000008274)
# [[-0.58359365  0.        ]]
# ('episode:', 166, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.336832500000824)
# [[-0.50628801  0.        ]]
# ('episode:', 167, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.33285250000082056)
# [[-0.43487648  0.        ]]
# ('episode:', 168, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.32887250000081714)
# [[-0.43811951  0.        ]]
# ('episode:', 169, '  score:', -171.0, '  memory length:', 10000, '  epsilon:', 0.3254696000008142)
# [[-0.50538271  0.        ]]
# ('episode:', 170, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.3214896000008108)
# [[-0.57410394  0.        ]]
# ('episode:', 171, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.31750960000080736)
# [[-0.41698743  0.        ]]
# ('episode:', 172, '  score:', -187.0, '  memory length:', 10000, '  epsilon:', 0.31378830000080415)
# [[-0.53258287  0.        ]]
# ('episode:', 173, '  score:', -187.0, '  memory length:', 10000, '  epsilon:', 0.31006700000080095)
# [[-0.48226919  0.        ]]
# ('episode:', 174, '  score:', -175.0, '  memory length:', 10000, '  epsilon:', 0.30658450000079795)
# [[-0.43880197  0.        ]]
# ('episode:', 175, '  score:', -186.0, '  memory length:', 10000, '  epsilon:', 0.30288310000079477)
# [[-0.50571696  0.        ]]
# ('episode:', 176, '  score:', -177.0, '  memory length:', 10000, '  epsilon:', 0.29936080000079174)
# [[-0.41950078  0.        ]]
# ('episode:', 177, '  score:', -181.0, '  memory length:', 10000, '  epsilon:', 0.29575890000078864)
# [[-0.56610054  0.        ]]
# ('episode:', 178, '  score:', -166.0, '  memory length:', 10000, '  epsilon:', 0.2924555000007858)
# [[-0.50261476  0.        ]]
# ('episode:', 179, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.2893511000007831)
# [[-0.56031302  0.        ]]
# ('episode:', 180, '  score:', -159.0, '  memory length:', 10000, '  epsilon:', 0.2861870000007804)
# [[-0.59881586  0.        ]]
# ('episode:', 181, '  score:', -139.0, '  memory length:', 10000, '  epsilon:', 0.283420900000778)
# [[-0.56865347  0.        ]]
# ('episode:', 182, '  score:', -167.0, '  memory length:', 10000, '  epsilon:', 0.28009760000077516)
# [[-0.56528531  0.        ]]
# ('episode:', 183, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.27611760000077173)
# [[-0.43873803  0.        ]]
# ('episode:', 184, '  score:', -137.0, '  memory length:', 10000, '  epsilon:', 0.2733913000007694)
# [[-0.58546991  0.        ]]
# ('episode:', 185, '  score:', -160.0, '  memory length:', 10000, '  epsilon:', 0.27020730000076665)
# [[-0.40841  0.     ]]
# ('episode:', 186, '  score:', -170.0, '  memory length:', 10000, '  epsilon:', 0.26682430000076374)
# [[-0.54328018  0.        ]]
# ('episode:', 187, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.2637796000007611)
# [[-0.53933161  0.        ]]
# ('episode:', 188, '  score:', -122.0, '  memory length:', 10000, '  epsilon:', 0.261351800000759)
# [[-0.55871676  0.        ]]
# ('episode:', 189, '  score:', -137.0, '  memory length:', 10000, '  epsilon:', 0.2586255000007567)
# [[-0.50622793  0.        ]]
# ('episode:', 190, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.2556405000007541)
# [[-0.49228777  0.        ]]
# ('episode:', 191, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.2516605000007507)
# [[-0.48213633  0.        ]]
# ('episode:', 192, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.2476805000007505)
# [[-0.44065466  0.        ]]
# ('episode:', 193, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.24370050000075263)
# [[-0.51999206  0.        ]]
# ('episode:', 194, '  score:', -132.0, '  memory length:', 10000, '  epsilon:', 0.24107370000075404)
# [[-0.55224936  0.        ]]
# ('episode:', 195, '  score:', -124.0, '  memory length:', 10000, '  epsilon:', 0.23860610000075536)
# [[-0.54990826  0.        ]]
# ('episode:', 196, '  score:', -134.0, '  memory length:', 10000, '  epsilon:', 0.23593950000075678)
# [[-0.52892138  0.        ]]
# ('episode:', 197, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.2319595000007589)
# [[-0.50490432  0.        ]]
# ('episode:', 198, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.22885510000076056)
# [[-0.54966738  0.        ]]
# ('episode:', 199, '  score:', -131.0, '  memory length:', 10000, '  epsilon:', 0.22624820000076196)
# [[-0.57080883  0.        ]]
# ('episode:', 200, '  score:', -127.0, '  memory length:', 10000, '  epsilon:', 0.2237209000007633)
# [[-0.44845323  0.        ]]
# ('episode:', 201, '  score:', -171.0, '  memory length:', 10000, '  epsilon:', 0.22031800000076512)
# [[-0.40512002  0.        ]]
# ('episode:', 202, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.21705440000076687)
# [[-0.45801808  0.        ]]
# ('episode:', 203, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.21377090000076862)
# [[-0.53958767  0.        ]]
# ('episode:', 204, '  score:', -135.0, '  memory length:', 10000, '  epsilon:', 0.21108440000077006)
# [[-0.54232816  0.        ]]
# ('episode:', 205, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.20869640000077133)
# [[-0.58592955  0.        ]]
# ('episode:', 206, '  score:', -134.0, '  memory length:', 10000, '  epsilon:', 0.20602980000077276)
# [[-0.59847736  0.        ]]
# ('episode:', 207, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.20366170000077402)
# [[-0.5747864  0.       ]]
# ('episode:', 208, '  score:', -135.0, '  memory length:', 10000, '  epsilon:', 0.20097520000077546)
# [[-0.47917029  0.        ]]
# ('episode:', 209, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.1977315000007772)
# [[-0.57882498  0.        ]]
# ('episode:', 210, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.19474650000077878)
# [[-0.57439132  0.        ]]
# ('episode:', 211, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.19178140000078037)
# [[-0.43462706  0.        ]]
# ('episode:', 212, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.18865710000078204)
# [[-0.55294431  0.        ]]
# ('episode:', 213, '  score:', -147.0, '  memory length:', 10000, '  epsilon:', 0.1857318000007836)
# [[-0.42408672  0.        ]]
# ('episode:', 214, '  score:', -184.0, '  memory length:', 10000, '  epsilon:', 0.18207020000078555)
# [[-0.44856458  0.        ]]
# ('episode:', 215, '  score:', -91.0, '  memory length:', 10000, '  epsilon:', 0.18025930000078652)
# [[-0.54205014  0.        ]]
# ('episode:', 216, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.1772942000007881)
# [[-0.52222449  0.        ]]
# ('episode:', 217, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.17409030000078982)
# [[-0.58935937  0.        ]]
# ('episode:', 218, '  score:', -166.0, '  memory length:', 10000, '  epsilon:', 0.17078690000079158)
# [[-0.45073623  0.        ]]
# ('episode:', 219, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.16752330000079332)
# [[-0.47781658  0.        ]]
# ('episode:', 220, '  score:', -175.0, '  memory length:', 10000, '  epsilon:', 0.16404080000079518)
# [[-0.52046709  0.        ]]
# ('episode:', 221, '  score:', -152.0, '  memory length:', 10000, '  epsilon:', 0.1610160000007968)
# [[-0.55838573  0.        ]]
# ('episode:', 222, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.15703600000079893)
# [[-0.57084995  0.        ]]
# ('episode:', 223, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.15375250000080068)
# [[-0.43159128  0.        ]]
# ('episode:', 224, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.1520212000008016)
# [[-0.59951935  0.        ]]
# ('episode:', 225, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.14804120000080373)
# [[-0.46964641  0.        ]]
# ('episode:', 226, '  score:', -180.0, '  memory length:', 10000, '  epsilon:', 0.14445920000080564)
# [[-0.58992423  0.        ]]
# ('episode:', 227, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.14047920000080777)
# [[-0.43358348  0.        ]]
# ('episode:', 228, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.1387280000008087)
# [[-0.52364456  0.        ]]
# ('episode:', 229, '  score:', -166.0, '  memory length:', 10000, '  epsilon:', 0.13542460000081047)
# [[-0.59788828  0.        ]]
# ('episode:', 230, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.1314446000008126)
# [[-0.46213004  0.        ]]
# ('episode:', 231, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.12746460000081472)
# [[-0.59692783  0.        ]]
# ('episode:', 232, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.12348460000081578)
# [[-0.54099365  0.        ]]
# ('episode:', 233, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.12020110000081524)
# [[-0.40009716  0.        ]]
# ('episode:', 234, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.11850960000081497)
# [[-0.59597498  0.        ]]
# ('episode:', 235, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.11452960000081432)
# [[-0.4252208  0.       ]]
# ('episode:', 236, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.11054960000081367)
# [[-0.51663343  0.        ]]
# ('episode:', 237, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.10656960000081302)
# [[-0.53389569  0.        ]]
# ('episode:', 238, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.10258960000081237)
# [[-0.41984204  0.        ]]
# ('episode:', 239, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.10085830000081208)
# [[-0.41885624  0.        ]]
# ('episode:', 240, '  score:', -93.0, '  memory length:', 10000, '  epsilon:', 0.09900760000081178)
# [[-0.46365338  0.        ]]
# ('episode:', 241, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.09594300000081128)
# [[-0.57996595  0.        ]]
# ('episode:', 242, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.09196300000081063)
# [[-0.46040287  0.        ]]
# ('episode:', 243, '  score:', -99.0, '  memory length:', 10000, '  epsilon:', 0.08999290000081031)
# [[-0.49899418  0.        ]]
# ('episode:', 244, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.08670940000080977)
# [[-0.50761851  0.        ]]
# ('episode:', 245, '  score:', -169.0, '  memory length:', 10000, '  epsilon:', 0.08334630000080923)
# [[-0.5143919  0.       ]]
# ('episode:', 246, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.0801026000008087)
# [[-0.44405519  0.        ]]
# ('episode:', 247, '  score:', -169.0, '  memory length:', 10000, '  epsilon:', 0.07673950000080815)
# [[-0.44890287  0.        ]]
# ('episode:', 248, '  score:', -91.0, '  memory length:', 10000, '  epsilon:', 0.07492860000080785)
# [[-0.47165998  0.        ]]
# ('episode:', 249, '  score:', -170.0, '  memory length:', 10000, '  epsilon:', 0.0715456000008073)
# [[-0.56195568  0.        ]]
# ('episode:', 250, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.06840140000080679)
# [[-0.51031912  0.        ]]
# ('episode:', 251, '  score:', -168.0, '  memory length:', 10000, '  epsilon:', 0.06505820000080624)
# [[-0.55849925  0.        ]]
# ('episode:', 252, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.06191400000080573)
# [[-0.58906754  0.        ]]
# ('episode:', 253, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.05894890000080524)
# [[-0.50164251  0.        ]]
# ('episode:', 254, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.05588430000080474)
# [[-0.47912371  0.        ]]
# ('episode:', 255, '  score:', -167.0, '  memory length:', 10000, '  epsilon:', 0.0525610000008042)
# [[-0.54053361  0.        ]]
# ('episode:', 256, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.04943670000080369)
# [[-0.41354617  0.        ]]
# ('episode:', 257, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.04776510000080342)
# [[-0.44601501  0.        ]]
# ('episode:', 258, '  score:', -173.0, '  memory length:', 10000, '  epsilon:', 0.044322400000802856)
# [[-0.47955921  0.        ]]
# ('episode:', 259, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.040342400000802206)
# [[-0.59841594  0.        ]]
# ('episode:', 260, '  score:', -170.0, '  memory length:', 10000, '  epsilon:', 0.036959400000801654)
# [[-0.56400148  0.        ]]
# ('episode:', 261, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.033835100000801144)
# [[-0.41827954  0.        ]]
# ('episode:', 262, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.03214360000080087)
# [[-0.42118295  0.        ]]
# ('episode:', 263, '  score:', -105.0, '  memory length:', 10000, '  epsilon:', 0.030054100000800738)
# [[-0.57049248  0.        ]]
# ('episode:', 264, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.02706910000080077)
# [[-0.45437593  0.        ]]
# ('episode:', 265, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.023944800000800806)
# [[-0.58146864  0.        ]]
# ('episode:', 266, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.02084040000080084)
# [[-0.48569602  0.        ]]
# ('episode:', 267, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.017576800000800877)
# [[-0.51001173  0.        ]]
# ('episode:', 268, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.014372900000800912)
# [[-0.42735994  0.        ]]
# ('episode:', 269, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.012661500000800931)
# [[-0.45514134  0.        ]]
# ('episode:', 270, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.010830700000800952)
# [[-0.55189863  0.        ]]
# ('episode:', 271, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.007626800000800987)
# [[-0.55686004  0.        ]]
# ('episode:', 272, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55926279  0.        ]]
# ('episode:', 273, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54535411  0.        ]]
# ('episode:', 274, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57848803  0.        ]]
# ('episode:', 275, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54514379  0.        ]]
# ('episode:', 276, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55569669  0.        ]]
# ('episode:', 277, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56260047  0.        ]]
# ('episode:', 278, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40045728  0.        ]]
# ('episode:', 279, '  score:', -83.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40377445  0.        ]]
# ('episode:', 280, '  score:', -83.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57052758  0.        ]]
# ('episode:', 281, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41164506  0.        ]]
# ('episode:', 282, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55198471  0.        ]]
# ('episode:', 283, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47167432  0.        ]]
# ('episode:', 284, '  score:', -101.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54320661  0.        ]]
# ('episode:', 285, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50441556  0.        ]]
# ('episode:', 286, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42772276  0.        ]]
# ('episode:', 287, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44630986  0.        ]]
# ('episode:', 288, '  score:', -90.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.49244435  0.        ]]
# ('episode:', 289, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47367873  0.        ]]
# ('episode:', 290, '  score:', -103.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.49707622  0.        ]]
# ('episode:', 291, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46094265  0.        ]]
# ('episode:', 292, '  score:', -104.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41137399  0.        ]]
# ('episode:', 293, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43534581  0.        ]]
# ('episode:', 294, '  score:', -111.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52964493  0.        ]]
# ('episode:', 295, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59096882  0.        ]]
# ('episode:', 296, '  score:', -144.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59286312  0.        ]]
# ('episode:', 297, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40622841  0.        ]]
# ('episode:', 298, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47961805  0.        ]]
# ('episode:', 299, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45424908  0.        ]]
# ('episode:', 300, '  score:', -97.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54569203  0.        ]]
# ('episode:', 301, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42730618  0.        ]]
# ('episode:', 302, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56856411  0.        ]]
# ('episode:', 303, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54130665  0.        ]]
# ('episode:', 304, '  score:', -146.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.48983398  0.        ]]
# ('episode:', 305, '  score:', -167.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51376721  0.        ]]
# ('episode:', 306, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4103177  0.       ]]
# ('episode:', 307, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56311561  0.        ]]
# ('episode:', 308, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47658303  0.        ]]
# ('episode:', 309, '  score:', -106.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45426224  0.        ]]
# ('episode:', 310, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44162367  0.        ]]
# ('episode:', 311, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46668711  0.        ]]
# ('episode:', 312, '  score:', -97.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58297285  0.        ]]
# ('episode:', 313, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46604185  0.        ]]
# ('episode:', 314, '  score:', -97.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56028426  0.        ]]
# ('episode:', 315, '  score:', -152.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50993373  0.        ]]
# ('episode:', 316, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5291352  0.       ]]
# ('episode:', 317, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54571383  0.        ]]
# ('episode:', 318, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52783762  0.        ]]
# ('episode:', 319, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43624555  0.        ]]
# ('episode:', 320, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.49709588  0.        ]]
# ('episode:', 321, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40740055  0.        ]]
# ('episode:', 322, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.53160431  0.        ]]
# ('episode:', 323, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41987612  0.        ]]
# ('episode:', 324, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4007683  0.       ]]
# ('episode:', 325, '  score:', -83.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50497706  0.        ]]
# ('episode:', 326, '  score:', -159.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54914684  0.        ]]
# ('episode:', 327, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.53981291  0.        ]]
# ('episode:', 328, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52603341  0.        ]]
# ('episode:', 329, '  score:', -152.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5862279  0.       ]]
# ('episode:', 330, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57229438  0.        ]]
# ('episode:', 331, '  score:', -147.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58203636  0.        ]]
# ('episode:', 332, '  score:', -152.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51768683  0.        ]]
# ('episode:', 333, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57196713  0.        ]]
# ('episode:', 334, '  score:', -152.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47846392  0.        ]]
# ('episode:', 335, '  score:', -167.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44259569  0.        ]]
# ('episode:', 336, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55738791  0.        ]]
# ('episode:', 337, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44947256  0.        ]]
# ('episode:', 338, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58190715  0.        ]]
# ('episode:', 339, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4576888  0.       ]]
# ('episode:', 340, '  score:', -100.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57972188  0.        ]]
# ('episode:', 341, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41776058  0.        ]]
# ('episode:', 342, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52245203  0.        ]]
# ('episode:', 343, '  score:', -143.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52633253  0.        ]]
# ('episode:', 344, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4969403  0.       ]]
# ('episode:', 345, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42312098  0.        ]]
# ('episode:', 346, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58122332  0.        ]]
# ('episode:', 347, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51871355  0.        ]]
# ('episode:', 348, '  score:', -143.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51533025  0.        ]]
# ('episode:', 349, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41466346  0.        ]]
# ('episode:', 350, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56089497  0.        ]]
# ('episode:', 351, '  score:', -145.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46929568  0.        ]]
# ('episode:', 352, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.53367065  0.        ]]
# ('episode:', 353, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55914826  0.        ]]
# ('episode:', 354, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54410339  0.        ]]
# ('episode:', 355, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.53158048  0.        ]]
# ('episode:', 356, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55646623  0.        ]]
# ('episode:', 357, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42581344  0.        ]]
# ('episode:', 358, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59731095  0.        ]]
# ('episode:', 359, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54927842  0.        ]]
# ('episode:', 360, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57112371  0.        ]]
# ('episode:', 361, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43837526  0.        ]]
# ('episode:', 362, '  score:', -90.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42609074  0.        ]]
# ('episode:', 363, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55290917  0.        ]]
# ('episode:', 364, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50972106  0.        ]]
# ('episode:', 365, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47226333  0.        ]]
# ...
# [[-0.56982463  0.        ]]
# ('episode:', 534, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5844674  0.       ]]
# ('episode:', 535, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47697338  0.        ]]
# ('episode:', 536, '  score:', -104.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56873759  0.        ]]
# ('episode:', 537, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44198643  0.        ]]
# ('episode:', 538, '  score:', -146.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46140831  0.        ]]
# ('episode:', 539, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43263441  0.        ]]
# ('episode:', 540, '  score:', -89.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41871703  0.        ]]
# ('episode:', 541, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40204123  0.        ]]
# ('episode:', 542, '  score:', -83.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52444614  0.        ]]
# ('episode:', 543, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43242701  0.        ]]
# ('episode:', 544, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.53679073  0.        ]]
# ('episode:', 545, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56051608  0.        ]]
# ('episode:', 546, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47481788  0.        ]]
# ('episode:', 547, '  score:', -146.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4438909  0.       ]]
# ('episode:', 548, '  score:', -89.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40792138  0.        ]]
# ('episode:', 549, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56978454  0.        ]]
# ('episode:', 550, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46334827  0.        ]]
# ('episode:', 551, '  score:', -96.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59591077  0.        ]]
# ('episode:', 552, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41641581  0.        ]]
# ('episode:', 553, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4422904  0.       ]]
# ('episode:', 554, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43118301  0.        ]]
# ('episode:', 555, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45966597  0.        ]]
# ('episode:', 556, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56060942  0.        ]]
# ('episode:', 557, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45672025  0.        ]]
# ('episode:', 558, '  score:', -93.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44868776  0.        ]]
# ('episode:', 559, '  score:', -90.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56160161  0.        ]]
# ('episode:', 560, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41101906  0.        ]]
# ('episode:', 561, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42729635  0.        ]]
# ('episode:', 562, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5924834  0.       ]]
# ('episode:', 563, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4606903  0.       ]]
# ('episode:', 564, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59605328  0.        ]]
# ('episode:', 565, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42832643  0.        ]]
# ('episode:', 566, '  score:', -100.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51606355  0.        ]]
# ('episode:', 567, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56611373  0.        ]]
# ('episode:', 568, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59953365  0.        ]]
# ('episode:', 569, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58230103  0.        ]]
# ('episode:', 570, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47238704  0.        ]]
# ('episode:', 571, '  score:', -147.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55369524  0.        ]]
# ('episode:', 572, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52969814  0.        ]]
# ('episode:', 573, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42894669  0.        ]]
# ('episode:', 574, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56474974  0.        ]]
# ('episode:', 575, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44417775  0.        ]]
# ('episode:', 576, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5490948  0.       ]]
# ('episode:', 577, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54126796  0.        ]]
# ('episode:', 578, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43160952  0.        ]]
# ('episode:', 579, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56501961  0.        ]]
# ('episode:', 580, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43273402  0.        ]]
# ('episode:', 581, '  score:', -89.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59423511  0.        ]]
# ('episode:', 582, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52440469  0.        ]]
# ('episode:', 583, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40998275  0.        ]]
# ('episode:', 584, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47591419  0.        ]]
# ('episode:', 585, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41727007  0.        ]]
# ('episode:', 586, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41886748  0.        ]]
# ('episode:', 587, '  score:', -93.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.49470863  0.        ]]
# ('episode:', 588, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54264397  0.        ]]
# ('episode:', 589, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58773838  0.        ]]
# ('episode:', 590, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41750025  0.        ]]
# ('episode:', 591, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58936679  0.        ]]
# ('episode:', 592, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57608834  0.        ]]
# ('episode:', 593, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58484089  0.        ]]
# ('episode:', 594, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.49915955  0.        ]]
# ('episode:', 595, '  score:', -159.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57996701  0.        ]]
# ('episode:', 596, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56150674  0.        ]]
# ('episode:', 597, '  score:', -141.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59895814  0.        ]]
# ('episode:', 598, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.47190911  0.        ]]
# ('episode:', 599, '  score:', -101.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.54173947  0.        ]]
# ('episode:', 600, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44409895  0.        ]]
# ('episode:', 601, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50453686  0.        ]]
# ('episode:', 602, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46733652  0.        ]]
# ('episode:', 603, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4777048  0.       ]]
# ('episode:', 604, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58195656  0.        ]]
# ('episode:', 605, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57228489  0.        ]]
# ('episode:', 606, '  score:', -192.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4793123  0.       ]]
# ('episode:', 607, '  score:', -111.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.451939  0.      ]]
# ('episode:', 608, '  score:', -160.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43193721  0.        ]]
# ('episode:', 609, '  score:', -104.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58703227  0.        ]]
# ('episode:', 610, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.59529317  0.        ]]
# ('episode:', 611, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51226262  0.        ]]
# ('episode:', 612, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50837957  0.        ]]
# ('episode:', 613, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58837118  0.        ]]
# ('episode:', 614, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.48090982  0.        ]]
# ('episode:', 615, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4418626  0.       ]]
# ('episode:', 616, '  score:', -89.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51993006  0.        ]]
# ('episode:', 617, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.49901336  0.        ]]
# ('episode:', 618, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51435919  0.        ]]
# ('episode:', 619, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45063896  0.        ]]
# ('episode:', 620, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.48532643  0.        ]]
# ('episode:', 621, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.52363488  0.        ]]
# ('episode:', 622, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.48954466  0.        ]]
# ('episode:', 623, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41049744  0.        ]]
# ('episode:', 624, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.57337632  0.        ]]
# ('episode:', 625, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50658812  0.        ]]
# ('episode:', 626, '  score:', -168.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.41311314  0.        ]]
# ('episode:', 627, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.58146987  0.        ]]
# ('episode:', 628, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45440024  0.        ]]
# ('episode:', 629, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4849087  0.       ]]
# ('episode:', 630, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45172485  0.        ]]
# ('episode:', 631, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45971023  0.        ]]
# ('episode:', 632, '  score:', -94.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55418048  0.        ]]
# ('episode:', 633, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43320902  0.        ]]
# ('episode:', 634, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5746954  0.       ]]
# ('episode:', 635, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.5022244  0.       ]]
# ('episode:', 636, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.48893867  0.        ]]
# ('episode:', 637, '  score:', -179.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46544159  0.        ]]
# ('episode:', 638, '  score:', -97.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.44271793  0.        ]]
# ('episode:', 639, '  score:', -177.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43873391  0.        ]]
# ('episode:', 640, '  score:', -134.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56960086  0.        ]]
# ('episode:', 641, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42161551  0.        ]]
# ('episode:', 642, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.46928788  0.        ]]
# ('episode:', 643, '  score:', -98.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.40703104  0.        ]]
# ('episode:', 644, '  score:', -92.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.45165561  0.        ]]
# ('episode:', 645, '  score:', -96.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.42327858  0.        ]]
# ('episode:', 646, '  score:', -94.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.55631208  0.        ]]
# ('episode:', 647, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.43301772  0.        ]]
# ('episode:', 648, '  score:', -91.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50195838  0.        ]]
# ('episode:', 649, '  score:', -166.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.51541606  0.        ]]
# ('episode:', 650, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.56804212  0.        ]]
# ('episode:', 651, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50120607  0.        ]]
# ('episode:', 652, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50742618  0.        ]]
# ('episode:', 653, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50253897  0.        ]]
# ('episode:', 654, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.53138294  0.        ]]
# ('episode:', 655, '  score:', -157.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.48616791  0.        ]]
# ('episode:', 656, '  score:', -182.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.50721044  0.        ]]
# ('episode:', 657, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# [[-0.4676991  0.       ]]
